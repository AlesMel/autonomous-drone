# %%
import pickle
import numpy as np
import neat
import os
import keyboard

#from game_config import game_config
# MLAGENTS stuff
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
engine_config_channel = EngineConfigurationChannel()
from comunication_channel import AgentLogChannel
agent_count_channel = AgentLogChannel()
engine_config_channel.set_configuration_parameters(time_scale=1)

env_path = "../Builds/train-env/autonomous-drone.exe"

env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
env.reset()
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1
# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()
set_agents_and_double_reset(2)
import time
import random
import math

def eval_agent(genome, cfg):
    i = 0
    send_array = [2, 1, 2]

    while True:
        policy = neat.nn.FeedForwardNetwork.create(genome, cfg)
        #policy = neat.nn.RecurrentNetwork.create(genome, cfg)
        set_agents_and_double_reset(random.randint(1, 1))
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        agent_count = len(decision_steps.agent_id)
        policies = [policy] * agent_count

        unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

        done = False  # Vectorized initialization
        removed_agents = []

        episode_rewards = [0] * agent_count
        print(f"Agent count: {agent_count}")
        while not done:
            # if keyboard.is_pressed('q'):  # Check if 'q' is pressed
            #     env.close()
            #     return
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    nn_input = np.asarray(decision_steps[agent].obs[:])
                    #print(f"{agent} {nn_input}")
                    actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                    print(f"{agent} {actions}")
                    #actions = [0, 0, 0, 0]
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)

                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward                             
            if len(removed_agents) >= agent_count:
                print(".") 
                done = True
        print(round(max(episode_rewards), 2))
        for reward in episode_rewards:
            print(reward)
        #while keyboard.is_pressed('c') == False:
        #    time.sleep(0.1)
save_nn_destination = 'result/best.pkl'

with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    genome = genome[1]
    print(genome)
print(genome.fitness)
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'test_config')

eval_agent(genome, config)
env.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\rpc_communicator.py:71, in RpcCommunicator.create_server(self)
#      69 # Using unspecified address, which means that grpc is communicating on all IPs
#      70 # This is so that the docker container can connect.
# ---> 71 self.server.add_insecure_port("[::]:" + str(self.port))
#      72 self.server.start()
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\grpc\_server.py:969, in _Server.add_insecure_port(self, address)
#     968 def add_insecure_port(self, address):
# --> 969     return _common.validate_port_binding_result(
#     970         address, _add_insecure_port(self._state, _common.encode(address)))
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\grpc\_common.py:166, in validate_port_binding_result(address, port)
#     163 if port == 0:
#     164     # The Core API doesn't return a failure message. The best we can do
#     165     # is raising an exception to prevent further confusion.
# --> 166     raise RuntimeError(_ERROR_MESSAGE_PORT_BINDING_FAILED % address)
#     167 else:
#
# RuntimeError: Failed to bind to address [::]:5004; set GRPC_VERBOSITY=debug environment variable to see detailed error message.
#
# During handling of the above exception, another exception occurred:
#
# UnityWorkerInUseException                 Traceback (most recent call last)
# Cell In[2], line 19
#      15 engine_config_channel.set_configuration_parameters(time_scale=1)
#      17 env_path = "../Builds/train-env/autonomous-drone.exe"
# ---> 19 env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
#      20 env.reset()
#      21 behavior_specs = env.behavior_specs
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:189, in UnityEnvironment.__init__(self, file_name, worker_id, base_port, seed, no_graphics, timeout_wait, additional_args, side_channels, log_folder, num_areas)
#     187 self._process: Optional[subprocess.Popen] = None
#     188 self._timeout_wait: int = timeout_wait
# --> 189 self._communicator = self._get_communicator(worker_id, base_port, timeout_wait)
#     190 self._worker_id = worker_id
#     191 if side_channels is None:
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:267, in UnityEnvironment._get_communicator(worker_id, base_port, timeout_wait)
#     265 @staticmethod
#     266 def _get_communicator(worker_id, base_port, timeout_wait):
# --> 267     return RpcCommunicator(worker_id, base_port, timeout_wait)
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\rpc_communicator.py:51, in RpcCommunicator.__init__(self, worker_id, base_port, timeout_wait)
#      49 self.unity_to_external = None
#      50 self.is_open = False
# ---> 51 self.create_server()
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\rpc_communicator.py:75, in RpcCommunicator.create_server(self)
#      73     self.is_open = True
#      74 except Exception:
# ---> 75     raise UnityWorkerInUseException(self.worker_id)
#
# UnityWorkerInUseException: Couldn't start socket communication because worker number 0 is still in use. You may need to manually close a previously opened environment or use a different worker number.
