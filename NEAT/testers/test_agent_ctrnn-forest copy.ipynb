# %%
import pickle
import numpy as np
import neat
import os
import keyboard

#from game_config import game_config
# MLAGENTS stuff
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
engine_config_channel = EngineConfigurationChannel()
from comunication_channel import AgentLogChannel
agent_count_channel = AgentLogChannel()
engine_config_channel.set_configuration_parameters(time_scale=1)

env_path = "../Builds/train-env/autonomous-drone.exe"

env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x0000014013646E90>
# Name of the behavior : ForestControl?team=0
# Number of observations :  5

# %%
# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# There are 4 continuous actions

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
set_agents_and_double_reset(2)

# %%
import time
import random
import math

def eval_agent(genome, cfg):
    i = 0
    send_array = [2, 1, 2]

    while True:
        policy = neat.ctrnn.CTRNN.create(genome, cfg, time_const)
        set_agents_and_double_reset(random.randint(1, 1))
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        agent_count = len(decision_steps.agent_id)
        policies = [policy] * agent_count

        unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

        done = False  # Vectorized initialization
        removed_agents = []

        episode_rewards = [0] * agent_count
        print(f"Agent count: {agent_count}")
        while not done:
            # if keyboard.is_pressed('q'):  # Check if 'q' is pressed
            #     env.close()
            #     return
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    obs = np.concatenate(decision_steps[agent].obs[:])
                    nn_input =  np.asarray(obs)
                    #print(f"{agent} {nn_input}")
                    actions = policies[unity_to_neat_map[agent]].advance(nn_input, time_const, time_const)
                    #print(f"{agent} {actions}")
                    #actions = [1, 0.5,0.5, 1]
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)

                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward                             
            if len(removed_agents) >= agent_count:
                print(".") 
                done = True
        for reward in episode_rewards:
            print(reward)
        #while keyboard.is_pressed('c') == False:
        #    time.sleep(0.1)

# %%
save_nn_destination = '../result/best.pkl'

with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    genome = genome[1]
    print(genome)
print(genome.fitness)
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    '../configs/config-recurrent-cave')
# Save best genome
# with open(f'best.pkl', 'wb') as f:
#    pickle.dump(genome, f)
eval_agent(genome, config)
# Out:
# Key: 267274
# Fitness: 2.782757580398993
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	242 DefaultNodeGene(key=242, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	414 DefaultNodeGene(key=414, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	1377 DefaultNodeGene(key=1377, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	1429 DefaultNodeGene(key=1429, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	1500 DefaultNodeGene(key=1500, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	1600 DefaultNodeGene(key=1600, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	3063 DefaultNodeGene(key=3063, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	3874 DefaultNodeGene(key=3874, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	4145 DefaultNodeGene(key=4145, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	5124 DefaultNodeGene(key=5124, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	9707 DefaultNodeGene(key=9707, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	19878 DefaultNodeGene(key=19878, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	24725 DefaultNodeGene(key=24725, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	24792 DefaultNodeGene(key=24792, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	47418 DefaultNodeGene(key=47418, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	47485 DefaultNodeGene(key=47485, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	48176 DefaultNodeGene(key=48176, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	63987 DefaultNodeGene(key=63987, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	83446 DefaultNodeGene(key=83446, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	88078 DefaultNodeGene(key=88078, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	88121 DefaultNodeGene(key=88121, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	91709 DefaultNodeGene(key=91709, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	98123 DefaultNodeGene(key=98123, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	98194 DefaultNodeGene(key=98194, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	129159 DefaultNodeGene(key=129159, bias=-0.0, response=1.0, activation=swish, aggregation=sum)
# 	185930 DefaultNodeGene(key=185930, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	199918 DefaultNodeGene(key=199918, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# 	214139 DefaultNodeGene(key=214139, bias=0.0, response=1.0, activation=swish, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-76, 1), weight=-3.0997207508076876, enabled=True)
# 	DefaultConnectionGene(key=(-76, 2), weight=-1.1173514106965203, enabled=True)
# 	DefaultConnectionGene(key=(-76, 242), weight=0.1351984856849987, enabled=True)
# 	DefaultConnectionGene(key=(-76, 3874), weight=-0.0041581081123472224, enabled=True)
# 	DefaultConnectionGene(key=(-76, 48176), weight=-4.852354119533912, enabled=False)
# 	DefaultConnectionGene(key=(-75, 242), weight=0.11113382436006147, enabled=False)
# 	DefaultConnectionGene(key=(-74, 3), weight=-0.020572754719565704, enabled=True)
# 	DefaultConnectionGene(key=(-73, 0), weight=0.47034601083832517, enabled=False)
# 	DefaultConnectionGene(key=(-72, 3), weight=0.7951686927032859, enabled=True)
# 	DefaultConnectionGene(key=(-72, 3063), weight=0.5712351118306178, enabled=False)
# 	DefaultConnectionGene(key=(-72, 4145), weight=-2.209050202114829, enabled=False)
# 	DefaultConnectionGene(key=(-71, 2), weight=-0.05490901632338011, enabled=True)
# 	DefaultConnectionGene(key=(-71, 242), weight=1.497416788401421, enabled=True)
# 	DefaultConnectionGene(key=(-70, 0), weight=0.22818481872874985, enabled=True)
# 	DefaultConnectionGene(key=(-70, 2), weight=-0.023447933249741235, enabled=True)
# 	DefaultConnectionGene(key=(-69, 1), weight=0.04758246926510692, enabled=True)
# 	DefaultConnectionGene(key=(-69, 2), weight=-0.41403773541199673, enabled=True)
# 	DefaultConnectionGene(key=(-69, 242), weight=0.9137371337296001, enabled=True)
# 	DefaultConnectionGene(key=(-69, 1377), weight=0.29158593841726616, enabled=False)
# 	DefaultConnectionGene(key=(-69, 24725), weight=-2.4290166972511686, enabled=True)
# 	DefaultConnectionGene(key=(-68, 1), weight=-0.15383943919727866, enabled=False)
# 	DefaultConnectionGene(key=(-68, 2), weight=-1.7917892836519829, enabled=False)
# 	DefaultConnectionGene(key=(-68, 242), weight=0.05913217866308495, enabled=False)
# 	DefaultConnectionGene(key=(-68, 63987), weight=0.3847423469883768, enabled=False)
# 	DefaultConnectionGene(key=(-68, 91709), weight=2.2977871174627684, enabled=True)
# 	DefaultConnectionGene(key=(-67, 2), weight=0.804314029479636, enabled=True)
# 	DefaultConnectionGene(key=(-66, 1), weight=0.2493377568557584, enabled=False)
# 	DefaultConnectionGene(key=(-66, 2), weight=-2.3531187327611955, enabled=False)
# 	DefaultConnectionGene(key=(-66, 3), weight=4.053617032185982, enabled=True)
# 	DefaultConnectionGene(key=(-66, 3874), weight=-0.2408625291580234, enabled=True)
# 	DefaultConnectionGene(key=(-65, 2), weight=-0.14206826696678287, enabled=True)
# 	DefaultConnectionGene(key=(-65, 242), weight=-0.16344269631314368, enabled=True)
# 	DefaultConnectionGene(key=(-64, 2), weight=-0.24110824423171268, enabled=False)
# 	DefaultConnectionGene(key=(-64, 3), weight=-0.4506066442928385, enabled=False)
# 	DefaultConnectionGene(key=(-63, 2), weight=-0.24813308764835518, enabled=True)
# 	DefaultConnectionGene(key=(-63, 3), weight=1.2693213816741142, enabled=False)
# 	DefaultConnectionGene(key=(-63, 47485), weight=-0.10691882077194446, enabled=True)
# 	DefaultConnectionGene(key=(-62, 0), weight=0.02513046149327894, enabled=True)
# 	DefaultConnectionGene(key=(-62, 242), weight=-0.6505260388373195, enabled=True)
# 	DefaultConnectionGene(key=(-61, 0), weight=-1.5485335223708803, enabled=True)
# 	DefaultConnectionGene(key=(-61, 2), weight=0.857872488277533, enabled=False)
# 	DefaultConnectionGene(key=(-60, 0), weight=0.36502852508602396, enabled=False)
# 	DefaultConnectionGene(key=(-60, 1), weight=0.10127590680078496, enabled=False)
# 	DefaultConnectionGene(key=(-60, 3), weight=0.07440400164423411, enabled=False)
# 	DefaultConnectionGene(key=(-60, 129159), weight=0.20546337298472647, enabled=True)
# 	DefaultConnectionGene(key=(-59, 0), weight=0.061395275451664455, enabled=True)
# 	DefaultConnectionGene(key=(-59, 242), weight=0.010445291452439755, enabled=False)
# 	DefaultConnectionGene(key=(-59, 414), weight=2.1438537011978394, enabled=True)
# 	DefaultConnectionGene(key=(-59, 88078), weight=1.2781326440309417, enabled=True)
# 	DefaultConnectionGene(key=(-58, 1), weight=0.5434128515727632, enabled=False)
# 	DefaultConnectionGene(key=(-58, 2), weight=-1.1606583854483072, enabled=True)
# 	DefaultConnectionGene(key=(-58, 3), weight=0.7378239174879532, enabled=True)
# 	DefaultConnectionGene(key=(-58, 5124), weight=-0.154514979299253, enabled=True)
# 	DefaultConnectionGene(key=(-57, 1), weight=1.7952793889316905, enabled=True)
# 	DefaultConnectionGene(key=(-57, 3), weight=1.1922074583230313, enabled=True)
# 	DefaultConnectionGene(key=(-56, 0), weight=-9.668875720472109, enabled=True)
# 	DefaultConnectionGene(key=(-56, 3), weight=-0.3997649996601785, enabled=True)
# 	DefaultConnectionGene(key=(-56, 242), weight=5.273634768333942, enabled=True)
# 	DefaultConnectionGene(key=(-55, 0), weight=-5.468447798881958, enabled=True)
# 	DefaultConnectionGene(key=(-55, 1), weight=-0.005952288378164361, enabled=True)
# 	DefaultConnectionGene(key=(-55, 2), weight=0.10056086476926396, enabled=True)
# 	DefaultConnectionGene(key=(-55, 242), weight=1.179944301128749, enabled=True)
# 	DefaultConnectionGene(key=(-54, 242), weight=0.7745596376850186, enabled=True)
# 	DefaultConnectionGene(key=(-53, 1), weight=-4.818866140275701, enabled=False)
# 	DefaultConnectionGene(key=(-53, 2), weight=-0.3826947450800319, enabled=True)
# 	DefaultConnectionGene(key=(-53, 242), weight=-0.009822796468146593, enabled=True)
# 	DefaultConnectionGene(key=(-52, 1), weight=0.4876247135711279, enabled=True)
# 	DefaultConnectionGene(key=(-52, 2), weight=0.6298971714167164, enabled=False)
# 	DefaultConnectionGene(key=(-51, 1), weight=-0.20352970204090756, enabled=True)
# 	DefaultConnectionGene(key=(-51, 3), weight=0.5988199787130208, enabled=False)
# 	DefaultConnectionGene(key=(-51, 1600), weight=0.6285001190712225, enabled=True)
# 	DefaultConnectionGene(key=(-51, 24792), weight=-0.12373744470587586, enabled=True)
# 	DefaultConnectionGene(key=(-50, 3), weight=-0.0878582014492717, enabled=False)
# 	DefaultConnectionGene(key=(-50, 242), weight=-0.29165276687990727, enabled=True)
# 	DefaultConnectionGene(key=(-50, 1600), weight=-1.7570275667168487, enabled=True)
# 	DefaultConnectionGene(key=(-49, 242), weight=0.8861739739776722, enabled=True)
# 	DefaultConnectionGene(key=(-48, 1), weight=0.13053891432141723, enabled=False)
# 	DefaultConnectionGene(key=(-48, 3), weight=-0.3696156383489976, enabled=True)
# 	DefaultConnectionGene(key=(-47, 0), weight=0.04487772220556868, enabled=True)
# 	DefaultConnectionGene(key=(-47, 1), weight=0.7007915141396984, enabled=True)
# 	DefaultConnectionGene(key=(-47, 2), weight=-0.1591182721233728, enabled=False)
# 	DefaultConnectionGene(key=(-47, 3), weight=0.1063401831691156, enabled=True)
# 	DefaultConnectionGene(key=(-46, 0), weight=0.882352423089596, enabled=True)
# 	DefaultConnectionGene(key=(-46, 1), weight=-1.1895294537645835, enabled=True)
# 	DefaultConnectionGene(key=(-45, 3), weight=0.024963472005254533, enabled=True)
# 	DefaultConnectionGene(key=(-44, 2), weight=-0.1128386141412425, enabled=True)
# 	DefaultConnectionGene(key=(-44, 24725), weight=0.062377110946928216, enabled=True)
# 	DefaultConnectionGene(key=(-43, 1), weight=-0.01749786326187813, enabled=True)
# 	DefaultConnectionGene(key=(-43, 2), weight=0.15679651025878558, enabled=False)
# 	DefaultConnectionGene(key=(-43, 3), weight=0.8947094612728884, enabled=True)
# 	DefaultConnectionGene(key=(-43, 242), weight=-0.5808035749261788, enabled=False)
# 	DefaultConnectionGene(key=(-42, 1), weight=1.826163969407755, enabled=True)
# 	DefaultConnectionGene(key=(-42, 3), weight=1.5363512753873065, enabled=True)
# 	DefaultConnectionGene(key=(-42, 242), weight=-0.1488001644526064, enabled=True)
# 	DefaultConnectionGene(key=(-40, 0), weight=1.8159963287945704, enabled=True)
# 	DefaultConnectionGene(key=(-40, 242), weight=1.079243932635015, enabled=False)
# 	DefaultConnectionGene(key=(-40, 199918), weight=1.9181489300436063, enabled=True)
# 	DefaultConnectionGene(key=(-39, 2), weight=2.115334325479617, enabled=False)
# 	DefaultConnectionGene(key=(-39, 3), weight=-0.24565701128853776, enabled=True)
# 	DefaultConnectionGene(key=(-39, 242), weight=0.737812176661033, enabled=False)
# 	DefaultConnectionGene(key=(-38, 0), weight=0.20092966841969345, enabled=True)
# 	DefaultConnectionGene(key=(-38, 242), weight=0.09400333065407204, enabled=True)
# 	DefaultConnectionGene(key=(-37, 0), weight=-0.4236550905505511, enabled=True)
# 	DefaultConnectionGene(key=(-37, 1), weight=-2.0827703873962284, enabled=False)
# 	DefaultConnectionGene(key=(-37, 242), weight=0.8970895715187688, enabled=True)
# 	DefaultConnectionGene(key=(-37, 98194), weight=0.7912682375303591, enabled=True)
# 	DefaultConnectionGene(key=(-36, 0), weight=-0.5826100255125919, enabled=True)
# 	DefaultConnectionGene(key=(-36, 1), weight=1.0978267814705915, enabled=False)
# 	DefaultConnectionGene(key=(-36, 2), weight=2.5322262787579595, enabled=False)
# 	DefaultConnectionGene(key=(-36, 3), weight=1.6837025041525497, enabled=False)
# 	DefaultConnectionGene(key=(-36, 88121), weight=1.460488406797324, enabled=True)
# 	DefaultConnectionGene(key=(-35, 0), weight=-0.04263269659278923, enabled=True)
# 	DefaultConnectionGene(key=(-35, 1), weight=-1.5776331354790056, enabled=True)
# 	DefaultConnectionGene(key=(-35, 2), weight=0.4968329341118299, enabled=True)
# 	DefaultConnectionGene(key=(-35, 242), weight=1.5582901524972854, enabled=True)
# 	DefaultConnectionGene(key=(-34, 1), weight=-0.1411898102852, enabled=True)
# 	DefaultConnectionGene(key=(-34, 2), weight=-0.1459560129727789, enabled=False)
# 	DefaultConnectionGene(key=(-34, 3), weight=1.4774692341146485, enabled=True)
# 	DefaultConnectionGene(key=(-34, 242), weight=1.0803076702772536, enabled=False)
# 	DefaultConnectionGene(key=(-33, 0), weight=0.03750145036330718, enabled=True)
# 	DefaultConnectionGene(key=(-33, 1), weight=-0.5515083418683225, enabled=False)
# 	DefaultConnectionGene(key=(-33, 3), weight=-0.4768446118093076, enabled=False)
# 	DefaultConnectionGene(key=(-33, 242), weight=2.0739027333217175, enabled=True)
# 	DefaultConnectionGene(key=(-32, 3), weight=0.17624993835422895, enabled=True)
# 	DefaultConnectionGene(key=(-31, 0), weight=0.8046668038048863, enabled=False)
# 	DefaultConnectionGene(key=(-31, 1), weight=1.9833840806803762, enabled=True)
# 	DefaultConnectionGene(key=(-31, 3), weight=0.7154989979163205, enabled=False)
# 	DefaultConnectionGene(key=(-31, 414), weight=3.6535287304816007, enabled=False)
# 	DefaultConnectionGene(key=(-31, 1429), weight=0.13240683611783916, enabled=True)
# 	DefaultConnectionGene(key=(-30, 1), weight=5.359669129760338, enabled=True)
# 	DefaultConnectionGene(key=(-30, 242), weight=0.8076396671092154, enabled=False)
# 	DefaultConnectionGene(key=(-29, 1), weight=-2.903584068060597, enabled=True)
# 	DefaultConnectionGene(key=(-29, 2), weight=-0.34055497454006833, enabled=True)
# 	DefaultConnectionGene(key=(-29, 3), weight=4.4744725056184445, enabled=False)
# 	DefaultConnectionGene(key=(-29, 242), weight=-0.34520400825988623, enabled=True)
# 	DefaultConnectionGene(key=(-29, 47418), weight=0.48238524401959926, enabled=True)
# 	DefaultConnectionGene(key=(-28, 1), weight=0.3030050294669381, enabled=False)
# 	DefaultConnectionGene(key=(-28, 242), weight=0.11585783435601592, enabled=False)
# 	DefaultConnectionGene(key=(-27, 3), weight=1.158145718527519, enabled=True)
# 	DefaultConnectionGene(key=(-26, 0), weight=2.3564324138343498, enabled=False)
# 	DefaultConnectionGene(key=(-26, 1), weight=-0.002616554183081099, enabled=True)
# 	DefaultConnectionGene(key=(-26, 3), weight=-0.24414490382157245, enabled=False)
# 	DefaultConnectionGene(key=(-26, 242), weight=-0.25791472706839114, enabled=False)
# 	DefaultConnectionGene(key=(-26, 47418), weight=0.9148991528629913, enabled=True)
# 	DefaultConnectionGene(key=(-25, 1), weight=-0.21419082361341302, enabled=False)
# 	DefaultConnectionGene(key=(-25, 2), weight=0.4702389692553045, enabled=False)
# 	DefaultConnectionGene(key=(-25, 242), weight=-1.853518112416339, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=-0.18354540952302065, enabled=True)
# 	DefaultConnectionGene(key=(-24, 2), weight=-0.3843527165344842, enabled=True)
# 	DefaultConnectionGene(key=(-24, 242), weight=-0.9444797283362312, enabled=False)
# 	DefaultConnectionGene(key=(-24, 9707), weight=-1.2407528009813305, enabled=True)
# 	DefaultConnectionGene(key=(-24, 19878), weight=-1.784074358295214, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=0.07263385364318065, enabled=False)
# 	DefaultConnectionGene(key=(-23, 2), weight=2.6044332515744686, enabled=False)
# 	DefaultConnectionGene(key=(-23, 242), weight=0.594056936101916, enabled=True)
# 	DefaultConnectionGene(key=(-23, 83446), weight=0.9791977794049246, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=0.011644523149622638, enabled=True)
# 	DefaultConnectionGene(key=(-22, 1), weight=0.8864196705906705, enabled=False)
# 	DefaultConnectionGene(key=(-22, 2), weight=-0.3598516913653996, enabled=True)
# 	DefaultConnectionGene(key=(-22, 3), weight=-0.3856719949571203, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=1.5579505054662968, enabled=False)
# 	DefaultConnectionGene(key=(-21, 48176), weight=-0.024337371476949088, enabled=True)
# 	DefaultConnectionGene(key=(-20, 2), weight=3.427819278204418, enabled=True)
# 	DefaultConnectionGene(key=(-20, 242), weight=1.0350753432989244, enabled=False)
# 	DefaultConnectionGene(key=(-19, 0), weight=0.29641577384620554, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=-0.13500743355623684, enabled=False)
# 	DefaultConnectionGene(key=(-19, 1500), weight=-1.2074067930662316, enabled=True)
# 	DefaultConnectionGene(key=(-19, 214139), weight=1.7936532696842016, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=1.3448693847414777, enabled=False)
# 	DefaultConnectionGene(key=(-18, 1), weight=0.5228208201595222, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1), weight=-0.15182986384610447, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=-0.36554272137750443, enabled=True)
# 	DefaultConnectionGene(key=(-17, 3), weight=-0.4819271762463939, enabled=True)
# 	DefaultConnectionGene(key=(-17, 242), weight=-1.975355433600638, enabled=True)
# 	DefaultConnectionGene(key=(-17, 98123), weight=0.09826702610090732, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=0.47231301759625643, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=4.902701680883111, enabled=False)
# 	DefaultConnectionGene(key=(-15, 242), weight=0.35943921994719197, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=3.3812842316030345, enabled=True)
# 	DefaultConnectionGene(key=(-14, 2), weight=-0.2923993442542238, enabled=True)
# 	DefaultConnectionGene(key=(-14, 242), weight=-3.1811437784425713, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=0.12700087918078537, enabled=False)
# 	DefaultConnectionGene(key=(-13, 2), weight=0.7002099128940905, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=0.5381318504779153, enabled=False)
# 	DefaultConnectionGene(key=(-12, 2), weight=0.6254792486268143, enabled=False)
# 	DefaultConnectionGene(key=(-12, 3), weight=0.034196216676824785, enabled=True)
# 	DefaultConnectionGene(key=(-12, 242), weight=-0.33272103979295553, enabled=False)
# 	DefaultConnectionGene(key=(-11, 3), weight=0.5102856526188206, enabled=False)
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.7058996771669916, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=1.7437035452487974, enabled=False)
# 	DefaultConnectionGene(key=(-10, 2), weight=-0.0010770235145083993, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=2.1740971025787483, enabled=True)
# 	DefaultConnectionGene(key=(-9, 242), weight=1.3046006040161333, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=0.874294241373941, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=0.05920380975708598, enabled=True)
# 	DefaultConnectionGene(key=(-8, 242), weight=1.5297562442830304, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-3.2668352711070994, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=-2.046443145854577, enabled=False)
# 	DefaultConnectionGene(key=(-6, 2), weight=0.8573829957702885, enabled=True)
# 	DefaultConnectionGene(key=(-6, 47485), weight=1.536608666053998, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=2.113700050962797, enabled=True)
# 	DefaultConnectionGene(key=(-5, 242), weight=1.652609907664624, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.48154123104331864, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=-0.028262187940057915, enabled=False)
# 	DefaultConnectionGene(key=(-4, 242), weight=1.750889558900076, enabled=False)
# 	DefaultConnectionGene(key=(-4, 1500), weight=-1.4004218014386012, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3063), weight=0.2583797571171877, enabled=True)
# 	DefaultConnectionGene(key=(-4, 185930), weight=2.853143171525472, enabled=True)
# 	DefaultConnectionGene(key=(-3, 242), weight=-0.3515465676767557, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=0.9960014036638991, enabled=False)
# 	DefaultConnectionGene(key=(-2, 3), weight=-0.611628712618641, enabled=False)
# 	DefaultConnectionGene(key=(-1, 2), weight=0.0420598556087764, enabled=False)
# 	DefaultConnectionGene(key=(-1, 3), weight=1.3980288728468007, enabled=True)
# 	DefaultConnectionGene(key=(-1, 242), weight=0.0017749395069364207, enabled=False)
# 	DefaultConnectionGene(key=(1, 1), weight=-1.8685026951917922, enabled=False)
# 	DefaultConnectionGene(key=(1, 414), weight=-0.07516344244368313, enabled=True)
# 	DefaultConnectionGene(key=(2, 2), weight=0.02711355761145738, enabled=False)
# 	DefaultConnectionGene(key=(242, 0), weight=0.24198559292936483, enabled=False)
# 	DefaultConnectionGene(key=(242, 1), weight=-4.106153925270868, enabled=True)
# 	DefaultConnectionGene(key=(242, 2), weight=-1.6040822993090507, enabled=True)
# 	DefaultConnectionGene(key=(242, 3), weight=-2.0369847160495613, enabled=True)
# 	DefaultConnectionGene(key=(414, 242), weight=1.9976534154949017, enabled=True)
# 	DefaultConnectionGene(key=(1377, 2), weight=0.40248556144374814, enabled=True)
# 	DefaultConnectionGene(key=(1429, 1), weight=0.4494059438210255, enabled=False)
# 	DefaultConnectionGene(key=(1500, 0), weight=-1.0673075241698036, enabled=True)
# 	DefaultConnectionGene(key=(1500, 3), weight=0.36638563918052564, enabled=True)
# 	DefaultConnectionGene(key=(1600, 3), weight=0.9534317658769164, enabled=True)
# 	DefaultConnectionGene(key=(3063, 1377), weight=-0.794107984029583, enabled=True)
# 	DefaultConnectionGene(key=(4145, 2), weight=0.9035053951177338, enabled=True)
# 	DefaultConnectionGene(key=(4145, 4145), weight=2.2947979778400347, enabled=True)
# 	DefaultConnectionGene(key=(9707, 242), weight=0.058164993955086036, enabled=True)
# 	DefaultConnectionGene(key=(19878, 242), weight=-0.0885575893335164, enabled=True)
# 	DefaultConnectionGene(key=(24725, 1), weight=-1.765894025404536, enabled=True)
# 	DefaultConnectionGene(key=(47418, 1), weight=4.086112207336159, enabled=True)
# 	DefaultConnectionGene(key=(48176, 242), weight=-4.399479858332709, enabled=True)
# 	DefaultConnectionGene(key=(63987, 242), weight=0.7047257326040034, enabled=True)
# 	DefaultConnectionGene(key=(83446, 242), weight=0.06501548872980732, enabled=False)
# 	DefaultConnectionGene(key=(88078, 414), weight=0.11987939693190736, enabled=True)
# 	DefaultConnectionGene(key=(88078, 48176), weight=1.5886572812735784, enabled=True)
# 	DefaultConnectionGene(key=(88121, 1), weight=-0.6431421788550165, enabled=True)
# 	DefaultConnectionGene(key=(91709, 2), weight=-0.266220557349114, enabled=True)
# 	DefaultConnectionGene(key=(98194, 0), weight=0.4631695940298438, enabled=True)
# 	DefaultConnectionGene(key=(98194, 1), weight=-1.4384383455190473, enabled=True)
# 	DefaultConnectionGene(key=(129159, 3), weight=0.06080977738571722, enabled=True)
# 	DefaultConnectionGene(key=(185930, 242), weight=1.1129121754173614, enabled=True)
# 	DefaultConnectionGene(key=(199918, 242), weight=1.8410775806178319, enabled=True)
# 	DefaultConnectionGene(key=(214139, 1), weight=0.5926069133401872, enabled=True)
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# .
# 2.782757580398993
# Agent count: 1
# ---------------------------------------------------------------------------
# UnityCommunicatorStoppedException         Traceback (most recent call last)
# Cell In[21], line 14
#       8 config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
#       9                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
#      10                     '../configs/config-recurrent-cave')
#      11 # Save best genome
#      12 # with open(f'best.pkl', 'wb') as f:
#      13 #    pickle.dump(genome, f)
# ---> 14 eval_agent(genome, config)
#
# Cell In[20], line 43, in eval_agent(genome, cfg)
#      39         action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
#      40         env.set_action_for_agent(behavior_name=behavior_name,
#      41                                 agent_id=agent,
#      42                                 action=action_tuple)
# ---> 43 env.step()
#      44 decision_steps, terminal_steps = env.get_steps(behavior_name)
#      45 for agent in range(agent_count):
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:350, in UnityEnvironment.step(self)
#     348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
# --> 350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#     351 self._update_behavior_specs(outputs)
#     352 rl_output = outputs.rl_output
#
# UnityCommunicatorStoppedException: Communicator has exited.

# %%
env.close()

# %%
import visualize
name = 'winner-{0}'.format(1)
visualize.draw_net(config, genome, view=False, filename=name + "-net.gv")
visualize.draw_net(config, genome, view=False, filename=name + "-net-pruned.gv", prune_unused=True)
