# %%
import pickle
import numpy as np
import neat
import os
import keyboard

#from game_config import game_config
# MLAGENTS stuff
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
import neat
from neat.genome import DefaultGenome
from neat.genes import DefaultNodeGene, DefaultConnectionGene
from neat.config import ConfigParameter, write_pretty_params
from neat.genes import BaseGene
from neat.attributes import FloatAttribute, BoolAttribute, StringAttribute
from neat.activations import ActivationFunctionSet
from itertools import count
from neat.aggregations import AggregationFunctionSet

class FixedStructureNodeGene(BaseGene):
    _gene_attributes = [
                        FloatAttribute('bias'),
                        FloatAttribute('response'),
                        StringAttribute('activation', options=''),
                        StringAttribute('aggregation', options='')]

    def distance(self, other, config):
        return 0.0


class FixedStructureConnectionGene(BaseGene):
    _gene_attributes = [FloatAttribute('weight'),
                        BoolAttribute('enabled')]
    
    def mutate(self, config):
        for a in self._gene_attributes:
            if not isinstance(a, BoolAttribute):
                v = getattr(self, a.name)
                setattr(self, a.name, a.mutate_value(v, config))

    def distance(self, other, config):
        d = abs(self.weight - other.weight) + abs(self.bias - other.bias)
        return d
    
class FixedStructureGenomeConfig(object):
    __params = [ConfigParameter('feed_forward', bool),
                ConfigParameter('num_inputs', int),
                ConfigParameter('num_outputs', int),
                ConfigParameter('num_hidden', int),
                ConfigParameter('num_hidden_layers', int),
                ConfigParameter('initial_connection', str, 'full_direct'),
                ConfigParameter('conn_add_prob', float),
                ConfigParameter('conn_delete_prob', float),
                ConfigParameter('node_add_prob', float),
                ConfigParameter('node_delete_prob', float)]


    def __init__(self, params):
        # Create full set of available activation functions.
        self.activation_defs = ActivationFunctionSet()
        self.activation_options = params.get('activation_options', 'sigmoid').strip().split()
        self.aggregation_options = params.get('aggregation_options', 'sum').strip().split()
        self.aggregation_function_defs = AggregationFunctionSet()

        # Gather configuration data from the gene classes.
        self.node_gene_type = params['node_gene_type']
        self.__params += self.node_gene_type.get_config_params()
        self.connection_gene_type = params['connection_gene_type']
        self.__params += self.connection_gene_type.get_config_params()
        self.connection_fraction = None
        self.node_indexer = None
        self.structural_mutation_surer = 'false'

        # Use the configuration data to interpret the supplied parameters.
        for p in self.__params:
            setattr(self, p.name, p.interpret(params))

        # By convention, input pins have negative keys, and the output
        # pins have keys 0,1,...
        self.input_keys = [-i - 1 for i in range(self.num_inputs)]
        self.output_keys = [i for i in range(self.num_outputs)]

    def get_new_node_key(self, node_dict):
        if self.node_indexer is None:
            if node_dict:
                self.node_indexer = count(max(list(node_dict)) + 1)
            else:
                self.node_indexer = count(max(list(node_dict)) + 1)

        new_id = next(self.node_indexer)

        assert new_id not in node_dict

        return new_id
    
    def save(self, f):
        write_pretty_params(f, self, self.__params)

class FixedStructureGenome(object):
    @classmethod
    def parse_config(cls, param_dict):
        param_dict['node_gene_type'] = FixedStructureNodeGene
        param_dict['connection_gene_type'] = FixedStructureConnectionGene
        return FixedStructureGenomeConfig(param_dict)
    
    @classmethod
    def write_config(cls, f, config):
        config.save(f)

    def __init__(self, key):
        self.key = key
        self.connections = {}
        self.nodes = {}

        # Fitness results.
        self.fitness = None

    def mutate(self, config):
        """ Mutates this genome. """
        # Mutate connection genes.
        for cg in self.connections.values():
            cg.mutate(config)

        # Mutate node genes (bias, response, etc.).
        for ng in self.nodes.values():
            ng.mutate(config)

    def configure_crossover(self, genome1, genome2, config):
        """ Configure a new genome by crossover from two parent genomes. """
        if genome1.fitness > genome2.fitness:
            parent1, parent2 = genome1, genome2
        else:
            parent1, parent2 = genome2, genome1

        # Inherit connection genes
        for key, cg1 in parent1.connections.items():
            cg2 = parent2.connections.get(key)
            if cg2 is None:
                # Excess or disjoint gene: copy from the fittest parent.
                self.connections[key] = cg1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.connections[key] = cg1.crossover(cg2)
            self.connections[key].enabled = True

        # Inherit node genes
        parent1_set = parent1.nodes
        parent2_set = parent2.nodes

        for key, ng1 in parent1_set.items():
            ng2 = parent2_set.get(key)
            assert key not in self.nodes
            if ng2 is None:
                # Extra gene: copy from the fittest parent
                self.nodes[key] = ng1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.nodes[key] = ng1.crossover(ng2)

    # def add_connection(self, config, input_key, output_key, weight):
    #     key = (input_key, output_key)
    #     connection = FixedStructureConnectionGene(key)
    #     connection.init_attributes(config)
    #     connection.weight = weight
    #     connection.enabled = True

    #     self.connections[key] = connection

    def distance(self, other, config):
        return 0.0
    
    def size(self):
        """Returns genome 'complexity', taken to be (number of nodes, number of enabled connections)"""
        num_enabled_connections = sum([1 for cg in self.connections.values() if cg.enabled is True])
        return len(self.nodes), num_enabled_connections

    def __str__(self):
        s = f"Key: {self.key}\nFitness: {self.fitness}\nNodes:"
        for k, ng in self.nodes.items():
            s += f"\n\t{k} {ng!s}"
        s += "\nConnections:"
        connections = list(self.connections.values())
        connections.sort()
        for c in connections:
            s += "\n\t" + str(c)
        return s
    
    # def add_hidden_nodes(self, config):
    #     for i in range(config.num_hidden):
    #         node_key = self.get_new_node_key()
    #         assert node_key not in self.nodes
    #         node = self.__class__.create_node(config, node_key)
    #         self.nodes[node_key] = node

    def compute_full_connections(self, config, direct):
        """
        Compute connections for a fully-connected feed-forward genome--each
        input connected to all hidden nodes
        (and output nodes if ``direct`` is set or there are no hidden nodes),
        each hidden node connected to all output nodes.
        (Recurrent genomes will also include node self-connections.)
        """
        hidden = [i for i in self.nodes if i not in config.output_keys]
        output = [i for i in self.nodes if i in config.output_keys]
        connections = []
        if hidden:
            for input_id in config.input_keys:
                for h in hidden:
                    connections.append((input_id, h))
            for h in hidden:
                for output_id in output:
                    connections.append((h, output_id))
        if direct or (not hidden):
            for input_id in config.input_keys:
                for output_id in output:
                    connections.append((input_id, output_id))
        return connections   

    def configure_new(self, config):
        # Create node genes for the input and output nodes
        for node_key in config.input_keys + config.output_keys:
            self.nodes[node_key] = self.create_node(config, node_key)

        # Initialize list to keep track of nodes in the last layer (start with input layer)
        last_layer_nodes = config.input_keys

        # Add hidden nodes and layers
        # config.num_hidden now represents the number of neurons PER HIDDEN LAYER
        if config.num_hidden > 0 and config.num_hidden_layers > 0:
            for _ in range(config.num_hidden_layers):
                layer_node_ids = []
                for _ in range(config.num_hidden):  # Create the specified number of nodes for this layer
                    node_key = config.get_new_node_key(self.nodes)
                    self.nodes[node_key] = self.create_node(config, node_key)
                    layer_node_ids.append(node_key)
                
                # Connect all nodes from the last layer to the current layer's nodes
                for last_layer_node in last_layer_nodes:
                    for current_layer_node in layer_node_ids:
                        connection = self.create_connection(config, last_layer_node, current_layer_node)
                        self.connections[connection.key] = connection

                # Update last_layer_nodes to reflect the current layer for next iteration
                last_layer_nodes = layer_node_ids

            # Connect all nodes from the last hidden layer to the output nodes
            for hidden_node_id in last_layer_nodes:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, hidden_node_id, output_node_id)
                    self.connections[connection.key] = connection
        else:
            # If there are no hidden layers, connect input nodes directly to output nodes
            for input_node_id in config.input_keys:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, input_node_id, output_node_id)
                    self.connections[connection.key] = connection

    @staticmethod
    def create_node(config, node_id):
        node = FixedStructureNodeGene(node_id)
        node.init_attributes(config)
        return node

    @staticmethod
    def create_connection(config, input_id, output_id):
        connection = config.connection_gene_type((input_id, output_id))
        connection.init_attributes(config)
        return connection
# Remember to adjust the class as needed for your application

# %%
engine_config_channel = EngineConfigurationChannel()
from comunication_channel import AgentLogChannel
agent_count_channel = AgentLogChannel()
engine_config_channel.set_configuration_parameters(time_scale=0.1)

env_path = "../Builds/train-env/autonomous-drone.exe"

env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000002D947F29480>
# Name of the behavior : DroneControl?team=0
# Number of observations :  1

# %%
# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# There are 4 continuous actions

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
set_agents_and_double_reset(2)

# %%
import time
import random
import math

def eval_agent(genome, cfg):
    i = 0
    send_array = [2, 1, 2]

    while True:
        policy = neat.nn.FeedForwardNetwork.create(genome, cfg)
        #policy = neat.nn.RecurrentNetwork.create(genome, cfg)
        set_agents_and_double_reset(random.randint(1, 1))
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        agent_count = len(decision_steps.agent_id)
        policies = [policy] * agent_count

        unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

        done = False  # Vectorized initialization
        removed_agents = []

        episode_rewards = [0] * agent_count
        print(f"Agent count: {agent_count}")
        while not done:
            # if keyboard.is_pressed('q'):  # Check if 'q' is pressed
            #     env.close()
            #     return
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    nn_input = np.asarray(decision_steps[agent].obs[:])
                    #print(f"{agent} {nn_input}")
                    actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                    print(f"{agent} {actions}")
                    #actions = [0, 0, 0, 0]
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)

                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward                             
            if len(removed_agents) >= agent_count:
                print(".") 
                done = True
        print(round(max(episode_rewards), 2))
        for reward in episode_rewards:
            print(reward)
        #while keyboard.is_pressed('c') == False:
        #    time.sleep(0.1)

# %%
save_nn_destination = 'result/best.pkl'

with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    #genome = genome[1]
    print(genome)
print(genome.fitness)
config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'config_fixed')

eval_agent(genome, config)
# Out:
# Key: 39132
# Fitness: 39.089240929228254
# Nodes:
# 	-1 FixedStructureNodeGene(key=-1, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-2 FixedStructureNodeGene(key=-2, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-3 FixedStructureNodeGene(key=-3, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-4 FixedStructureNodeGene(key=-4, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-5 FixedStructureNodeGene(key=-5, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-6 FixedStructureNodeGene(key=-6, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-7 FixedStructureNodeGene(key=-7, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-8 FixedStructureNodeGene(key=-8, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-9 FixedStructureNodeGene(key=-9, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-10 FixedStructureNodeGene(key=-10, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-11 FixedStructureNodeGene(key=-11, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-12 FixedStructureNodeGene(key=-12, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-13 FixedStructureNodeGene(key=-13, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-14 FixedStructureNodeGene(key=-14, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-15 FixedStructureNodeGene(key=-15, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	-16 FixedStructureNodeGene(key=-16, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	0 FixedStructureNodeGene(key=0, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	1 FixedStructureNodeGene(key=1, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	2 FixedStructureNodeGene(key=2, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	3 FixedStructureNodeGene(key=3, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	924 FixedStructureNodeGene(key=924, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	925 FixedStructureNodeGene(key=925, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	926 FixedStructureNodeGene(key=926, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	927 FixedStructureNodeGene(key=927, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	928 FixedStructureNodeGene(key=928, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	929 FixedStructureNodeGene(key=929, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	930 FixedStructureNodeGene(key=930, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	931 FixedStructureNodeGene(key=931, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	932 FixedStructureNodeGene(key=932, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	933 FixedStructureNodeGene(key=933, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	934 FixedStructureNodeGene(key=934, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	935 FixedStructureNodeGene(key=935, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	936 FixedStructureNodeGene(key=936, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	937 FixedStructureNodeGene(key=937, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	938 FixedStructureNodeGene(key=938, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	939 FixedStructureNodeGene(key=939, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	940 FixedStructureNodeGene(key=940, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	941 FixedStructureNodeGene(key=941, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	942 FixedStructureNodeGene(key=942, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	943 FixedStructureNodeGene(key=943, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	FixedStructureConnectionGene(key=(-16, 924), weight=0.028139471112199693, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 925), weight=0.18446279861422818, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 926), weight=-0.3532325632084022, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 927), weight=0.1758381739089897, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 928), weight=-0.2556815136519073, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 929), weight=-0.20003760624747896, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 930), weight=-0.11285498918769023, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 931), weight=-0.14511144805268927, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 932), weight=-0.16077330208398558, enabled=True)
# 	FixedStructureConnectionGene(key=(-16, 933), weight=-0.002241686320612113, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 924), weight=0.2107486212815237, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 925), weight=0.23125610254997947, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 926), weight=-0.19768882926487735, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 927), weight=0.23174715734586376, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 928), weight=0.0910997830576796, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 929), weight=-0.03763778115366427, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 930), weight=-0.14059998385361594, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 931), weight=0.010108374189670827, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 932), weight=0.029931865753878236, enabled=True)
# 	FixedStructureConnectionGene(key=(-15, 933), weight=-0.23210575966025196, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 924), weight=0.09276782004893364, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 925), weight=-0.09235655819805369, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 926), weight=0.09969832229938229, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 927), weight=-0.12503344362400912, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 928), weight=0.38153158067582726, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 929), weight=-0.1722597769145539, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 930), weight=0.008609099989609483, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 931), weight=0.26522188650631684, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 932), weight=-0.07897940301119985, enabled=True)
# 	FixedStructureConnectionGene(key=(-14, 933), weight=-0.21642599245835323, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 924), weight=0.028365180887734223, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 925), weight=0.017339296085573774, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 926), weight=-0.3047125138440469, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 927), weight=-0.3878820010589319, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 928), weight=-0.25045499014402944, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 929), weight=0.13182182498097506, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 930), weight=-0.09254254313265099, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 931), weight=0.09765365263552696, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 932), weight=0.0635300816574199, enabled=True)
# 	FixedStructureConnectionGene(key=(-13, 933), weight=0.06730812873461156, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 924), weight=-0.04981060387323652, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 925), weight=-0.9097329734446484, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 926), weight=0.06837564380676006, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 927), weight=0.35678131178128886, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 928), weight=-0.10126502710752472, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 929), weight=0.10104462249934203, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 930), weight=-0.2507701660360087, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 931), weight=-0.01747217695544675, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 932), weight=0.02533683899441861, enabled=True)
# 	FixedStructureConnectionGene(key=(-12, 933), weight=-0.2674365091988057, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 924), weight=-0.19845884048305948, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 925), weight=0.1285611001493924, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 926), weight=-0.10708676622151661, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 927), weight=0.006454117553894773, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 928), weight=0.33447772951891847, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 929), weight=0.002101839097079755, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 930), weight=-0.20117062549660897, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 931), weight=0.09512146784738565, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 932), weight=0.04435255543717302, enabled=True)
# 	FixedStructureConnectionGene(key=(-11, 933), weight=0.1640721034545234, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 924), weight=-0.34003712652207563, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 925), weight=0.20273505383204524, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 926), weight=-0.031486709274785536, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 927), weight=0.0019435713618419451, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 928), weight=-0.0824301739221536, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 929), weight=0.1311433227029057, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 930), weight=0.08310324625968413, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 931), weight=-0.015361928998935554, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 932), weight=0.008777566317940768, enabled=True)
# 	FixedStructureConnectionGene(key=(-10, 933), weight=-0.07773486895638287, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 924), weight=0.09463341462885719, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 925), weight=-0.051811811593373426, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 926), weight=-0.08652535343597714, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 927), weight=-0.18776082301026226, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 928), weight=0.0005136227918400641, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 929), weight=0.05087749166382967, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 930), weight=0.016971804610752594, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 931), weight=0.2261753393288096, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 932), weight=0.037653555608866976, enabled=True)
# 	FixedStructureConnectionGene(key=(-9, 933), weight=0.037745787641056044, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 924), weight=0.06179637254645222, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 925), weight=0.023764081359963753, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 926), weight=0.19837310466948793, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 927), weight=0.23788252717325223, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 928), weight=0.08700424003821772, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 929), weight=-0.03291556757530259, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 930), weight=-0.06902348262906403, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 931), weight=0.14031603231866857, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 932), weight=-0.09926061890704177, enabled=True)
# 	FixedStructureConnectionGene(key=(-8, 933), weight=0.19218865547257918, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 924), weight=0.021061747956444506, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 925), weight=-0.11350523185166554, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 926), weight=0.16414351242118352, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 927), weight=-0.3123729265287556, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 928), weight=-0.07403856978810808, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 929), weight=-0.2650523502371045, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 930), weight=0.0898462311981355, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 931), weight=0.20717030730589417, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 932), weight=-0.04807794496600872, enabled=True)
# 	FixedStructureConnectionGene(key=(-7, 933), weight=0.31656025648185787, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 924), weight=0.015790185614335296, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 925), weight=0.17768856683959738, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 926), weight=-0.0036738294191899657, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 927), weight=0.02987977679394868, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 928), weight=0.040389524771658164, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 929), weight=0.12346066059699254, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 930), weight=0.17178962710116122, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 931), weight=-0.01747081124568215, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 932), weight=-0.10282868593999965, enabled=True)
# 	FixedStructureConnectionGene(key=(-6, 933), weight=-0.7034882642791118, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 924), weight=-0.11778773313206435, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 925), weight=-0.3030620819454796, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 926), weight=0.24032379020262226, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 927), weight=-0.13162324469467132, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 928), weight=-0.1586012323540048, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 929), weight=-0.1924788567401874, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 930), weight=0.32504127346871, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 931), weight=0.028867904393847975, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 932), weight=0.02626198021040898, enabled=True)
# 	FixedStructureConnectionGene(key=(-5, 933), weight=0.0920280357381047, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 924), weight=0.21796373277144623, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 925), weight=-0.0891547284605344, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 926), weight=-0.055534453774254755, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 927), weight=0.21770969093537457, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 928), weight=-0.07949326410493963, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 929), weight=0.17584292445537467, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 930), weight=-0.14734808820272954, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 931), weight=0.08341142364206762, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 932), weight=-0.05987199818933154, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 933), weight=-0.03211925267848472, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 924), weight=0.028344891937838686, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 925), weight=0.20146179950367116, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 926), weight=-0.16264649709119028, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 927), weight=0.022669673199053268, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 928), weight=-0.15308236717090767, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 929), weight=-0.09517795858485861, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 930), weight=-0.15582430419297158, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 931), weight=0.008224031378640102, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 932), weight=0.06687911078486458, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 933), weight=-0.03566383055262823, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 924), weight=-0.04688525142615671, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 925), weight=0.10778893524814159, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 926), weight=-0.002148819781405681, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 927), weight=-0.10542168466919954, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 928), weight=0.2224667705818243, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 929), weight=0.1728718688220248, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 930), weight=-0.31672489799163384, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 931), weight=-0.22797845005072595, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 932), weight=0.17127457852481587, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 933), weight=0.003962039767052973, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 924), weight=-0.05415249512576794, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 925), weight=-0.13675779286800785, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 926), weight=0.022132188688236177, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 927), weight=-0.07167901842983021, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 928), weight=0.17135728781333587, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 929), weight=0.2015319790509091, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 930), weight=0.22660085819296563, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 931), weight=-0.24933143730187937, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 932), weight=-0.022358709094709203, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 933), weight=0.205566947114378, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 934), weight=-0.077349508806458, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 935), weight=0.027643373906921453, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 936), weight=-0.17417336134782319, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 937), weight=-0.00043162018840003924, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 938), weight=0.14836153076552133, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 939), weight=0.18041771907042026, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 940), weight=-0.2045099946433924, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 941), weight=0.24747683812300048, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 942), weight=0.03922772435141435, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 943), weight=-0.19839336240216274, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 934), weight=-0.04556331759956819, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 935), weight=0.03785515799617746, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 936), weight=0.09101884249034552, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 937), weight=-0.2227558894352843, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 938), weight=-0.1569288171329064, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 939), weight=0.04821039084756819, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 940), weight=-0.04507231708846088, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 941), weight=-0.2546521568125841, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 942), weight=0.1542460890814027, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 943), weight=-0.07763909528085478, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 934), weight=0.02073554672017739, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 935), weight=-0.1687229230106156, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 936), weight=-0.015856375552192374, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 937), weight=-0.05425300707683465, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 938), weight=0.016595608156160346, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 939), weight=0.18646285662437012, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 940), weight=-0.3088472064141371, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 941), weight=0.0056310660430112305, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 942), weight=-0.2442471688892114, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 943), weight=-0.09628167470707051, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 934), weight=0.08422781330073298, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 935), weight=-0.05053145475865105, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 936), weight=0.12029625146555628, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 937), weight=0.05039968718941602, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 938), weight=-0.2790970886002773, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 939), weight=-0.3589937663084015, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 940), weight=0.08508209122380142, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 941), weight=-0.06197574380728478, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 942), weight=-0.21107156139302982, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 943), weight=-0.005582595172292787, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 934), weight=0.030694587735008445, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 935), weight=-0.010902470325293463, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 936), weight=-0.0029330218604545024, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 937), weight=-0.025981999803016922, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 938), weight=-0.23936434241224525, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 939), weight=0.06009959475995724, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 940), weight=-0.1362514988687249, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 941), weight=-0.1391599455105071, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 942), weight=-0.17995360430125923, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 943), weight=0.047851885164786244, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 934), weight=-0.11317403244968055, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 935), weight=0.023276364253104392, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 936), weight=0.16941702204527853, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 937), weight=0.07042424796177975, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 938), weight=-0.14518370221919613, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 939), weight=0.03845766851660104, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 940), weight=0.1606871182192361, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 941), weight=0.2129016578420849, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 942), weight=-0.058019530568294994, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 943), weight=0.10272956031689118, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 934), weight=0.28210598371953954, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 935), weight=-0.0684889868952732, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 936), weight=-0.11197240337556744, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 937), weight=-0.014771596482809058, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 938), weight=-0.005285013195331069, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 939), weight=-0.0729380034188934, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 940), weight=0.11241523774444342, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 941), weight=0.21061865940617194, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 942), weight=-0.021024638142808943, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 943), weight=-0.027257179138170985, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 934), weight=0.058690912095375115, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 935), weight=0.12213236289955218, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 936), weight=0.12970047478394853, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 937), weight=-0.05367532501706153, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 938), weight=0.27386078599068986, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 939), weight=-0.1505090390338018, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 940), weight=0.06038848606324951, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 941), weight=-0.05730395119447063, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 942), weight=0.035053659107120896, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 943), weight=-0.013511696294721383, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 934), weight=-0.02865034131817911, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 935), weight=-0.17461725329823566, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 936), weight=0.21778172372547755, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 937), weight=0.10688210747066819, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 938), weight=0.09006126176331189, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 939), weight=0.14141718966506828, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 940), weight=0.09966104117453681, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 941), weight=-0.19461015209336638, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 942), weight=0.018550971549962506, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 943), weight=-0.10898633352961687, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 934), weight=0.00870948412175269, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 935), weight=0.13818839266295124, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 936), weight=-0.23869138931783113, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 937), weight=0.15693918223357137, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 938), weight=-0.07846839066946514, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 939), weight=0.014832589398082519, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 940), weight=0.19710867199238513, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 941), weight=-0.09806965509821765, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 942), weight=0.08223402171998731, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 943), weight=0.01992013294165578, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 0), weight=0.14958166220882085, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 1), weight=-0.02126340701304977, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 2), weight=0.08187257232284023, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 3), weight=-0.15319548302806432, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 0), weight=0.02280710433743731, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 1), weight=-0.07454730182891639, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 2), weight=-0.1783431583638341, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 3), weight=0.15682244169403176, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 0), weight=0.12341721439908926, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 1), weight=-0.17832353501894388, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 2), weight=0.07417436512104139, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 3), weight=0.0023395333908544508, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 0), weight=-0.17996398436846248, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 1), weight=-0.1589064553095146, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 2), weight=-0.2703371800781085, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 3), weight=-0.6050238277909609, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 0), weight=0.1959623285520906, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 1), weight=0.03772843645543714, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 2), weight=0.00713336620764881, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 3), weight=-0.029114002262680433, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 0), weight=-0.07146114836333461, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 1), weight=-0.343378280305886, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 2), weight=0.09651565363860959, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 3), weight=0.16467407751304697, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 0), weight=0.041718877521857836, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 1), weight=-0.0121519624209563, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 2), weight=0.0013822132296902184, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 3), weight=0.02849672398019669, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 0), weight=0.14709600990254112, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 1), weight=0.020323297333882787, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 2), weight=-0.20552842184976194, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 3), weight=-0.06983229276791673, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 0), weight=-0.30002539267838924, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 1), weight=-0.0997375013261924, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 2), weight=-0.07545604944634685, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 3), weight=0.17116418121322574, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 0), weight=0.17951590867162015, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 1), weight=-0.1507826418292435, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 2), weight=-0.34481294709261695, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 3), weight=-0.1527496318919843, enabled=True)
# 39.089240929228254
# Agent count: 1
# 19 [0.05788206852800209, 0.04081259464155611, 0.026888999458427765, 0.005190206997267266]
# 19 [0.049382989237054635, 0.03891514497663553, 0.035178851986093065, 0.025203341517962875]
# 19 [0.046135482873734986, 0.03852743377238104, 0.0378102264996822, 0.03229860777858124]
# 19 [0.04456643305717487, 0.0386692861686096, 0.03832438605401228, 0.034870866397900796]
# 19 [0.04342352455533875, 0.03897087064710955, 0.0379650038548461, 0.03584456072545249]
# 19 [0.07316865290919457, 0.07507756056973594, 0.07075355311505685, 0.06938012292189237]
# 19 [0.05588023422558698, 0.07588313422144169, 0.06522953273042137, 0.08751979156898974]
# 19 [0.04057955734333438, 0.07308177956574322, 0.05782864093892186, 0.09611989208083035]
# 19 [0.029583711546862217, 0.06922268556467948, 0.050410278363458794, 0.09786819008397044]
# 19 [0.02284534413134021, 0.06542532075945147, 0.04351891790746471, 0.09521563026784598]
# 19 [0.01967922548927512, 0.06214507999891796, 0.037358908524925016, 0.08979310678122177]
# 19 [0.019312604481014347, 0.05951930164400132, 0.0320080510766157, 0.08266274471283527]
# 19 [0.021056430871763166, 0.05748391809194466, 0.02739129746785099, 0.07436416495369279]
# 19 [0.02428281112984949, 0.055830636143962664, 0.023316902669105032, 0.06505783862755536]
# 19 [-0.04398757733093664, -0.03916985886132545, 0.033762137016165955, 0.02642484484578461]
# 19 [-0.030011094714731186, -0.043057083161255866, 0.025562281592771092, 0.0005742767934149788]
# 19 [-0.018495379446117337, -0.046462826955664095, 0.023766464280487818, -0.012953140411226716]
# .
# 39.09
# 39.08912092237733
# Agent count: 1
# 19 [0.05788206852800209, 0.04081259464155611, 0.026888999458427765, 0.005190206997267266]
# 19 [0.049382989237054635, 0.03891514497663553, 0.035178851986093065, 0.025203341517962875]
# 19 [0.046135482873734986, 0.03852743377238104, 0.0378102264996822, 0.03229860777858124]
# 19 [0.04456643305717487, 0.0386692861686096, 0.03832438605401228, 0.034870866397900796]
# 19 [0.04342352455533875, 0.03897087064710955, 0.0379650038548461, 0.03584456072545249]
# 19 [0.04227711158784363, 0.039277894500520175, 0.03717705605402143, 0.036235409582719834]
# ---------------------------------------------------------------------------
# UnityCommunicatorStoppedException         Traceback (most recent call last)
# Cell In[22], line 12
#       7 print(genome.fitness)
#       8 config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
#       9                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
#      10                     'config_fixed')
# ---> 12 eval_agent(genome, config)
#
# Cell In[20], line 42, in eval_agent(genome, cfg)
#      38         action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
#      39         env.set_action_for_agent(behavior_name=behavior_name,
#      40                                 agent_id=agent,
#      41                                 action=action_tuple)
# ---> 42 env.step()
#      43 decision_steps, terminal_steps = env.get_steps(behavior_name)
#      44 for agent in range(agent_count):
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:350, in UnityEnvironment.step(self)
#     348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
# --> 350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#     351 self._update_behavior_specs(outputs)
#     352 rl_output = outputs.rl_output
#
# UnityCommunicatorStoppedException: Communicator has exited.

# %%
env.close()
