# %%
import pickle
import numpy as np
import neat
import os
import keyboard

#from game_config import game_config
# MLAGENTS stuff
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
engine_config_channel = EngineConfigurationChannel()
from comunication_channel import AgentLogChannel
agent_count_channel = AgentLogChannel()
engine_config_channel.set_configuration_parameters(time_scale=1)

env_path = "../Builds/train-env/autonomous-drone.exe"

env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000002A12335B0A0>
# Name of the behavior : DroneControl?team=0
# Number of observations :  1

# %%
# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# There are 4 continuous actions

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
set_agents_and_double_reset(2)

# %%
import time
import random
import math

def eval_agent(genome, cfg):
    i = 0
    send_array = [2, 1, 2]

    while True:
        policy = neat.ctrnn.CTRNN.create(genome, cfg, 0.02)
        #policy = neat.nn.RecurrentNetwork.create(genome, cfg)
        set_agents_and_double_reset(random.randint(1, 1))
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        agent_count = len(decision_steps.agent_id)
        policies = [policy] * agent_count

        unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

        done = False  # Vectorized initialization
        removed_agents = []

        episode_rewards = [0] * agent_count
        print(f"Agent count: {agent_count}")
        while not done:
            # if keyboard.is_pressed('q'):  # Check if 'q' is pressed
            #     env.close()
            #     return
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    nn_input = np.asarray(decision_steps[agent].obs[:])
                    #print(f"{agent} {nn_input}")
                    actions = policies[unity_to_neat_map[agent]].advance(nn_input[0], 0.02, 0.02)
                    #print(f"{agent} {actions}")
                    #actions = [0, 0, 0, 0]
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)

                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward                             
            if len(removed_agents) >= agent_count:
                print(".") 
                done = True
        print(round(max(episode_rewards), 2))
        for reward in episode_rewards:
            print(reward)
        #while keyboard.is_pressed('c') == False:
        #    time.sleep(0.1)

# %%
save_nn_destination = 'result/best.pkl'

with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    genome = genome[1]
    print(genome)
print(genome.fitness)
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'config-ctrnn')

eval_agent(genome, config)
# Out:
# Key: 72590
# Fitness: 763.2730853557587
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=1.1297422224699842, response=1.0, activation=tanh3, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.5398495642808837, response=1.0, activation=tanh3, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=2.176128329085536, response=1.0, activation=tanh3, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=3.1418979616984526, response=1.0, activation=tanh3, aggregation=sum)
# 	240 DefaultNodeGene(key=240, bias=-0.5371395987906755, response=1.0, activation=tanh3, aggregation=sum)
# 	1293 DefaultNodeGene(key=1293, bias=-2.259397557813684, response=1.0, activation=tanh3, aggregation=sum)
# 	2295 DefaultNodeGene(key=2295, bias=2.6190844709230316, response=1.0, activation=tanh3, aggregation=sum)
# 	3193 DefaultNodeGene(key=3193, bias=0.32071563477019877, response=1.0, activation=tanh3, aggregation=sum)
# 	3459 DefaultNodeGene(key=3459, bias=3.1626951724775694, response=1.0, activation=tanh3, aggregation=sum)
# 	3584 DefaultNodeGene(key=3584, bias=2.2658213737482047, response=1.0, activation=tanh3, aggregation=sum)
# 	3883 DefaultNodeGene(key=3883, bias=0.9535864955213156, response=1.0, activation=tanh3, aggregation=sum)
# 	3921 DefaultNodeGene(key=3921, bias=0.678002154675156, response=1.0, activation=tanh3, aggregation=sum)
# 	4082 DefaultNodeGene(key=4082, bias=-0.03045079646279719, response=1.0, activation=tanh3, aggregation=sum)
# 	4165 DefaultNodeGene(key=4165, bias=0.5061056138820652, response=1.0, activation=tanh3, aggregation=sum)
# 	4237 DefaultNodeGene(key=4237, bias=0.47842794107006026, response=1.0, activation=tanh3, aggregation=sum)
# 	4382 DefaultNodeGene(key=4382, bias=-0.015327164565915874, response=1.0, activation=tanh3, aggregation=sum)
# 	4432 DefaultNodeGene(key=4432, bias=-0.8418167763471498, response=1.0, activation=tanh3, aggregation=sum)
# 	4686 DefaultNodeGene(key=4686, bias=-0.8569415446149812, response=1.0, activation=tanh3, aggregation=sum)
# 	4720 DefaultNodeGene(key=4720, bias=-3.0639000319484953, response=1.0, activation=tanh3, aggregation=sum)
# 	5101 DefaultNodeGene(key=5101, bias=-2.282839461072288, response=1.0, activation=tanh3, aggregation=sum)
# 	5258 DefaultNodeGene(key=5258, bias=-1.3236672126585676, response=1.0, activation=tanh3, aggregation=sum)
# 	5293 DefaultNodeGene(key=5293, bias=1.985052740106014, response=1.0, activation=tanh3, aggregation=sum)
# 	5505 DefaultNodeGene(key=5505, bias=1.873136948300053, response=1.0, activation=tanh3, aggregation=sum)
# 	5514 DefaultNodeGene(key=5514, bias=0.41086950795201843, response=1.0, activation=tanh3, aggregation=sum)
# 	5679 DefaultNodeGene(key=5679, bias=0.8779137728376767, response=1.0, activation=tanh3, aggregation=sum)
# 	5845 DefaultNodeGene(key=5845, bias=-0.36437620860039915, response=1.0, activation=tanh3, aggregation=sum)
# 	5932 DefaultNodeGene(key=5932, bias=2.061216091946834, response=1.0, activation=tanh3, aggregation=sum)
# 	6284 DefaultNodeGene(key=6284, bias=0.7854717273085282, response=1.0, activation=tanh3, aggregation=sum)
# 	6345 DefaultNodeGene(key=6345, bias=0.2379926885542365, response=1.0, activation=tanh3, aggregation=sum)
# 	6350 DefaultNodeGene(key=6350, bias=-1.5552483277189086, response=1.0, activation=tanh3, aggregation=sum)
# 	6509 DefaultNodeGene(key=6509, bias=-1.7733226390335728, response=1.0, activation=tanh3, aggregation=sum)
# 	6535 DefaultNodeGene(key=6535, bias=0.5913230498510388, response=1.0, activation=tanh3, aggregation=sum)
# 	6622 DefaultNodeGene(key=6622, bias=1.939074537942001, response=1.0, activation=tanh3, aggregation=sum)
# 	6785 DefaultNodeGene(key=6785, bias=-1.1407248944461548, response=1.0, activation=tanh3, aggregation=sum)
# 	6835 DefaultNodeGene(key=6835, bias=-0.30750602114046166, response=1.0, activation=tanh3, aggregation=sum)
# 	6883 DefaultNodeGene(key=6883, bias=-0.20364511872437785, response=1.0, activation=tanh3, aggregation=sum)
# 	6894 DefaultNodeGene(key=6894, bias=2.4659038432592175, response=1.0, activation=tanh3, aggregation=sum)
# 	6909 DefaultNodeGene(key=6909, bias=0.519919076436953, response=1.0, activation=tanh3, aggregation=sum)
# 	7073 DefaultNodeGene(key=7073, bias=-1.0784041775737419, response=1.0, activation=tanh3, aggregation=sum)
# 	7104 DefaultNodeGene(key=7104, bias=-2.556261618188418, response=1.0, activation=tanh3, aggregation=sum)
# 	7122 DefaultNodeGene(key=7122, bias=0.8494998302186332, response=1.0, activation=tanh3, aggregation=sum)
# 	7136 DefaultNodeGene(key=7136, bias=1.2814177319181208, response=1.0, activation=tanh3, aggregation=sum)
# 	7223 DefaultNodeGene(key=7223, bias=-0.3908352212062455, response=1.0, activation=tanh3, aggregation=sum)
# 	7331 DefaultNodeGene(key=7331, bias=1.1799856376745361, response=1.0, activation=tanh3, aggregation=sum)
# 	7386 DefaultNodeGene(key=7386, bias=-2.0088466030992755, response=1.0, activation=tanh3, aggregation=sum)
# 	7631 DefaultNodeGene(key=7631, bias=0.6143952632292591, response=1.0, activation=tanh3, aggregation=sum)
# 	7820 DefaultNodeGene(key=7820, bias=-0.388379981290799, response=1.0, activation=tanh3, aggregation=sum)
# 	7894 DefaultNodeGene(key=7894, bias=0.5273955195868905, response=1.0, activation=tanh3, aggregation=sum)
# 	8111 DefaultNodeGene(key=8111, bias=-0.041971419819814365, response=1.0, activation=tanh3, aggregation=sum)
# 	8300 DefaultNodeGene(key=8300, bias=0.4778515624959622, response=1.0, activation=tanh3, aggregation=sum)
# 	8461 DefaultNodeGene(key=8461, bias=-4.20463319695085, response=1.0, activation=tanh3, aggregation=sum)
# 	8625 DefaultNodeGene(key=8625, bias=-0.512052284663777, response=1.0, activation=tanh3, aggregation=sum)
# 	8633 DefaultNodeGene(key=8633, bias=-0.2588613858714189, response=1.0, activation=tanh3, aggregation=sum)
# 	8644 DefaultNodeGene(key=8644, bias=0.9319121444416079, response=1.0, activation=tanh3, aggregation=sum)
# 	8653 DefaultNodeGene(key=8653, bias=0.21739068980331042, response=1.0, activation=tanh3, aggregation=sum)
# 	8879 DefaultNodeGene(key=8879, bias=-1.4883631285819656, response=1.0, activation=tanh3, aggregation=sum)
# 	8940 DefaultNodeGene(key=8940, bias=-0.20940611631427608, response=1.0, activation=tanh3, aggregation=sum)
# 	9097 DefaultNodeGene(key=9097, bias=-0.9047708564977892, response=1.0, activation=tanh3, aggregation=sum)
# 	9315 DefaultNodeGene(key=9315, bias=-0.22796795227907352, response=1.0, activation=tanh3, aggregation=sum)
# 	9350 DefaultNodeGene(key=9350, bias=-0.5891538786456497, response=1.0, activation=tanh3, aggregation=sum)
# 	9366 DefaultNodeGene(key=9366, bias=-0.30044794521737794, response=1.0, activation=tanh3, aggregation=sum)
# 	9427 DefaultNodeGene(key=9427, bias=-1.1981631641773363, response=1.0, activation=tanh3, aggregation=sum)
# 	9452 DefaultNodeGene(key=9452, bias=-0.037427134718355515, response=1.0, activation=tanh3, aggregation=sum)
# 	9490 DefaultNodeGene(key=9490, bias=-0.16387154774078205, response=1.0, activation=tanh3, aggregation=sum)
# 	9507 DefaultNodeGene(key=9507, bias=-3.208620467550357, response=1.0, activation=tanh3, aggregation=sum)
# 	9590 DefaultNodeGene(key=9590, bias=-0.5972108644797812, response=1.0, activation=tanh3, aggregation=sum)
# 	9599 DefaultNodeGene(key=9599, bias=3.3306622938565877, response=1.0, activation=tanh3, aggregation=sum)
# 	9666 DefaultNodeGene(key=9666, bias=1.0638211855230173, response=1.0, activation=tanh3, aggregation=sum)
# 	9715 DefaultNodeGene(key=9715, bias=-0.5616614895142943, response=1.0, activation=tanh3, aggregation=sum)
# 	9791 DefaultNodeGene(key=9791, bias=0.09758924019237224, response=1.0, activation=tanh3, aggregation=sum)
# 	9809 DefaultNodeGene(key=9809, bias=-0.8601791738263576, response=1.0, activation=tanh3, aggregation=sum)
# 	10203 DefaultNodeGene(key=10203, bias=0.4157212734149363, response=1.0, activation=tanh3, aggregation=sum)
# 	10384 DefaultNodeGene(key=10384, bias=1.231936894153614, response=1.0, activation=tanh3, aggregation=sum)
# 	10406 DefaultNodeGene(key=10406, bias=1.0804437884163756, response=1.0, activation=tanh3, aggregation=sum)
# 	10438 DefaultNodeGene(key=10438, bias=-0.9632315947878172, response=1.0, activation=tanh3, aggregation=sum)
# 	10446 DefaultNodeGene(key=10446, bias=1.859043530049062, response=1.0, activation=tanh3, aggregation=sum)
# 	10477 DefaultNodeGene(key=10477, bias=-0.37432649542410457, response=1.0, activation=tanh3, aggregation=sum)
# 	10488 DefaultNodeGene(key=10488, bias=0.18707496797304415, response=1.0, activation=tanh3, aggregation=sum)
# 	10726 DefaultNodeGene(key=10726, bias=-1.583693301642335, response=1.0, activation=tanh3, aggregation=sum)
# 	10803 DefaultNodeGene(key=10803, bias=-0.5653992293496033, response=1.0, activation=tanh3, aggregation=sum)
# 	10832 DefaultNodeGene(key=10832, bias=0.45114533517586897, response=1.0, activation=tanh3, aggregation=sum)
# 	10948 DefaultNodeGene(key=10948, bias=-2.617642901172057, response=1.0, activation=tanh3, aggregation=sum)
# 	11033 DefaultNodeGene(key=11033, bias=0.753868601423815, response=1.0, activation=tanh3, aggregation=sum)
# 	11330 DefaultNodeGene(key=11330, bias=-0.39351923377202236, response=1.0, activation=tanh3, aggregation=sum)
# 	11365 DefaultNodeGene(key=11365, bias=1.6351329043769067, response=1.0, activation=tanh3, aggregation=sum)
# 	11370 DefaultNodeGene(key=11370, bias=1.6626781828321606, response=1.0, activation=tanh3, aggregation=sum)
# 	11407 DefaultNodeGene(key=11407, bias=-1.138464347644701, response=1.0, activation=tanh3, aggregation=sum)
# 	11478 DefaultNodeGene(key=11478, bias=-0.40473639848600973, response=1.0, activation=tanh3, aggregation=sum)
# 	11496 DefaultNodeGene(key=11496, bias=0.837034985851465, response=1.0, activation=tanh3, aggregation=sum)
# 	11775 DefaultNodeGene(key=11775, bias=-0.5650721633010878, response=1.0, activation=tanh3, aggregation=sum)
# 	11877 DefaultNodeGene(key=11877, bias=0.8302706303021885, response=1.0, activation=tanh3, aggregation=sum)
# 	11980 DefaultNodeGene(key=11980, bias=1.723950237789793, response=1.0, activation=tanh3, aggregation=sum)
# 	12320 DefaultNodeGene(key=12320, bias=0.9057331548826673, response=1.0, activation=tanh3, aggregation=sum)
# 	12450 DefaultNodeGene(key=12450, bias=-0.32664660656829264, response=1.0, activation=tanh3, aggregation=sum)
# 	12464 DefaultNodeGene(key=12464, bias=-1.4269758698884718, response=1.0, activation=tanh3, aggregation=sum)
# 	12500 DefaultNodeGene(key=12500, bias=0.7524700731989289, response=1.0, activation=tanh3, aggregation=sum)
# 	12573 DefaultNodeGene(key=12573, bias=-0.5361316500057365, response=1.0, activation=tanh3, aggregation=sum)
# 	12674 DefaultNodeGene(key=12674, bias=3.961291996743409, response=1.0, activation=tanh3, aggregation=sum)
# 	12862 DefaultNodeGene(key=12862, bias=-0.8296277410536623, response=1.0, activation=tanh3, aggregation=sum)
# 	12986 DefaultNodeGene(key=12986, bias=1.2308150970443719, response=1.0, activation=tanh3, aggregation=sum)
# 	13051 DefaultNodeGene(key=13051, bias=-3.0324615259720615, response=1.0, activation=tanh3, aggregation=sum)
# 	13137 DefaultNodeGene(key=13137, bias=1.7211234156934145, response=1.0, activation=tanh3, aggregation=sum)
# 	13177 DefaultNodeGene(key=13177, bias=0.5126821221817912, response=1.0, activation=tanh3, aggregation=sum)
# 	13381 DefaultNodeGene(key=13381, bias=1.1280091818459717, response=1.0, activation=tanh3, aggregation=sum)
# 	13385 DefaultNodeGene(key=13385, bias=0.05425619628227907, response=1.0, activation=tanh3, aggregation=sum)
# 	13464 DefaultNodeGene(key=13464, bias=-0.4218577547805641, response=1.0, activation=tanh3, aggregation=sum)
# 	13474 DefaultNodeGene(key=13474, bias=-1.7684140722730066, response=1.0, activation=tanh3, aggregation=sum)
# 	13589 DefaultNodeGene(key=13589, bias=0.9603748455625938, response=1.0, activation=tanh3, aggregation=sum)
# 	13729 DefaultNodeGene(key=13729, bias=-0.690198637981924, response=1.0, activation=tanh3, aggregation=sum)
# 	13884 DefaultNodeGene(key=13884, bias=-0.10927919642822692, response=1.0, activation=tanh3, aggregation=sum)
# 	13975 DefaultNodeGene(key=13975, bias=-2.5588582596682268, response=1.0, activation=tanh3, aggregation=sum)
# 	14147 DefaultNodeGene(key=14147, bias=1.196014052559918, response=1.0, activation=tanh3, aggregation=sum)
# 	14178 DefaultNodeGene(key=14178, bias=0.4689248301789535, response=1.0, activation=tanh3, aggregation=sum)
# 	14383 DefaultNodeGene(key=14383, bias=1.5708419027372784, response=1.0, activation=tanh3, aggregation=sum)
# 	14491 DefaultNodeGene(key=14491, bias=0.01817001734316606, response=1.0, activation=tanh3, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-12, 1), weight=1.135349013427918, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=-0.38081448495089076, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=2.0545687996463826, enabled=True)
# 	DefaultConnectionGene(key=(-12, 7223), weight=3.6950256498021306, enabled=True)
# 	DefaultConnectionGene(key=(-12, 7631), weight=2.8531341809808053, enabled=True)
# 	DefaultConnectionGene(key=(-12, 11496), weight=3.1863597198200453, enabled=True)
# 	DefaultConnectionGene(key=(-12, 12464), weight=-2.6039223906911024, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=9.411672045602126, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=-0.5667471507822724, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2295), weight=0.8673097701083193, enabled=False)
# 	DefaultConnectionGene(key=(-11, 7894), weight=-2.243370138822838, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=0.0769800021702077, enabled=False)
# 	DefaultConnectionGene(key=(-8, 3459), weight=0.4296154232499873, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3584), weight=1.3314350044015755, enabled=False)
# 	DefaultConnectionGene(key=(-8, 5845), weight=1.3627417847133296, enabled=False)
# 	DefaultConnectionGene(key=(-8, 6345), weight=0.0871276812627413, enabled=True)
# 	DefaultConnectionGene(key=(-8, 7386), weight=-2.3877098605456646, enabled=True)
# 	DefaultConnectionGene(key=(-8, 8633), weight=2.900369656768916, enabled=False)
# 	DefaultConnectionGene(key=(-8, 9490), weight=0.7126909307078331, enabled=False)
# 	DefaultConnectionGene(key=(-8, 10803), weight=-0.030717173646445495, enabled=False)
# 	DefaultConnectionGene(key=(-8, 11033), weight=-0.0474909021121679, enabled=True)
# 	DefaultConnectionGene(key=(-8, 11365), weight=1.7442065492796621, enabled=False)
# 	DefaultConnectionGene(key=(-8, 11980), weight=2.3328872246778682, enabled=True)
# 	DefaultConnectionGene(key=(-8, 12450), weight=1.2381292788826939, enabled=False)
# 	DefaultConnectionGene(key=(-8, 13474), weight=1.823610540003477, enabled=False)
# 	DefaultConnectionGene(key=(-7, 5101), weight=0.18473096054801355, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=0.37203456994156814, enabled=True)
# 	DefaultConnectionGene(key=(-6, 3584), weight=1.826869049389991, enabled=False)
# 	DefaultConnectionGene(key=(-6, 4237), weight=2.521424338377134, enabled=True)
# 	DefaultConnectionGene(key=(-6, 8300), weight=0.007934577973622403, enabled=False)
# 	DefaultConnectionGene(key=(-6, 9427), weight=2.7727774181123785, enabled=False)
# 	DefaultConnectionGene(key=(-6, 10406), weight=-1.8470522174136847, enabled=False)
# 	DefaultConnectionGene(key=(-6, 10832), weight=3.876807200764225, enabled=False)
# 	DefaultConnectionGene(key=(-5, 4686), weight=-1.5518670555131409, enabled=True)
# 	DefaultConnectionGene(key=(-5, 5845), weight=-0.6421471961110952, enabled=False)
# 	DefaultConnectionGene(key=(-5, 8111), weight=-1.3906544104957086, enabled=False)
# 	DefaultConnectionGene(key=(-4, 3193), weight=0.794231433808209, enabled=True)
# 	DefaultConnectionGene(key=(-4, 5679), weight=-1.9016682930832587, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=0.26204750004119215, enabled=False)
# 	DefaultConnectionGene(key=(-2, 0), weight=2.77550973592819, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2295), weight=-3.320702938738714, enabled=False)
# 	DefaultConnectionGene(key=(-2, 5679), weight=1.247201328495704, enabled=True)
# 	DefaultConnectionGene(key=(-2, 7104), weight=4.91596277906396, enabled=True)
# 	DefaultConnectionGene(key=(-2, 12320), weight=0.1755623759757435, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.607458078961101, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=2.295956930844058, enabled=False)
# 	DefaultConnectionGene(key=(-1, 1293), weight=-0.7443138935281753, enabled=False)
# 	DefaultConnectionGene(key=(-1, 5845), weight=1.1718485397062202, enabled=False)
# 	DefaultConnectionGene(key=(-1, 8644), weight=-1.043270463550178, enabled=True)
# 	DefaultConnectionGene(key=(-1, 10384), weight=4.695503748230221, enabled=True)
# 	DefaultConnectionGene(key=(-1, 13884), weight=-1.2389798028823342, enabled=True)
# 	DefaultConnectionGene(key=(-1, 14491), weight=1.9572207319516357, enabled=False)
# 	DefaultConnectionGene(key=(1, 240), weight=6.617795804003605, enabled=True)
# 	DefaultConnectionGene(key=(1, 9315), weight=-0.2457515364923091, enabled=False)
# 	DefaultConnectionGene(key=(1, 9490), weight=-0.3396398093932261, enabled=True)
# 	DefaultConnectionGene(key=(1, 12674), weight=0.6307367493560686, enabled=True)
# 	DefaultConnectionGene(key=(2, 4082), weight=0.5988262555662444, enabled=True)
# 	DefaultConnectionGene(key=(3, 3459), weight=-1.212059905845741, enabled=True)
# 	DefaultConnectionGene(key=(3, 4686), weight=0.9528560566789308, enabled=False)
# 	DefaultConnectionGene(key=(240, 1), weight=9.13402297928578, enabled=True)
# 	DefaultConnectionGene(key=(240, 3), weight=-3.719688872114941, enabled=False)
# 	DefaultConnectionGene(key=(240, 9350), weight=3.6912675807229878, enabled=True)
# 	DefaultConnectionGene(key=(240, 10203), weight=1.1950329836275149, enabled=False)
# 	DefaultConnectionGene(key=(240, 10488), weight=-3.2683356370443417, enabled=True)
# 	DefaultConnectionGene(key=(1293, 3584), weight=0.403164311171893, enabled=False)
# 	DefaultConnectionGene(key=(1293, 13589), weight=5.246564349329554, enabled=True)
# 	DefaultConnectionGene(key=(2295, 3921), weight=2.4185611021336815, enabled=False)
# 	DefaultConnectionGene(key=(2295, 6350), weight=-1.971445802918566, enabled=True)
# 	DefaultConnectionGene(key=(3193, 1), weight=-4.559438854465407, enabled=False)
# 	DefaultConnectionGene(key=(3459, 1293), weight=-1.134901902447846, enabled=True)
# 	DefaultConnectionGene(key=(3459, 4237), weight=3.8580232269635553, enabled=True)
# 	DefaultConnectionGene(key=(3459, 6622), weight=0.6564782574003102, enabled=False)
# 	DefaultConnectionGene(key=(3459, 12862), weight=-1.0503032622947448, enabled=True)
# 	DefaultConnectionGene(key=(3459, 13381), weight=-0.09046663404494151, enabled=True)
# 	DefaultConnectionGene(key=(3584, 1), weight=4.617878566456503, enabled=True)
# 	DefaultConnectionGene(key=(3584, 4082), weight=1.2189119120765264, enabled=True)
# 	DefaultConnectionGene(key=(3883, 4686), weight=3.231461253560102, enabled=True)
# 	DefaultConnectionGene(key=(3883, 6909), weight=-0.2566958132597691, enabled=False)
# 	DefaultConnectionGene(key=(3921, 4082), weight=-3.3864583830857025, enabled=True)
# 	DefaultConnectionGene(key=(4082, 1293), weight=0.5321197957528936, enabled=False)
# 	DefaultConnectionGene(key=(4082, 5932), weight=4.459909759365194, enabled=False)
# 	DefaultConnectionGene(key=(4082, 9590), weight=2.4592824040521517, enabled=True)
# 	DefaultConnectionGene(key=(4082, 9791), weight=-0.03019210503832523, enabled=True)
# 	DefaultConnectionGene(key=(4082, 13464), weight=0.5628035956198807, enabled=True)
# 	DefaultConnectionGene(key=(4165, 1293), weight=-0.5793151854275799, enabled=False)
# 	DefaultConnectionGene(key=(4165, 5258), weight=-1.649060425750925, enabled=False)
# 	DefaultConnectionGene(key=(4382, 1), weight=0.7987387648793227, enabled=True)
# 	DefaultConnectionGene(key=(4382, 5101), weight=-0.14586485116327835, enabled=True)
# 	DefaultConnectionGene(key=(4432, 1), weight=1.6508648461783553, enabled=False)
# 	DefaultConnectionGene(key=(4432, 3584), weight=1.125988352788654, enabled=True)
# 	DefaultConnectionGene(key=(4686, 3883), weight=4.731301066368011, enabled=True)
# 	DefaultConnectionGene(key=(4686, 6509), weight=1.3005614703557706, enabled=True)
# 	DefaultConnectionGene(key=(4686, 10477), weight=2.0673864833591815, enabled=True)
# 	DefaultConnectionGene(key=(5101, 3), weight=1.6012786541681912, enabled=False)
# 	DefaultConnectionGene(key=(5101, 5293), weight=-0.23358464405614537, enabled=False)
# 	DefaultConnectionGene(key=(5101, 5505), weight=-0.13786069609966206, enabled=True)
# 	DefaultConnectionGene(key=(5258, 1293), weight=1.3287050547517523, enabled=False)
# 	DefaultConnectionGene(key=(5258, 5514), weight=-0.09399873021558373, enabled=True)
# 	DefaultConnectionGene(key=(5258, 7073), weight=-0.8245069611253476, enabled=True)
# 	DefaultConnectionGene(key=(5258, 11980), weight=1.4829924479969798, enabled=False)
# 	DefaultConnectionGene(key=(5258, 12500), weight=0.3974561004198906, enabled=False)
# 	DefaultConnectionGene(key=(5293, 1293), weight=1.284718334924464, enabled=True)
# 	DefaultConnectionGene(key=(5293, 6345), weight=0.022439522661395556, enabled=True)
# 	DefaultConnectionGene(key=(5293, 13385), weight=-1.689640152028322, enabled=True)
# 	DefaultConnectionGene(key=(5505, 4165), weight=1.7242678388670567, enabled=True)
# 	DefaultConnectionGene(key=(5514, 4686), weight=-0.2694244852889859, enabled=False)
# 	DefaultConnectionGene(key=(5679, 1), weight=-0.23968904655838535, enabled=False)
# 	DefaultConnectionGene(key=(5679, 3459), weight=-0.653985035291081, enabled=True)
# 	DefaultConnectionGene(key=(5679, 9599), weight=-0.22576298342278064, enabled=True)
# 	DefaultConnectionGene(key=(5679, 11370), weight=-0.7331601410768257, enabled=True)
# 	DefaultConnectionGene(key=(5679, 13137), weight=-2.285423573099486, enabled=False)
# 	DefaultConnectionGene(key=(5679, 13177), weight=0.28522642880006255, enabled=False)
# 	DefaultConnectionGene(key=(5845, 3459), weight=0.3004119633119668, enabled=True)
# 	DefaultConnectionGene(key=(6345, 7331), weight=-1.5434985489993327, enabled=True)
# 	DefaultConnectionGene(key=(6350, 3883), weight=-0.7944163801147507, enabled=False)
# 	DefaultConnectionGene(key=(6350, 9715), weight=2.8886672108056355, enabled=True)
# 	DefaultConnectionGene(key=(6509, 3883), weight=-1.1721675172156085, enabled=False)
# 	DefaultConnectionGene(key=(6509, 10406), weight=-0.8683507167828094, enabled=False)
# 	DefaultConnectionGene(key=(6535, 7631), weight=-3.703250310091116, enabled=True)
# 	DefaultConnectionGene(key=(6622, 1293), weight=2.901404443548767, enabled=True)
# 	DefaultConnectionGene(key=(6622, 7122), weight=-0.7771859934892136, enabled=True)
# 	DefaultConnectionGene(key=(6785, 8653), weight=2.1751495367819427, enabled=False)
# 	DefaultConnectionGene(key=(6835, 4165), weight=1.3907935854095526, enabled=True)
# 	DefaultConnectionGene(key=(6835, 4686), weight=0.4263545515543011, enabled=True)
# 	DefaultConnectionGene(key=(6835, 8940), weight=0.9048733740044105, enabled=True)
# 	DefaultConnectionGene(key=(6894, 240), weight=1.018993482690606, enabled=True)
# 	DefaultConnectionGene(key=(6894, 4237), weight=-1.5483997983788045, enabled=True)
# 	DefaultConnectionGene(key=(6894, 9507), weight=4.595806046013889, enabled=False)
# 	DefaultConnectionGene(key=(7073, 7122), weight=-0.3106318735439597, enabled=True)
# 	DefaultConnectionGene(key=(7104, 4686), weight=0.2638197103493414, enabled=True)
# 	DefaultConnectionGene(key=(7104, 5679), weight=-0.3237440333812333, enabled=True)
# 	DefaultConnectionGene(key=(7104, 7631), weight=-0.35447637009537447, enabled=False)
# 	DefaultConnectionGene(key=(7104, 14383), weight=0.34869483111843114, enabled=True)
# 	DefaultConnectionGene(key=(7122, 1293), weight=-0.1596591134533234, enabled=False)
# 	DefaultConnectionGene(key=(7136, 1), weight=-0.5562831270002003, enabled=True)
# 	DefaultConnectionGene(key=(7223, 3), weight=2.2774703819076727, enabled=True)
# 	DefaultConnectionGene(key=(7331, 1), weight=5.1144274855304, enabled=False)
# 	DefaultConnectionGene(key=(7331, 6894), weight=0.6916519143443514, enabled=True)
# 	DefaultConnectionGene(key=(7331, 6909), weight=-2.0979290237930712, enabled=True)
# 	DefaultConnectionGene(key=(7331, 10446), weight=0.03282116240902472, enabled=False)
# 	DefaultConnectionGene(key=(7386, 1), weight=2.1814864698274095, enabled=True)
# 	DefaultConnectionGene(key=(7631, 7223), weight=5.026973623974644, enabled=True)
# 	DefaultConnectionGene(key=(7631, 9097), weight=1.3099883348062962, enabled=False)
# 	DefaultConnectionGene(key=(7820, 240), weight=1.6012903057086771, enabled=True)
# 	DefaultConnectionGene(key=(7820, 10203), weight=1.3246172888596595, enabled=True)
# 	DefaultConnectionGene(key=(7894, 2), weight=0.6342310071361978, enabled=True)
# 	DefaultConnectionGene(key=(7894, 8111), weight=-1.730428625381906, enabled=False)
# 	DefaultConnectionGene(key=(7894, 8461), weight=3.2341913108645644, enabled=True)
# 	DefaultConnectionGene(key=(8111, 2), weight=-1.465160338942956, enabled=True)
# 	DefaultConnectionGene(key=(8461, 2), weight=-0.25970641942777384, enabled=False)
# 	DefaultConnectionGene(key=(8633, 7122), weight=2.6388256118100246, enabled=True)
# 	DefaultConnectionGene(key=(8633, 9666), weight=-1.4544576555479054, enabled=True)
# 	DefaultConnectionGene(key=(8644, 1293), weight=-1.0603058924574, enabled=False)
# 	DefaultConnectionGene(key=(8644, 5514), weight=-1.741503741896667, enabled=False)
# 	DefaultConnectionGene(key=(8644, 8644), weight=1.4442515725903693, enabled=False)
# 	DefaultConnectionGene(key=(8940, 4165), weight=-1.2270032526973171, enabled=False)
# 	DefaultConnectionGene(key=(8940, 6345), weight=1.9849108890123157, enabled=True)
# 	DefaultConnectionGene(key=(8940, 6894), weight=-0.5345549692184296, enabled=True)
# 	DefaultConnectionGene(key=(9097, 7223), weight=-0.9811906172806706, enabled=False)
# 	DefaultConnectionGene(key=(9097, 7631), weight=-2.9466732080890874, enabled=True)
# 	DefaultConnectionGene(key=(9350, 4432), weight=1.3367971787412372, enabled=False)
# 	DefaultConnectionGene(key=(9350, 5101), weight=0.9288917847834988, enabled=True)
# 	DefaultConnectionGene(key=(9350, 11330), weight=1.4576924310138415, enabled=True)
# 	DefaultConnectionGene(key=(9350, 14147), weight=0.9956778916860574, enabled=True)
# 	DefaultConnectionGene(key=(9366, 5101), weight=2.10613971281304, enabled=True)
# 	DefaultConnectionGene(key=(9452, 4432), weight=1.9650705356012101, enabled=True)
# 	DefaultConnectionGene(key=(9490, 7073), weight=0.1646929424403608, enabled=False)
# 	DefaultConnectionGene(key=(9490, 11330), weight=2.135164890926114, enabled=True)
# 	DefaultConnectionGene(key=(9590, 5932), weight=-4.1906867697019665, enabled=True)
# 	DefaultConnectionGene(key=(9590, 11775), weight=-2.3387181879202443, enabled=True)
# 	DefaultConnectionGene(key=(9590, 13729), weight=0.5029800477438866, enabled=True)
# 	DefaultConnectionGene(key=(9599, 3459), weight=0.4110823046973572, enabled=False)
# 	DefaultConnectionGene(key=(9599, 7894), weight=-0.8256852872240117, enabled=True)
# 	DefaultConnectionGene(key=(9666, 2295), weight=3.077990035186543, enabled=True)
# 	DefaultConnectionGene(key=(9666, 5679), weight=0.6057076825560023, enabled=True)
# 	DefaultConnectionGene(key=(9666, 6622), weight=2.087330103501888, enabled=False)
# 	DefaultConnectionGene(key=(9666, 9097), weight=-2.479135976564584, enabled=True)
# 	DefaultConnectionGene(key=(9666, 14178), weight=0.9758987286450287, enabled=True)
# 	DefaultConnectionGene(key=(9715, 3883), weight=0.6433643557151378, enabled=False)
# 	DefaultConnectionGene(key=(9809, 1293), weight=-0.9819037492301087, enabled=False)
# 	DefaultConnectionGene(key=(10203, 4432), weight=1.3772984316609234, enabled=True)
# 	DefaultConnectionGene(key=(10203, 10438), weight=-0.7497839786048921, enabled=False)
# 	DefaultConnectionGene(key=(10203, 12986), weight=-1.698344561162397, enabled=True)
# 	DefaultConnectionGene(key=(10384, 1293), weight=0.02491882433126018, enabled=False)
# 	DefaultConnectionGene(key=(10406, 7136), weight=-0.14418338650617155, enabled=True)
# 	DefaultConnectionGene(key=(10438, 1293), weight=0.026169512229158143, enabled=True)
# 	DefaultConnectionGene(key=(10446, 6894), weight=1.7248382173652923, enabled=True)
# 	DefaultConnectionGene(key=(10477, 6509), weight=2.4247980612213027, enabled=False)
# 	DefaultConnectionGene(key=(10488, 3), weight=-1.8038761993161612, enabled=True)
# 	DefaultConnectionGene(key=(10726, 2295), weight=0.957552329077815, enabled=False)
# 	DefaultConnectionGene(key=(10726, 11478), weight=1.1502942246913521, enabled=False)
# 	DefaultConnectionGene(key=(10726, 11877), weight=0.8485834609157861, enabled=False)
# 	DefaultConnectionGene(key=(10803, 6345), weight=1.129893730987842, enabled=True)
# 	DefaultConnectionGene(key=(10803, 6785), weight=-1.4141528151058744, enabled=True)
# 	DefaultConnectionGene(key=(10803, 7073), weight=-4.687189552135016, enabled=False)
# 	DefaultConnectionGene(key=(10832, 5514), weight=-3.39620432313615, enabled=False)
# 	DefaultConnectionGene(key=(10832, 6883), weight=1.1465076733745485, enabled=True)
# 	DefaultConnectionGene(key=(10948, 3584), weight=-1.6723872800389707, enabled=False)
# 	DefaultConnectionGene(key=(11033, 7386), weight=-0.15961785922433575, enabled=False)
# 	DefaultConnectionGene(key=(11033, 9666), weight=-1.9939746944408838, enabled=False)
# 	DefaultConnectionGene(key=(11330, 12862), weight=1.0539538884916153, enabled=True)
# 	DefaultConnectionGene(key=(11365, 6345), weight=-0.8833602536377344, enabled=False)
# 	DefaultConnectionGene(key=(11370, 1), weight=3.642198242432949, enabled=False)
# 	DefaultConnectionGene(key=(11407, 1293), weight=1.680753335436619, enabled=False)
# 	DefaultConnectionGene(key=(11478, 2295), weight=-1.5568271395159128, enabled=True)
# 	DefaultConnectionGene(key=(11496, 7223), weight=-0.02605359399324736, enabled=True)
# 	DefaultConnectionGene(key=(11775, 5932), weight=-3.6555643446865966, enabled=False)
# 	DefaultConnectionGene(key=(11877, 2295), weight=1.0779935840114774, enabled=True)
# 	DefaultConnectionGene(key=(11980, 1293), weight=-0.13669701793330796, enabled=False)
# 	DefaultConnectionGene(key=(12320, 5679), weight=-1.1240320707872251, enabled=False)
# 	DefaultConnectionGene(key=(12320, 12674), weight=0.0171617910948427, enabled=True)
# 	DefaultConnectionGene(key=(12450, 11365), weight=-2.1444254531154905, enabled=False)
# 	DefaultConnectionGene(key=(12500, 5514), weight=0.31811344664001173, enabled=False)
# 	DefaultConnectionGene(key=(12500, 13975), weight=-0.8311856747882894, enabled=False)
# 	DefaultConnectionGene(key=(12573, 5101), weight=-1.0403092290526585, enabled=True)
# 	DefaultConnectionGene(key=(12674, 9490), weight=0.015735121934885965, enabled=True)
# 	DefaultConnectionGene(key=(12674, 13137), weight=-5.283477293506835, enabled=True)
# 	DefaultConnectionGene(key=(12862, 6622), weight=1.6623240198438078, enabled=False)
# 	DefaultConnectionGene(key=(12862, 13051), weight=4.093722106453789, enabled=False)
# 	DefaultConnectionGene(key=(12986, 10438), weight=-2.162462381774594, enabled=False)
# 	DefaultConnectionGene(key=(12986, 10948), weight=-0.1757601205907582, enabled=True)
# 	DefaultConnectionGene(key=(13051, 6622), weight=0.8961994271853183, enabled=True)
# 	DefaultConnectionGene(key=(13137, 6909), weight=-0.9171891876685959, enabled=True)
# 	DefaultConnectionGene(key=(13137, 11370), weight=0.911253187581654, enabled=True)
# 	DefaultConnectionGene(key=(13177, 1), weight=-0.01900706507826204, enabled=True)
# 	DefaultConnectionGene(key=(13381, 4237), weight=-0.7379805653426141, enabled=True)
# 	DefaultConnectionGene(key=(13385, 1293), weight=3.762596496600703, enabled=True)
# 	DefaultConnectionGene(key=(13464, 1293), weight=-0.8844131411461135, enabled=False)
# 	DefaultConnectionGene(key=(13474, 12450), weight=-1.3816796474350692, enabled=True)
# 	DefaultConnectionGene(key=(13589, 3584), weight=1.8113784039183476, enabled=True)
# 	DefaultConnectionGene(key=(13729, 5932), weight=-2.2279855537147504, enabled=True)
# 	DefaultConnectionGene(key=(13884, 1293), weight=0.11220282675267611, enabled=True)
# 	DefaultConnectionGene(key=(14147, 11330), weight=0.5024276380413468, enabled=False)
# 	DefaultConnectionGene(key=(14178, 6622), weight=1.139879151902722, enabled=True)
# 	DefaultConnectionGene(key=(14383, 7631), weight=3.665742487463864, enabled=True)
# 	DefaultConnectionGene(key=(14491, 5845), weight=1.12746930250415, enabled=True)
# 763.2730853557587
# Agent count: 1
# .
# 103.43
# 103.43005061149597
# Agent count: 1
# .
# 121.97
# 121.97125601768494
# Agent count: 1
# .
# 121.97
# 121.97125601768494
# Agent count: 1
# .
# 94.9
# 94.89952993392944
# Agent count: 1
# .
# 112.07
# 112.06976318359375
# Agent count: 1

# %%
env.close()
