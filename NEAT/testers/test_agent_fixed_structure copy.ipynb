# %%
import pickle
import numpy as np
import neat
import os
import keyboard

#from game_config import game_config
# MLAGENTS stuff
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
import neat
from random import choice, gauss, random, uniform, randint
from neat.genome import DefaultGenome
from neat.genes import DefaultNodeGene, DefaultConnectionGene
from neat.config import ConfigParameter, write_pretty_params
from neat.genes import BaseGene
from neat.attributes import FloatAttribute, BoolAttribute, StringAttribute, BaseAttribute
from neat.activations import ActivationFunctionSet
from neat.aggregations import AggregationFunctionSet
from itertools import count

class FixedFloatAttribute(BaseAttribute):
    """
    Class for floating-point numeric attributes,
    such as the response of a node or the weight of a connection.
    """
    _config_items = {"init_mean": [float, None],
                     "init_stdev": [float, None],
                     "init_type": [str, 'gaussian'],
                     "replace_rate": [float, None],
                     "mutate_rate": [float, None],
                     "mutate_power": [float, None],
                     "max_value": [float, None],
                     "min_value": [float, None]}

    def clamp(self, value, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        return max(min(value, max_value), min_value)

    def init_value(self, config):
        mean = getattr(config, self.init_mean_name)
        stdev = getattr(config, self.init_stdev_name)
        init_type = getattr(config, self.init_type_name).lower()

        if ('gauss' in init_type) or ('normal' in init_type):
            return self.clamp(gauss(mean, stdev), config)

        if 'uniform' in init_type:
            min_value = max(getattr(config, self.min_value_name),
                            (mean - (2 * stdev)))
            max_value = min(getattr(config, self.max_value_name),
                            (mean + (2 * stdev)))
            return uniform(min_value, max_value)

        raise RuntimeError(f"Unknown init_type {getattr(config, self.init_type_name)!r} for {self.init_type_name!s}")

    def mutate_value(self, value, config):
        # mutate_rate is usually no lower than replace_rate, and frequently higher -
        # so put first for efficiency
        mutate_rate = getattr(config, self.mutate_rate_name)
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        delta = choice([min_value / 10, max_value / 10])
        r = random()
        if r < mutate_rate:
            mutate_power = getattr(config, self.mutate_power_name)
            mutation = (2 * random() - 1) * delta
            return  self.clamp(value + mutation, config)

        replace_rate = getattr(config, self.replace_rate_name)

        r = random()
        if r < replace_rate:
            return self.init_value(config)

        return value

    def validate(self, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        if max_value < min_value:
            raise RuntimeError("Invalid min/max configuration for {self.name}")

class FixedStructureNodeGene(BaseGene):
    _gene_attributes = [
                        FixedFloatAttribute('bias'),
                        FloatAttribute('response'),
                        StringAttribute('activation', options=''),
                        StringAttribute('aggregation', options='')]

    def distance(self, other, config):
        return 0.0

class FixedStructureConnectionGene(BaseGene):
    _gene_attributes = [FixedFloatAttribute('weight'),
                        BoolAttribute('enabled')]

    def mutate(self, config):
        # Mutate only weights
        a = self._gene_attributes[0]
        v = getattr(self, a.name)
        setattr(self, a.name, a.mutate_value(v, config))

    def distance(self, other, config):
        d = abs(self.weight - other.weight)
        return d
    
class FixedStructureGenomeConfig(object):
    __params = [ConfigParameter('feed_forward', bool),
                ConfigParameter('num_inputs', int),
                ConfigParameter('num_outputs', int),
                ConfigParameter('num_hidden', int),
                ConfigParameter('num_hidden_layers', int),
                ConfigParameter('initial_connection', str, 'full_direct'),
                ConfigParameter('conn_add_prob', float),
                ConfigParameter('conn_delete_prob', float),
                ConfigParameter('node_add_prob', float),
                ConfigParameter('node_delete_prob', float)]


    def __init__(self, params):
        # Create full set of available activation functions.
        self.activation_defs = ActivationFunctionSet()
        self.activation_options = params.get('activation_options', 'sigmoid').strip().split()
        self.aggregation_options = params.get('aggregation_options', 'sum').strip().split()
        self.aggregation_function_defs = AggregationFunctionSet()

        # Gather configuration data from the gene classes.
        self.node_gene_type = params['node_gene_type']
        self.__params += self.node_gene_type.get_config_params()
        self.connection_gene_type = params['connection_gene_type']
        self.__params += self.connection_gene_type.get_config_params()
        self.connection_fraction = None
        self.node_indexer = None
        self.structural_mutation_surer = 'false'

        # Use the configuration data to interpret the supplied parameters.
        for p in self.__params:
            setattr(self, p.name, p.interpret(params))

        # By convention, input pins have negative keys, and the output
        # pins have keys 0,1,...
        self.input_keys = [-i - 1 for i in range(self.num_inputs)]
        self.output_keys = [i for i in range(self.num_outputs)]

    def get_new_node_key(self, node_dict):
        if self.node_indexer is None:
            if node_dict:
                self.node_indexer = count(max(list(node_dict)) + 1)
            else:
                self.node_indexer = count(max(list(node_dict)) + 1)

        new_id = next(self.node_indexer)

        assert new_id not in node_dict

        return new_id
    
    def save(self, f):
        write_pretty_params(f, self, self.__params)

class FixedStructureGenome(object):
    @classmethod
    def parse_config(cls, param_dict):
        param_dict['node_gene_type'] = FixedStructureNodeGene
        param_dict['connection_gene_type'] = FixedStructureConnectionGene
        return FixedStructureGenomeConfig(param_dict)
    
    @classmethod
    def write_config(cls, f, config):
        config.save(f)

    def __init__(self, key):
        self.key = key
        self.connections = {}
        self.nodes = {}

        # Fitness results.
        self.fitness = None

    def mutate(self, config):
        """ Mutates this genome. """
        # Mutate connection genes.
        for cg in self.connections.values():
            cg.mutate(config)

        # Mutate node genes (bias, response, etc.).
        for ng in self.nodes.values():
            ng.mutate(config)

    def configure_crossover(self, genome1, genome2, config):
        """ Configure a new genome by crossover from two parent genomes. """
        if genome1.fitness > genome2.fitness:
            parent1, parent2 = genome1, genome2
        else:
            parent1, parent2 = genome2, genome1

        # Inherit connection genes
        for key, cg1 in parent1.connections.items():
            cg2 = parent2.connections.get(key)
            if cg2 is None:
                # Excess or disjoint gene: copy from the fittest parent.
                self.connections[key] = cg1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.connections[key] = cg1.crossover(cg2)
            self.connections[key].enabled = True

        # Inherit node genes
        parent1_set = parent1.nodes
        parent2_set = parent2.nodes

        for key, ng1 in parent1_set.items():
            ng2 = parent2_set.get(key)
            assert key not in self.nodes
            if ng2 is None:
                # Extra gene: copy from the fittest parent
                self.nodes[key] = ng1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.nodes[key] = ng1.crossover(ng2)

    def distance(self, other, config):
        return 0.0
    
    def size(self):
        """Returns genome 'complexity', taken to be (number of nodes, number of enabled connections)"""
        num_enabled_connections = sum([1 for cg in self.connections.values() if cg.enabled is True])
        return len(self.nodes), num_enabled_connections

    def __str__(self):
        s = f"Key: {self.key}\nFitness: {self.fitness}\nNodes:"
        for k, ng in self.nodes.items():
            s += f"\n\t{k} {ng!s}"
        s += "\nConnections:"
        connections = list(self.connections.values())
        connections.sort()
        for c in connections:
            s += "\n\t" + str(c)
        return s

    def configure_new(self, config):
        # Create node genes for the input and output nodes
        for node_key in config.input_keys + config.output_keys:
            self.nodes[node_key] = self.create_node(config, node_key)

        # Initialize list to keep track of nodes in the last layer (start with input layer)
        last_layer_nodes = config.input_keys

        # Add hidden nodes and layers
        # config.num_hidden now represents the number of neurons PER HIDDEN LAYER
        if config.num_hidden > 0 and config.num_hidden_layers > 0:
            for _ in range(config.num_hidden_layers):
                layer_node_ids = []
                for _ in range(config.num_hidden):  # Create the specified number of nodes for this layer
                    node_key = config.get_new_node_key(self.nodes)
                    self.nodes[node_key] = self.create_node(config, node_key)
                    layer_node_ids.append(node_key)
                
                # Connect all nodes from the last layer to the current layer's nodes
                for last_layer_node in last_layer_nodes:
                    for current_layer_node in layer_node_ids:
                        connection = self.create_connection(config, last_layer_node, current_layer_node)
                        self.connections[connection.key] = connection

                # Update last_layer_nodes to reflect the current layer for next iteration
                last_layer_nodes = layer_node_ids

            # Connect all nodes from the last hidden layer to the output nodes
            for hidden_node_id in last_layer_nodes:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, hidden_node_id, output_node_id)
                    self.connections[connection.key] = connection
        else:
            # If there are no hidden layers, connect input nodes directly to output nodes
            for input_node_id in config.input_keys:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, input_node_id, output_node_id)
                    self.connections[connection.key] = connection

    @staticmethod
    def create_node(config, node_id):
        node = FixedStructureNodeGene(node_id)
        node.init_attributes(config)
        return node

    @staticmethod
    def create_connection(config, input_id, output_id):
        connection = config.connection_gene_type((input_id, output_id))
        connection.init_attributes(config)
        return connection

# %%
engine_config_channel = EngineConfigurationChannel()
from comunication_channel import AgentLogChannel
agent_count_channel = AgentLogChannel()
engine_config_channel.set_configuration_parameters(time_scale=0.1)

env_path = "../Builds/train-env/autonomous-drone.exe"

env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000002B2492A2AA0>
# Name of the behavior : ForestControl?team=0
# Number of observations :  5

# %%
# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# There are 4 continuous actions

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
set_agents_and_double_reset(2)

# %%
import time
import random
import math

def eval_agent(genome, cfg):
    i = 0
    send_array = [2, 1, 2]

    while True:
        policy = neat.nn.FeedForwardNetwork.create(genome, cfg)
        #policy = neat.nn.RecurrentNetwork.create(genome, cfg)
        set_agents_and_double_reset(random.randint(1, 1))
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        agent_count = len(decision_steps.agent_id)
        policies = [policy] * agent_count

        unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

        done = False  # Vectorized initialization
        removed_agents = []

        episode_rewards = [0] * agent_count
        print(f"Agent count: {agent_count}")
        while not done:
            # if keyboard.is_pressed('q'):  # Check if 'q' is pressed
            #     env.close()
            #     return
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    obs = np.concatenate(decision_steps[agent].obs[:])
                    nn_input =  np.asarray(obs)
                    #print(f"{agent} {nn_input}")
                    actions = policies[unity_to_neat_map[agent]].activate(nn_input)
                    print(f"{agent} {actions}")
                    #actions = [0, 0, 0, 0]
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)

                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward                             
            if len(removed_agents) >= agent_count:
                print(".") 
                done = True
        print(round(max(episode_rewards), 2))
        for reward in episode_rewards:
            print(reward)
        #while keyboard.is_pressed('c') == False:
        #    time.sleep(0.1)

# %%
save_nn_destination = '../result/best.pkl'

with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    genome = genome[1]
    print(genome)
print(genome.fitness)
config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    '../configs/config_fixed_forest')

eval_agent(genome, config)
# Out:
# Key: 2366
# Fitness: 0.9995000890921801
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.0, response=0.1, activation=clamped, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.0, response=0.1, activation=clamped, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.0, response=0.1, activation=clamped, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.0, response=0.1, activation=clamped, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-76, 0), weight=-0.1687892511046415, enabled=True)
# 	DefaultConnectionGene(key=(-76, 1), weight=-0.636396671094458, enabled=True)
# 	DefaultConnectionGene(key=(-76, 2), weight=-0.3548737387953247, enabled=True)
# 	DefaultConnectionGene(key=(-76, 3), weight=1.1889137214541312, enabled=True)
# 	DefaultConnectionGene(key=(-75, 0), weight=0.02434605150134456, enabled=True)
# 	DefaultConnectionGene(key=(-75, 1), weight=0.3905287970359391, enabled=True)
# 	DefaultConnectionGene(key=(-75, 2), weight=0.09316242143521511, enabled=True)
# 	DefaultConnectionGene(key=(-75, 3), weight=-0.1169423762301123, enabled=True)
# 	DefaultConnectionGene(key=(-74, 0), weight=0.38877697153711455, enabled=True)
# 	DefaultConnectionGene(key=(-74, 1), weight=-0.21628820539460275, enabled=True)
# 	DefaultConnectionGene(key=(-74, 2), weight=0.6336491648379429, enabled=True)
# 	DefaultConnectionGene(key=(-74, 3), weight=0.16082102248310978, enabled=True)
# 	DefaultConnectionGene(key=(-73, 0), weight=-0.2119579384371849, enabled=True)
# 	DefaultConnectionGene(key=(-73, 1), weight=-0.9030697929692286, enabled=True)
# 	DefaultConnectionGene(key=(-73, 2), weight=-0.3597753237945569, enabled=True)
# 	DefaultConnectionGene(key=(-73, 3), weight=0.3295832124058729, enabled=True)
# 	DefaultConnectionGene(key=(-72, 0), weight=-0.05102490349244862, enabled=True)
# 	DefaultConnectionGene(key=(-72, 2), weight=1.1997729216076976, enabled=True)
# 	DefaultConnectionGene(key=(-72, 3), weight=0.011755070221812026, enabled=True)
# 	DefaultConnectionGene(key=(-71, 0), weight=-0.03138855624146475, enabled=True)
# 	DefaultConnectionGene(key=(-71, 1), weight=-0.25155295368468933, enabled=False)
# 	DefaultConnectionGene(key=(-71, 2), weight=0.6225504140523238, enabled=True)
# 	DefaultConnectionGene(key=(-71, 3), weight=1.2095551190639906, enabled=True)
# 	DefaultConnectionGene(key=(-70, 0), weight=0.05855796471392696, enabled=False)
# 	DefaultConnectionGene(key=(-70, 1), weight=0.4585443864936971, enabled=True)
# 	DefaultConnectionGene(key=(-70, 2), weight=0.08911640766926754, enabled=True)
# 	DefaultConnectionGene(key=(-70, 3), weight=-1.072505681581933, enabled=False)
# 	DefaultConnectionGene(key=(-69, 0), weight=-0.49910313254783734, enabled=True)
# 	DefaultConnectionGene(key=(-69, 1), weight=-1.0228189719756275, enabled=True)
# 	DefaultConnectionGene(key=(-69, 2), weight=0.5274052640285852, enabled=True)
# 	DefaultConnectionGene(key=(-69, 3), weight=1.1489917735889914, enabled=True)
# 	DefaultConnectionGene(key=(-68, 0), weight=-1.0390233749620674, enabled=True)
# 	DefaultConnectionGene(key=(-68, 1), weight=0.8649411785980246, enabled=True)
# 	DefaultConnectionGene(key=(-68, 2), weight=-0.2501881591116365, enabled=True)
# 	DefaultConnectionGene(key=(-68, 3), weight=-0.03320990921706429, enabled=True)
# 	DefaultConnectionGene(key=(-67, 0), weight=-0.7618361889873676, enabled=False)
# 	DefaultConnectionGene(key=(-67, 1), weight=-0.43829260611756904, enabled=True)
# 	DefaultConnectionGene(key=(-67, 2), weight=-0.36927785404288405, enabled=True)
# 	DefaultConnectionGene(key=(-67, 3), weight=-0.22355576766658408, enabled=True)
# 	DefaultConnectionGene(key=(-66, 0), weight=0.34218735800626726, enabled=True)
# 	DefaultConnectionGene(key=(-66, 1), weight=0.9435778597703326, enabled=True)
# 	DefaultConnectionGene(key=(-66, 2), weight=-0.1606120642561838, enabled=True)
# 	DefaultConnectionGene(key=(-66, 3), weight=-0.3654023654760971, enabled=True)
# 	DefaultConnectionGene(key=(-65, 0), weight=-0.18688289823862994, enabled=True)
# 	DefaultConnectionGene(key=(-65, 1), weight=0.020943001823608365, enabled=False)
# 	DefaultConnectionGene(key=(-65, 2), weight=0.06963334976360769, enabled=True)
# 	DefaultConnectionGene(key=(-65, 3), weight=-0.4669124426699144, enabled=True)
# 	DefaultConnectionGene(key=(-64, 0), weight=-0.13422393424029025, enabled=True)
# 	DefaultConnectionGene(key=(-64, 1), weight=-0.00488004625398851, enabled=True)
# 	DefaultConnectionGene(key=(-64, 2), weight=-0.05791666180537669, enabled=True)
# 	DefaultConnectionGene(key=(-64, 3), weight=-0.22662594860611968, enabled=True)
# 	DefaultConnectionGene(key=(-63, 0), weight=0.3749476816661457, enabled=True)
# 	DefaultConnectionGene(key=(-63, 1), weight=-0.13167492902135255, enabled=False)
# 	DefaultConnectionGene(key=(-63, 2), weight=0.43097804968117676, enabled=True)
# 	DefaultConnectionGene(key=(-63, 3), weight=0.25816833988453497, enabled=True)
# 	DefaultConnectionGene(key=(-62, 0), weight=-0.5114901514396779, enabled=True)
# 	DefaultConnectionGene(key=(-62, 2), weight=0.023482972953384376, enabled=True)
# 	DefaultConnectionGene(key=(-62, 3), weight=0.022380835491439217, enabled=True)
# 	DefaultConnectionGene(key=(-61, 0), weight=-0.3702445711184203, enabled=True)
# 	DefaultConnectionGene(key=(-61, 1), weight=0.12508447525020872, enabled=True)
# 	DefaultConnectionGene(key=(-61, 2), weight=0.14404254417019857, enabled=True)
# 	DefaultConnectionGene(key=(-61, 3), weight=-0.1219741880912197, enabled=True)
# 	DefaultConnectionGene(key=(-60, 0), weight=0.7953364216228814, enabled=True)
# 	DefaultConnectionGene(key=(-60, 1), weight=-0.789527587391926, enabled=True)
# 	DefaultConnectionGene(key=(-60, 2), weight=-0.6172836921515128, enabled=True)
# 	DefaultConnectionGene(key=(-60, 3), weight=0.655707923664903, enabled=False)
# 	DefaultConnectionGene(key=(-59, 0), weight=-0.5773735949538963, enabled=True)
# 	DefaultConnectionGene(key=(-59, 1), weight=1.683829825752917, enabled=True)
# 	DefaultConnectionGene(key=(-59, 2), weight=0.03250526390333208, enabled=True)
# 	DefaultConnectionGene(key=(-59, 3), weight=0.5121484257250508, enabled=True)
# 	DefaultConnectionGene(key=(-58, 0), weight=-0.40417066840759763, enabled=True)
# 	DefaultConnectionGene(key=(-58, 1), weight=-0.6452398554551444, enabled=False)
# 	DefaultConnectionGene(key=(-58, 2), weight=-0.2469717316066854, enabled=True)
# 	DefaultConnectionGene(key=(-58, 3), weight=-0.30163847341879996, enabled=True)
# 	DefaultConnectionGene(key=(-57, 0), weight=-0.4184687930285788, enabled=True)
# 	DefaultConnectionGene(key=(-57, 2), weight=0.9284447217808794, enabled=True)
# 	DefaultConnectionGene(key=(-57, 3), weight=0.8729635244007096, enabled=True)
# 	DefaultConnectionGene(key=(-56, 0), weight=0.08813575912424787, enabled=True)
# 	DefaultConnectionGene(key=(-56, 1), weight=0.041160775457079926, enabled=True)
# 	DefaultConnectionGene(key=(-56, 2), weight=0.5194016157763497, enabled=True)
# 	DefaultConnectionGene(key=(-56, 3), weight=-0.11262402725830534, enabled=False)
# 	DefaultConnectionGene(key=(-55, 0), weight=0.17539594988519147, enabled=True)
# 	DefaultConnectionGene(key=(-55, 1), weight=-0.6866260812242226, enabled=True)
# 	DefaultConnectionGene(key=(-55, 2), weight=0.2859382131332462, enabled=True)
# 	DefaultConnectionGene(key=(-55, 3), weight=0.08933722025551838, enabled=False)
# 	DefaultConnectionGene(key=(-54, 0), weight=1.8236809975444415, enabled=True)
# 	DefaultConnectionGene(key=(-54, 1), weight=0.7470509369854414, enabled=True)
# 	DefaultConnectionGene(key=(-54, 2), weight=-0.31825622352386784, enabled=False)
# 	DefaultConnectionGene(key=(-53, 0), weight=0.2720807978018295, enabled=True)
# 	DefaultConnectionGene(key=(-53, 1), weight=-0.28665154439966173, enabled=True)
# 	DefaultConnectionGene(key=(-53, 2), weight=-0.15424412886789346, enabled=True)
# 	DefaultConnectionGene(key=(-53, 3), weight=-0.11371047346040491, enabled=True)
# 	DefaultConnectionGene(key=(-52, 0), weight=-0.0853358306940541, enabled=True)
# 	DefaultConnectionGene(key=(-52, 2), weight=0.09657584508070893, enabled=True)
# 	DefaultConnectionGene(key=(-52, 3), weight=0.1993858191670274, enabled=True)
# 	DefaultConnectionGene(key=(-51, 0), weight=0.7455248387821906, enabled=True)
# 	DefaultConnectionGene(key=(-51, 1), weight=-0.11253414974984219, enabled=True)
# 	DefaultConnectionGene(key=(-51, 2), weight=-0.3756092932828826, enabled=True)
# 	DefaultConnectionGene(key=(-51, 3), weight=0.41174131002110304, enabled=True)
# 	DefaultConnectionGene(key=(-50, 0), weight=0.033765059540754705, enabled=False)
# 	DefaultConnectionGene(key=(-50, 2), weight=0.5153438360198344, enabled=True)
# 	DefaultConnectionGene(key=(-50, 3), weight=0.022540393017588062, enabled=True)
# 	DefaultConnectionGene(key=(-49, 0), weight=0.43470298659735085, enabled=True)
# 	DefaultConnectionGene(key=(-49, 1), weight=-0.15118853345952077, enabled=True)
# 	DefaultConnectionGene(key=(-49, 2), weight=0.8203975780649333, enabled=False)
# 	DefaultConnectionGene(key=(-49, 3), weight=0.14672409717039042, enabled=True)
# 	DefaultConnectionGene(key=(-48, 0), weight=-0.10695672623263751, enabled=True)
# 	DefaultConnectionGene(key=(-48, 1), weight=-1.2889928325430116, enabled=False)
# 	DefaultConnectionGene(key=(-48, 2), weight=-0.007397339533074365, enabled=False)
# 	DefaultConnectionGene(key=(-48, 3), weight=0.19980305025372774, enabled=True)
# 	DefaultConnectionGene(key=(-47, 0), weight=0.7673970350332201, enabled=False)
# 	DefaultConnectionGene(key=(-47, 1), weight=0.44667020414193015, enabled=True)
# 	DefaultConnectionGene(key=(-47, 2), weight=-0.6303386003635106, enabled=True)
# 	DefaultConnectionGene(key=(-47, 3), weight=0.09303865493663749, enabled=True)
# 	DefaultConnectionGene(key=(-46, 0), weight=0.14391125151882936, enabled=True)
# 	DefaultConnectionGene(key=(-46, 1), weight=-0.22080315545281612, enabled=False)
# 	DefaultConnectionGene(key=(-46, 2), weight=-0.32862276132168444, enabled=True)
# 	DefaultConnectionGene(key=(-46, 3), weight=-0.731709451753606, enabled=False)
# 	DefaultConnectionGene(key=(-45, 0), weight=0.142987421164603, enabled=True)
# 	DefaultConnectionGene(key=(-45, 1), weight=0.4994063036543592, enabled=True)
# 	DefaultConnectionGene(key=(-45, 2), weight=0.14653176022906692, enabled=True)
# 	DefaultConnectionGene(key=(-45, 3), weight=-0.08432088860069506, enabled=True)
# 	DefaultConnectionGene(key=(-44, 0), weight=0.5357824462162776, enabled=True)
# 	DefaultConnectionGene(key=(-44, 1), weight=0.34783268120824673, enabled=True)
# 	DefaultConnectionGene(key=(-44, 2), weight=-0.38437724624707037, enabled=False)
# 	DefaultConnectionGene(key=(-44, 3), weight=-0.11326992184430303, enabled=False)
# 	DefaultConnectionGene(key=(-43, 0), weight=0.5864528792412312, enabled=True)
# 	DefaultConnectionGene(key=(-43, 1), weight=0.6047193287977075, enabled=True)
# 	DefaultConnectionGene(key=(-43, 2), weight=-0.05325079374509528, enabled=True)
# 	DefaultConnectionGene(key=(-43, 3), weight=-0.42747274193482987, enabled=True)
# 	DefaultConnectionGene(key=(-42, 0), weight=0.555835827954375, enabled=True)
# 	DefaultConnectionGene(key=(-42, 1), weight=0.885692206477317, enabled=True)
# 	DefaultConnectionGene(key=(-42, 2), weight=0.8441643797994203, enabled=True)
# 	DefaultConnectionGene(key=(-42, 3), weight=-0.22875092813167563, enabled=True)
# 	DefaultConnectionGene(key=(-41, 0), weight=0.23715116226843472, enabled=True)
# 	DefaultConnectionGene(key=(-41, 1), weight=0.23101161550081525, enabled=True)
# 	DefaultConnectionGene(key=(-41, 2), weight=-0.1499865248039422, enabled=True)
# 	DefaultConnectionGene(key=(-41, 3), weight=0.5637177054835704, enabled=True)
# 	DefaultConnectionGene(key=(-40, 0), weight=-0.20767403316983457, enabled=True)
# 	DefaultConnectionGene(key=(-40, 1), weight=0.2585293649798335, enabled=True)
# 	DefaultConnectionGene(key=(-40, 2), weight=0.45891116507677615, enabled=True)
# 	DefaultConnectionGene(key=(-40, 3), weight=-0.44221721108903744, enabled=True)
# 	DefaultConnectionGene(key=(-39, 1), weight=0.5311929690470294, enabled=True)
# 	DefaultConnectionGene(key=(-39, 2), weight=-0.19395614181556972, enabled=True)
# 	DefaultConnectionGene(key=(-39, 3), weight=0.49630607801871973, enabled=True)
# 	DefaultConnectionGene(key=(-38, 0), weight=0.05310413376753209, enabled=False)
# 	DefaultConnectionGene(key=(-38, 1), weight=0.3796156223142034, enabled=True)
# 	DefaultConnectionGene(key=(-38, 2), weight=-0.17449750639986417, enabled=True)
# 	DefaultConnectionGene(key=(-38, 3), weight=-0.16670378910115952, enabled=False)
# 	DefaultConnectionGene(key=(-37, 0), weight=-0.039177140082565814, enabled=True)
# 	DefaultConnectionGene(key=(-37, 1), weight=-0.2534117453297532, enabled=True)
# 	DefaultConnectionGene(key=(-37, 2), weight=-0.39501943324167194, enabled=True)
# 	DefaultConnectionGene(key=(-37, 3), weight=-0.8817194039798796, enabled=True)
# 	DefaultConnectionGene(key=(-36, 0), weight=0.5575851528751544, enabled=True)
# 	DefaultConnectionGene(key=(-36, 1), weight=0.6305499050856811, enabled=False)
# 	DefaultConnectionGene(key=(-36, 2), weight=-0.10837395179103085, enabled=False)
# 	DefaultConnectionGene(key=(-36, 3), weight=0.10028789342144825, enabled=True)
# 	DefaultConnectionGene(key=(-35, 0), weight=-0.1621298588507183, enabled=False)
# 	DefaultConnectionGene(key=(-35, 1), weight=0.024067091663134574, enabled=True)
# 	DefaultConnectionGene(key=(-35, 2), weight=-0.1039371239533031, enabled=True)
# 	DefaultConnectionGene(key=(-35, 3), weight=0.23576593896058573, enabled=False)
# 	DefaultConnectionGene(key=(-34, 0), weight=0.6493002845918432, enabled=True)
# 	DefaultConnectionGene(key=(-34, 1), weight=-0.06939391075455636, enabled=True)
# 	DefaultConnectionGene(key=(-34, 2), weight=-0.08072816419102839, enabled=True)
# 	DefaultConnectionGene(key=(-34, 3), weight=0.39054502148187153, enabled=True)
# 	DefaultConnectionGene(key=(-33, 0), weight=0.7558913213857927, enabled=True)
# 	DefaultConnectionGene(key=(-33, 1), weight=-0.21348461912152938, enabled=True)
# 	DefaultConnectionGene(key=(-33, 2), weight=-0.01334981846488878, enabled=False)
# 	DefaultConnectionGene(key=(-33, 3), weight=0.004209796235534732, enabled=True)
# 	DefaultConnectionGene(key=(-32, 0), weight=0.11809557246109428, enabled=False)
# 	DefaultConnectionGene(key=(-32, 1), weight=0.519156723100818, enabled=True)
# 	DefaultConnectionGene(key=(-32, 2), weight=0.0997813074137805, enabled=True)
# 	DefaultConnectionGene(key=(-32, 3), weight=-0.9988089530901476, enabled=True)
# 	DefaultConnectionGene(key=(-31, 0), weight=0.10624344185485302, enabled=True)
# 	DefaultConnectionGene(key=(-31, 1), weight=-0.03923568608784572, enabled=True)
# 	DefaultConnectionGene(key=(-31, 2), weight=0.40250324677697397, enabled=True)
# 	DefaultConnectionGene(key=(-31, 3), weight=0.533134394351181, enabled=True)
# 	DefaultConnectionGene(key=(-30, 0), weight=-0.11426176602819724, enabled=True)
# 	DefaultConnectionGene(key=(-30, 1), weight=0.7011270783417064, enabled=True)
# 	DefaultConnectionGene(key=(-30, 2), weight=1.5011017899761194, enabled=False)
# 	DefaultConnectionGene(key=(-30, 3), weight=-0.05550413034730314, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=0.4872122945364513, enabled=True)
# 	DefaultConnectionGene(key=(-29, 1), weight=1.217338870719098, enabled=True)
# 	DefaultConnectionGene(key=(-29, 2), weight=-0.4304425408071099, enabled=True)
# 	DefaultConnectionGene(key=(-29, 3), weight=0.18698485834337225, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-0.29387330533528616, enabled=True)
# 	DefaultConnectionGene(key=(-28, 1), weight=1.1750520794879922, enabled=True)
# 	DefaultConnectionGene(key=(-28, 2), weight=-0.1521086876235367, enabled=True)
# 	DefaultConnectionGene(key=(-28, 3), weight=1.0073848669856864, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=0.37725405462630646, enabled=False)
# 	DefaultConnectionGene(key=(-27, 1), weight=-0.2392186512758696, enabled=True)
# 	DefaultConnectionGene(key=(-27, 2), weight=-0.5680630523769485, enabled=True)
# 	DefaultConnectionGene(key=(-27, 3), weight=0.12306537433086878, enabled=True)
# 	DefaultConnectionGene(key=(-26, 0), weight=-0.33788265411572405, enabled=True)
# 	DefaultConnectionGene(key=(-26, 1), weight=-0.21002959758840486, enabled=True)
# 	DefaultConnectionGene(key=(-26, 2), weight=0.5458317799844705, enabled=True)
# 	DefaultConnectionGene(key=(-26, 3), weight=0.095497290557158, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=0.37610972863952763, enabled=True)
# 	DefaultConnectionGene(key=(-25, 1), weight=-0.3122151157488825, enabled=False)
# 	DefaultConnectionGene(key=(-25, 2), weight=0.20748819059519888, enabled=True)
# 	DefaultConnectionGene(key=(-25, 3), weight=0.786915825773536, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=0.4991812267922005, enabled=True)
# 	DefaultConnectionGene(key=(-24, 1), weight=0.19072417132538877, enabled=False)
# 	DefaultConnectionGene(key=(-24, 2), weight=-0.29107974920357016, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=-0.19936357925145592, enabled=True)
# 	DefaultConnectionGene(key=(-23, 1), weight=0.5420456225282024, enabled=True)
# 	DefaultConnectionGene(key=(-23, 2), weight=0.5378558301412003, enabled=True)
# 	DefaultConnectionGene(key=(-23, 3), weight=1.3789907214950743, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=-0.07198716189693816, enabled=False)
# 	DefaultConnectionGene(key=(-22, 1), weight=-0.0849239948010593, enabled=True)
# 	DefaultConnectionGene(key=(-22, 2), weight=0.9361224712165883, enabled=True)
# 	DefaultConnectionGene(key=(-22, 3), weight=0.11425696247524118, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=0.12198044761653783, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=0.10113670714161174, enabled=True)
# 	DefaultConnectionGene(key=(-21, 2), weight=-0.3114469037293335, enabled=True)
# 	DefaultConnectionGene(key=(-21, 3), weight=-0.3971075249220315, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=-0.1708572244559335, enabled=True)
# 	DefaultConnectionGene(key=(-20, 1), weight=0.8061067489352784, enabled=True)
# 	DefaultConnectionGene(key=(-20, 2), weight=-0.04664842011800075, enabled=True)
# 	DefaultConnectionGene(key=(-20, 3), weight=0.08052008487942613, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=0.1375335641214436, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=1.5009081017345332, enabled=True)
# 	DefaultConnectionGene(key=(-19, 2), weight=-0.2020121341405865, enabled=True)
# 	DefaultConnectionGene(key=(-19, 3), weight=1.0761783814167367, enabled=False)
# 	DefaultConnectionGene(key=(-18, 0), weight=0.6974460516477687, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=-0.156388924334995, enabled=False)
# 	DefaultConnectionGene(key=(-18, 2), weight=0.1179075259603149, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=0.09082086498683548, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.41958542206699734, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1), weight=0.5436408056484168, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=-0.9697558442394217, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=-0.7844052986214105, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=0.16087810019427756, enabled=True)
# 	DefaultConnectionGene(key=(-16, 2), weight=0.11948603188269245, enabled=True)
# 	DefaultConnectionGene(key=(-16, 3), weight=0.35069088825453826, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=0.2968326017425637, enabled=True)
# 	DefaultConnectionGene(key=(-15, 1), weight=0.05602861429744589, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=-0.0748935693158852, enabled=True)
# 	DefaultConnectionGene(key=(-15, 3), weight=-0.28992139659155963, enabled=False)
# 	DefaultConnectionGene(key=(-14, 0), weight=0.11262900245188978, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=-0.0030299413640222095, enabled=True)
# 	DefaultConnectionGene(key=(-14, 2), weight=-1.4116104292042093, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=-0.06279386351471766, enabled=False)
# 	DefaultConnectionGene(key=(-13, 1), weight=0.5795093317976476, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=0.01619691120742789, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=1.2477068870500678, enabled=False)
# 	DefaultConnectionGene(key=(-12, 1), weight=0.004174595412132501, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=0.03247576673389619, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=0.5195031727355143, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=0.6939908193510986, enabled=True)
# 	DefaultConnectionGene(key=(-11, 1), weight=-0.7754203768237562, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=0.5642699745360967, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=-0.3103156748916131, enabled=False)
# 	DefaultConnectionGene(key=(-10, 0), weight=0.7595608634445425, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=0.19029152283530928, enabled=True)
# 	DefaultConnectionGene(key=(-10, 2), weight=-0.06339581916263735, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=-0.07563778048230474, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.29128400581979585, enabled=False)
# 	DefaultConnectionGene(key=(-9, 1), weight=0.08528409963275019, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=0.18859854045994773, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=0.07994171181990699, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=0.3323360182431074, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=0.07223235808908283, enabled=False)
# 	DefaultConnectionGene(key=(-8, 2), weight=-0.3209599421161096, enabled=False)
# 	DefaultConnectionGene(key=(-8, 3), weight=0.0422221349346929, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.22602647085325767, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=0.44615928521140996, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=0.004474408052929313, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=0.1022786913462902, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-0.28347791378923404, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=-0.12489322463746176, enabled=False)
# 	DefaultConnectionGene(key=(-6, 2), weight=0.035910698259252014, enabled=True)
# 	DefaultConnectionGene(key=(-6, 3), weight=0.36024734362259564, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=-0.44113806069867156, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.3493459451859643, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=0.48979283309917787, enabled=True)
# 	DefaultConnectionGene(key=(-5, 3), weight=0.33776633348889457, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.48177571628734395, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-0.5687370649247221, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=0.3638710238019269, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=-0.21723085681011084, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.11466926901161915, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=-0.11651682255452339, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=0.9563123907449544, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=0.36093012987667117, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-0.2317516380870682, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=-0.06975827299269416, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-0.006865420321319909, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.045443417293554444, enabled=False)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.11843001939667083, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=-0.11617319840454307, enabled=False)
# 	DefaultConnectionGene(key=(-1, 2), weight=0.1776245930685561, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=-0.11763242753447234, enabled=True)
# 	DefaultConnectionGene(key=(0, 0), weight=-0.07576458932193264, enabled=False)
# 	DefaultConnectionGene(key=(1, 1), weight=-0.16409604960741425, enabled=True)
# 	DefaultConnectionGene(key=(2, 2), weight=-1.4326873426940376, enabled=True)
# 	DefaultConnectionGene(key=(3, 3), weight=-0.34263218716674504, enabled=True)
# 0.9995000890921801
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]
# 1 [0.5576639611516543, 0.0, 0.0, 0.0]
# 1 [0.44627342583855817, 0.0, 0.0, 0.0]
# .
# -1.0
# -1.0
# Agent count: 1
# 1 [0.5584469456373311, 0.0, 0.0, 0.0]
# 1 [0.625429788139912, 0.0, 0.0, 0.0]
# 1 [0.6059846658452339, 0.0, 0.0, 0.0]
# 1 [0.589075891315994, 0.0, 0.0, 0.0]
# 1 [0.616169130206323, 0.0, 0.0, 0.0]
# 1 [0.6851131708218856, 0.0, 0.0, 0.0]
# 1 [0.7376937730155309, 0.0, 0.0, 0.0]
# 1 [0.7802436538202786, 0.0, 0.0, 0.0]
# 1 [0.6724779201524473, 0.0, 0.0, 0.0]

# %%
env.close()
