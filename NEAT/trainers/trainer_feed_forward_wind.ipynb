# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
NUM_RUNS = 5
MAX_GENS = 3000

generation = 0
SAVE_INTERVAL = 50

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=4)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = 'result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x0000020F9DF2BCD0>
# Name of the behavior : WindControl?team=0
# Number of observations :  1
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.FeedForwardNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1
    num_runs = 5

    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")
    for _ in range(num_runs):
        env.reset()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        while not done:
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    nn_input =  np.asarray(decision_steps[agent].obs[:])
                    #print(f"NN INPUT: {nn_input}, agent: {agent}")
                    #print(f"NN INPUT[0]: {nn_input[0]}, agent: {agent}")
                    actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                    #print(f"NN OUTPUT: {actions}, agent: {agent}")
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)
                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                        #print(f"Finished: {agent}")
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward
            if len(removed_agents) >= agent_count:
                done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i] / num_runs
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"wind-env/checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    # print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = '../configs/config-feedforward'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# Population's average fitness: -0.00527 stdev: 0.17474
# Best fitness: 0.82360 - size: (8, 88) - species 27 - id 27
# Best fitness ever found! : 0.8235955320984578
# Population of 100 members in 50 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0     2  -0.09865270004532944  0.07702650090081678     0
#      2    0     2  0.14983700278121206  0.3255162037273583     0
#      3    0     2  -0.031178062743614364  0.14450113820253185     0
#      4    0     2  -0.1627903724565162  0.012888828489630022     0
#      5    0     2  -0.03926942725315696  0.13640977369298926     0
#      6    0     2  -0.11880690133036423  0.056872299615781996     0
#      7    0     2  0.0968136245945308  0.272492825540677     0
#      8    0     2  0.09466339982369121  0.2703426007698374     0
#      9    0     2  0.19436246055191297  0.37004166149805917     0
#     10    0     2  0.011655572937907088  0.1873347738840533     0
#     11    0     2  -0.16022441506506074  0.015454785881085481     0
#     12    0     2  0.14165026515798984  0.31732946610413604     0
#     13    0     2  -0.1549530513463165  0.020726149599829713     0
#     14    0     2  -0.1717800968056042  0.003899104140542037     0
#     15    0     2  0.0747663204535555  0.2504455213997017     0
#     16    0     2  -0.1257930657443838  0.04988613520176244     0
#     17    0     2  -0.16426607840256047  0.011413122543585758     0
#     18    0     2  -0.10400106348971808  0.07167813745642815     0
#     19    0     2  0.06867215310312877  0.244351354049275     0
#     20    0     2  0.36352085584714  0.5392000567932862     0
species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   59     2  -0.1517696662119722  0.01653985391096802    13
#     13   59     2  -0.14683768224758342  0.01823120225428825    13
#     19   59     9  0.39493349351897794  0.20402332712892568     1
#     23   59    10  0.5671130966758929  0.2630696842654648     5
#     29   59     2  -0.13687899125008357  0.02164638276620359    13
#     42   59     8  0.4908742323037833  0.2369247336972072     0
#     44   59    10  0.4109923571738607  0.20953046839994513     6
#     50   59     7  0.30619336438124634  0.1735912593268304    15
# Total extinctions: 0
# Generation time: 1.142 sec (1.345 average)
#
#  ****** Running generation 60 ******
#
# Agent count: 50
# Population's average fitness: 0.37983 stdev: 0.79503
# Best fitness: 2.71714 - size: (7, 71) - species 44 - id 928
# Population of 50 members in 8 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   60     2  -0.15176816751603706  0.016533925905791013     0
#     13   60     2  -0.14683613082029015  0.018224633579384707     0
#     19   60     8  0.3964931135801872  0.20447850382895216     2
#     23   60     9  0.43869882109161884  0.21894666738105287     6
#     29   60     2  -0.13687711345612158  0.021638595826172637    14
#     42   60     7  0.2932751713258451  0.16909527823931797     1
#     44   60    12  0.7009333658705528  0.3088409614607017     7
#     50   60     8  0.3644823476483864  0.19350517760751962    16
# Total extinctions: 0
# Generation time: 1.159 sec (1.306 average)
#
#  ****** Running generation 61 ******
#
# Agent count: 50
# Population's average fitness: 0.40957 stdev: 0.80188
# Best fitness: 2.71656 - size: (7, 71) - species 44 - id 928
# Population of 50 members in 8 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   61     2  -0.15176817062818077  0.01653721350647041     1
#     13   61     2  -0.14683613083528813  0.01822825853088179     1
#     19   61     8  0.42414611254124146  0.21400053982523656     3
#     23   61     9  0.44787478848851  0.22213637430376665     7
#     29   61     2  -0.1368771134849819  0.021642899824435635    15
#     42   61     8  0.4280761827497924  0.21534804024105533     2
#     44   61    12  0.6956774370887642  0.3071002946182968     8
#     50   61     7  0.322593147973116  0.17918114609393945    17
# Total extinctions: 0
# Generation time: 1.267 sec (1.307 average)
#
#  ****** Running generation 62 ******
#
# Agent count: 50
# Population's average fitness: 0.38396 stdev: 0.82020
# Best fitness: 2.71587 - size: (7, 71) - species 44 - id 928
# Population of 52 members in 8 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   62     2  -0.15176949915995092  0.006987324044707308     2
#     13   62     2  -0.14683756147842877  0.0086951651981494     2
#     19   62    11  0.7679374627794628  0.32546527330836517     0
#     23   62    10  0.45236863272727323  0.21618947350945733     8
#     29   62     2  -0.13687893463190642  0.012143658236491082    16
#     42   62     7  0.26348800837187175  0.1507835166234745     3
#     44   62    10  0.39881239949919517  0.1976439149406748     9
#     50   62     8  0.4229559387849927  0.20600438756718717    18
# Total extinctions: 0
# Generation time: 1.792 sec (1.355 average)
#
#  ****** Running generation 63 ******
#
# Agent count: 52
# Population's average fitness: 0.35666 stdev: 0.78235
# Best fitness: 2.71663 - size: (7, 71) - species 44 - id 928
# Population of 49 members in 8 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   63     2  -0.15176975281640318  0.01653628880054039     3
#     13   63     2  -0.14683783153335206  0.018227254106349604     3
#     19   63     9  0.38217335833676863  0.1996047573380765     1
#     23   63     8  0.40117920174865185  0.20612112691753076     9
#     29   63     2  -0.13687817437235889  0.021642035841587456    17
#     42   63     8  0.3374641148364305  0.18427568469698252     4
#     44   63    10  0.6058377057326874  0.27629062272134985    10
#     50   63     8  0.34763479475926307  0.18776281798621466    19
# Total extinctions: 0
# Generation time: 1.376 sec (1.376 average)
#
#  ****** Running generation 64 ******
#
# Agent count: 49
# Population's average fitness: 0.40783 stdev: 0.80960
# Best fitness: 2.71580 - size: (7, 71) - species 44 - id 928
#
# Species 50 with 8 members is stagnated: removing it
# Population of 48 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   64     2  -0.15177034328675584  0.016540822895128017     4
#     13   64     2  -0.14683854386907358  0.018232230760773814     4
#     19   64    12  0.6847747479435718  0.3034419775125067     2
#     23   64     9  0.44178252468552526  0.22010546625135494    10
#     29   64     2  -0.1368789731586157  0.021647960966208798    18
#     42   64     9  0.28706189583682656  0.1670425440907171     5
#     44   64    12  0.6368652735414682  0.2870109642088965    11
# Total extinctions: 0
# Generation time: 1.265 sec (1.326 average)
#
#  ****** Running generation 65 ******
#
# Agent count: 48
# Population's average fitness: 0.34426 stdev: 0.81823
# Best fitness: 2.71820 - size: (7, 71) - species 44 - id 928
# Best fitness ever found! : 2.718199833868898
# Population of 49 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   65     2  -0.15176802002657525  0.016526798832399468     0
#     13   65     2  -0.14683591077089253  0.018216921344263427     0
#     19   65    11  0.4094015606159298  0.20882694711568572     3
#     23   65    11  0.4949197798028139  0.23813211047064106    11
#     29   65     2  -0.13687616847987016  0.021629900211068826     0
#     42   65     8  0.17732448819992622  0.12929937295948932     6
#     44   65    13  0.5360223601311171  0.25221703696097    12
# Total extinctions: 0
# Generation time: 1.074 sec (1.273 average)
#
#  ****** Running generation 66 ******
#
# Agent count: 49
# Population's average fitness: 0.31617 stdev: 0.76910
# Best fitness: 2.71800 - size: (7, 71) - species 44 - id 928
# Population of 51 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   66     2  -0.15176802003056944  0.016529130216478158     1
#     13   66     2  -0.1468359107534861  0.01821936729431154     0
#     19   66    10  0.3273355332153358  0.18071823153680264     4
#     23   66    12  0.3455282244669818  0.18695287873774447    12
#     29   66     2  -0.13687616847957562  0.02163257749126468     0
#     42   66    10  0.35848122259201465  0.1913918796742736     7
#     44   66    13  0.46878013361391974  0.22919138868355435    13
# Total extinctions: 0
# Generation time: 1.141 sec (1.261 average)
#
#  ****** Running generation 67 ******
#
# Agent count: 51
# Population's average fitness: 0.33464 stdev: 0.78706
# Best fitness: 2.71758 - size: (7, 71) - species 44 - id 928
# Population of 50 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   67     2  -0.15176906541436386  0.016531161730846396     2
#     13   67     2  -0.14683712077373784  0.01822158668612479     1
#     19   67    11  0.30756424053686093  0.17396773893296152     5
#     23   67    12  0.5333219467454696  0.2513462352927665    13
#     29   67     2  -0.13687684195863914  0.021635474127577582     1
#     42   67     8  0.1471595788791239  0.11898901091244415     8
#     44   67    13  0.5377195796846894  0.2528535248116666    14
# Total extinctions: 0
# Generation time: 1.229 sec (1.270 average)
#
#  ****** Running generation 68 ******
#
# Agent count: 50
# Population's average fitness: 0.31480 stdev: 0.76363
# Best fitness: 2.71556 - size: (7, 71) - species 44 - id 928
# Population of 51 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   68     2  -0.1517705654698225  0.010884081625893455     3
#     13   68     2  -0.14683877336025405  0.01258535277751366     2
#     19   68    12  0.4426969650345027  0.21595161848733854     6
#     23   68    11  0.2947568082251712  0.16491817762968886    14
#     29   68     2  -0.13687931594027875  0.01602096750294385     2
#     42   68     9  0.29830230148127734  0.16614123108791848     9
#     44   68    13  0.4475303079958214  0.21761892861787394    15
# Total extinctions: 0
# Generation time: 1.111 sec (1.256 average)
#
#  ****** Running generation 69 ******
#
# Agent count: 51
# Population's average fitness: 0.38471 stdev: 0.83431
# Best fitness: 2.71590 - size: (7, 71) - species 44 - id 928
# Population of 51 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   69     2  -0.15177031198585977  0.012567036990696926     4
#     13   69     2  -0.14683853946048436  0.014265208804375047     3
#     19   69    11  0.37357841621856713  0.19346191768483342     7
#     23   69    10  0.35866388064442556  0.18832635155809305    15
#     29   69     2  -0.1368786750337736  0.017694718367208772     3
#     42   69     8  0.21126181066184319  0.13757096102978053    10
#     44   69    16  0.7816794182847524  0.33398454221318963    16
# Total extinctions: 0
# Generation time: 1.400 sec (1.281 average)
#
#  ****** Running generation 70 ******
#
# Agent count: 51
# Population's average fitness: 0.35483 stdev: 0.77265
# Best fitness: 2.71605 - size: (7, 71) - species 44 - id 928
# Population of 49 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   70     2  -0.151769579716442  0.016539663110667974     5
#     13   70     2  -0.14683773900184216  0.018230939766674337     4
#     19   70    11  0.38687517990289666  0.20125716729272705     8
#     23   70    10  0.33320113574786697  0.18285072167413172    16
#     29   70     2  -0.13687828468397342  0.021646336485491493     4
#     42   70     8  0.29260505320917235  0.16892910281086465    11
#     44   70    14  0.5649192051432552  0.2623138236318112    17
# Total extinctions: 0
# Generation time: 1.265 sec (1.292 average)
#
#  ****** Running generation 71 ******
#
# Agent count: 49
# Population's average fitness: 0.25894 stdev: 0.78431
# Best fitness: 2.71629 - size: (7, 71) - species 44 - id 928
# Population of 51 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   71     2  -0.15176959319614736  0.016538264844472933     6
#     13   71     2  -0.14683775545888395  0.018229397971351577     5
#     19   71    12  0.2923955444159248  0.16884302790368555     9
#     23   71    11  0.33169315345394035  0.1823182255869309    17
#     29   71     2  -0.1368781207224804  0.021644568772102458     5
#     42   71    10  0.3142640289837418  0.17634175771951902    12
#     44   71    12  0.32225896704989426  0.17908323165505766    18
# Total extinctions: 0
# Generation time: 1.544 sec (1.320 average)
#
#  ****** Running generation 72 ******
#
# Agent count: 51
# Population's average fitness: 0.25418 stdev: 0.76747
# Best fitness: 2.71580 - size: (7, 71) - species 44 - id 928
# Population of 51 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   72     2  -0.15176972598320704  0.013570771291309704     7
#     13   72     2  -0.1468379238682705  0.015267286952924982     6
#     19   72    11  0.2896968179838963  0.16543309027022046    10
#     23   72    10  0.2670372400132593  0.15763830694013692    18
#     29   72     2  -0.13687830850798588  0.018693345632613986     6
#     42   72    11  0.25869657321172507  0.15476915859895302    13
#     44   72    13  0.40277501282429923  0.20433143291720557    19
# Total extinctions: 0
# Generation time: 1.507 sec (1.291 average)
#
#  ****** Running generation 73 ******
#
# Agent count: 51
# Population's average fitness: 0.27411 stdev: 0.76366
# Best fitness: 2.71571 - size: (7, 71) - species 44 - id 928
# Population of 49 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   73     2  -0.15176996446081087  0.014517526799836662     8
#     13   73     2  -0.1468381980592091  0.016212455683720765     7
#     19   73    11  0.31693948381268283  0.17560163284551422    11
#     23   73    10  0.31343767741040934  0.17439814664327724    19
#     29   73     2  -0.13687863038301068  0.019635318315637928     7
#     42   73     9  0.20672187298846015  0.13772250458063956    14
#     44   73    13  0.45816792639840015  0.2241384342817615    20
# Total extinctions: 0
# Generation time: 1.218 sec (1.275 average)
#
#  ****** Running generation 74 ******
#
# Agent count: 49
# Population's average fitness: 0.33914 stdev: 0.78167
# Best fitness: 2.71559 - size: (7, 71) - species 44 - id 928
# Population of 51 members in 7 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   74     2  -0.15176955579226917  0.015346130309344064     9
#     13   74     2  -0.1468377179875835  0.017039727315557446     8
#     19   74    10  0.33126756701944854  0.1812214606591406    12
#     23   74    12  0.47209564167088863  0.22958193297513455    20
#     29   74     2  -0.13687883619705843  0.020459615205958414     8
#     42   74    10  0.33221790926120226  0.18154780893725775    15
#     44   74    13  0.4718451239068196  0.22949590497664127    21
# Total extinctions: 0
# Generation time: 1.311 sec (1.280 average)
#
#  ****** Running generation 75 ******
#
# Agent count: 51
# Population's average fitness: 0.37549 stdev: 0.83117
# Best fitness: 2.77435 - size: (7, 58) - species 44 - id 1898
# Best fitness ever found! : 2.7743473638736473
#
# Species 23 with 12 members is stagnated: removing it
# Population of 50 members in 6 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   75     2  -0.1517701641955998  0.0071377878827138695    10
#     13   75     2  -0.1468384781611498  0.008811160417706616     9
#     19   75    13  0.3596680959942552  0.18067412656442478    13
#     29   75     2  -0.13687904469010753  0.012190500123866212     9
#     42   75    12  0.2691571583934319  0.14996282092986982    16
#     44   75    19  0.7311840902402129  0.3067333802839375    22
# Total extinctions: 0
# Generation time: 1.690 sec (1.342 average)
#
#  ****** Running generation 76 ******
#
# Agent count: 50
# Population's average fitness: 0.29152 stdev: 0.76285
# Best fitness: 2.77635 - size: (7, 58) - species 44 - id 1898
# Best fitness ever found! : 2.776353335727756
# Population of 51 members in 6 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   76     2  -0.15176927104248428  0.016204638198885988    11
#     13   76     2  -0.1468373574468128  0.01786167049289135    10
#     19   76    14  0.30504872104058567  0.16968708485583578    14
#     29   76     2  -0.13687809994301947  0.021207797911381523    10
#     42   76    13  0.28594683569328666  0.1632692025708253    17
#     44   76    18  0.4236848248056494  0.2095466345742686    23
# Total extinctions: 0
# Generation time: 1.408 sec (1.368 average)
#
#  ****** Running generation 77 ******
#
# Agent count: 51
# Population's average fitness: 0.25877 stdev: 0.69902
# Best fitness: 2.77342 - size: (7, 58) - species 44 - id 1898
# Population of 49 members in 6 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      4   77     2  -0.1517698809204063  0.016220439686906066    12
#     13   77     2  -0.14683790717237305  0.01787912899234519    11
#     19   77    12  0.18239980465280006  0.128606213006009    15
#     29   77     2  -0.13687976630323262  0.021228186105288305    11
#     42   77    13  0.30429377979382166  0.16960080123643106    18
#     44   77    18  0.4199352168191466  0.2084925765497138    24
# Total extinctions: 0
# Generation time: 3.880 sec (1.634 average)
#
#  ****** Running generation 78 ******
#
# Agent count: 49

# %%
env.close()
