# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
NUM_RUNS = 1
MAX_GENS = 3000

generation = 0
SAVE_INTERVAL = 50

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=4)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = 'result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x0000025DF86325F0>
# Name of the behavior : ForestControl?team=0
# Number of observations :  5
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.FeedForwardNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1

    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")

    while not done:
        for agent in decision_steps:
            if unity_to_neat_map[agent] not in removed_agents:
                obs = np.concatenate(decision_steps[agent].obs[:])
                nn_input =  np.asarray(obs)
                #print(f"NN INPUT: {nn_input}, agent: {agent}")
                #print(f"NN INPUT[0]: {nn_input[0]}, agent: {agent}")
                actions = policies[unity_to_neat_map[agent]].activate(nn_input)
                #print(f"NN OUTPUT: {actions}, agent: {agent}")
                continous_actions = np.asarray([actions])
                continous_actions = np.clip(continous_actions, -1, 1)
                action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                env.set_action_for_agent(behavior_name=behavior_name, 
                                        agent_id=agent, 
                                        action=action_tuple)
        env.step()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        for agent in range(agent_count):
            if agent not in removed_agents:
                local_agent = neat_to_unity_map[agent]
                if local_agent in terminal_steps:
                    episode_rewards[agent] += terminal_steps[local_agent].reward
                    removed_agents.append(agent)
                    #print(f"Finished: {agent}")
                elif local_agent in decision_steps:
                    episode_rewards[agent] += decision_steps[local_agent].reward
                 

        if len(removed_agents) >= agent_count:
            done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i]
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    # print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = '../configs/config-feedforward-forest'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# Population's average fitness: -0.99999 stdev: 0.00003
# Best fitness: -0.99979 - size: (14, 552) - species 11 - id 11
# Best fitness ever found! : -0.9997909405321082
# Population of 106 members in 50 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0     2  -0.9999999982835586  1.7164414334303046e-09     0
#      2    0     2       -1.0      0.0     0
#      3    0     2  -0.9999999999279785  7.202149987506345e-11     0
#      4    0     2  -0.9999999992143849  7.856151285068336e-10     0
#      5    0     2       -1.0      0.0     0
#      6    0     2  -0.9999997640440533  2.359559466702521e-07     0
#      7    0     2       -1.0      0.0     0
#      8    0     2  -0.9999999995893935  4.1060654876190483e-10     0
#      9    0     2  -0.999977809445382  2.2190554618051195e-05     0
#     10    0     2  -0.9999999999839548  1.6045165196487687e-11     0
#     11    0     8  -0.9997909405321082  0.00020905946789184782     0
#     12    0     2  -0.9999999928981991  7.101800925113366e-09     0
#     13    0     2       -1.0      0.0     0
#     14    0     2  -0.9999999988035643  1.1964357282678861e-09     0
#     15    0     2  -0.9999999653577216  3.464227837923772e-08     0
#     16    0     2  -0.9999999866142053  1.3385794694897868e-08     0
#     17    0     2  -0.9999919610100675  8.038989932512841e-06     0
#     18    0     2  -0.9999999921184304  7.881569619172524e-09     0
#     19    0     2  -0.9999999973100853  2.689914735398702e-09     0
#     47   13     2       -1.0      0.0    13
#     48   13     2  -0.9999999996072888  1.9635559844743966e-10    12
#     49   13     2       -1.0      0.0    13
#     50   13     2       -1.0      0.0    13
# Total extinctions: 0
# Generation time: 6.889 sec (6.662 average)
#
#  ****** Running generation 14 ******
#
# Agent count: 110
# Population's average fitness: -0.99780 stdev: 0.02218
# Best fitness: -0.76640 - size: (17, 544) - species 11 - id 182
# Population of 110 members in 50 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14     2  -0.9999999982835586  8.762082170932217e-10    14
# ...
# Generation time: 1.979 sec (2.089 average)
#
#  ****** Running generation 147 ******
#
# Agent count: 50
# Population's average fitness: -0.97058 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  147    48  -0.265006876211487  0.030645265452868498    70
#     35  147     2  -0.999952915521757  4.481327219396647e-05   147
# Total extinctions: 0
# Generation time: 2.186 sec (2.108 average)
#
#  ****** Running generation 148 ******
#
# Agent count: 50
# Population's average fitness: -0.97057 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  148    48  -0.265006876211487  0.03064987602268543    71
#     35  148     2  -0.999952915521757  4.481327219396647e-05   148
# Total extinctions: 0
# Generation time: 1.906 sec (2.062 average)
#
#  ****** Running generation 149 ******
#
# Agent count: 50
# Population's average fitness: -0.96998 stdev: 0.14386
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  149    48  -0.265006876211487  0.03127254429232551    72
#     35  149     2  -0.999952915521757  4.481327219396647e-05   149
# Total extinctions: 0
# Generation time: 2.016 sec (2.070 average)
#
#  ****** Running generation 150 ******
#
# Agent count: 50
# Population's average fitness: -0.97060 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  150    48  -0.265006876211487  0.030619061918135237    73
#     35  150     2  -0.999952915521757  4.481327219396647e-05   150
# Total extinctions: 0
# Generation time: 2.008 sec (2.051 average)
#
#  ****** Running generation 151 ******
#
# Agent count: 50
# Population's average fitness: -0.97060 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  151    48  -0.265006876211487  0.03062431438940283    74
#     35  151     2  -0.999952915521757  4.481327219396647e-05   151
# Total extinctions: 0
# Generation time: 1.927 sec (2.008 average)
#
#  ****** Running generation 152 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  152    48  -0.265006876211487  0.030628974866283354    75
#     35  152     2  -0.999952915521757  4.481327219396647e-05   152
# Total extinctions: 0
# Generation time: 1.951 sec (2.009 average)
#
#  ****** Running generation 153 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  153    48  -0.265006876211487  0.03063179443020081    76
#     35  153     2  -0.999952915521757  4.4812586068143645e-05   153
# Total extinctions: 0
# Generation time: 2.014 sec (2.011 average)
#
#  ****** Running generation 154 ******
#
# Agent count: 50
# Population's average fitness: -0.97058 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  154    48  -0.265006876211487  0.03063945265071022    77
#     35  154     2  -0.999952915521757  4.481327219396647e-05   154
# Total extinctions: 0
# Generation time: 2.116 sec (2.015 average)
#
#  ****** Running generation 155 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  155    48  -0.265006876211487  0.030628672986309113    78
#     35  155     2  -0.999952915521757  4.481327219396647e-05   155
# Total extinctions: 0
# Generation time: 2.358 sec (2.046 average)
#
#  ****** Running generation 156 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  156    48  -0.265006876211487  0.030636746125485614    79
#     35  156     2  -0.999952915521757  4.48132711123872e-05   156
# Total extinctions: 0
# Generation time: 1.959 sec (2.044 average)
#
#  ****** Running generation 157 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  157    48  -0.265006876211487  0.030634214370608426    80
#     35  157     2  -0.999952915521757  4.481327219396647e-05   157
# Total extinctions: 0
# Generation time: 1.982 sec (2.024 average)
#
#  ****** Running generation 158 ******
#
# Agent count: 50
# Population's average fitness: -0.97060 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  158    48  -0.265006876211487  0.030626976031937425    81
#     35  158     2  -0.999952915521757  4.481327219396647e-05   158
# Total extinctions: 0
# Generation time: 1.958 sec (2.029 average)
#
#  ****** Running generation 159 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  159    48  -0.265006876211487  0.03063858765343286    82
#     35  159     2  -0.999952915521757  4.481327219396647e-05   159
# Total extinctions: 0
# Generation time: 2.128 sec (2.040 average)
#
#  ****** Running generation 160 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  160    48  -0.265006876211487  0.030632078957404385    83
#     35  160     2  -0.999952915521757  4.481327219396647e-05   160
# Total extinctions: 0
# Generation time: 1.915 sec (2.031 average)
#
#  ****** Running generation 161 ******
#
# Agent count: 50
# Population's average fitness: -0.97056 stdev: 0.14391
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  161    48  -0.265006876211487  0.03066635499117354    84
#     35  161     2  -0.999952915521757  4.481327219396647e-05   161
# Total extinctions: 0
# Generation time: 1.959 sec (2.034 average)
#
#  ****** Running generation 162 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  162    48  -0.265006876211487  0.03063022313731789    85
#     35  162     2  -0.999952915521757  4.481327219396647e-05   162
# Total extinctions: 0
# Generation time: 1.947 sec (2.034 average)
#
#  ****** Running generation 163 ******
#
# Agent count: 50
# Population's average fitness: -0.97058 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  163    48  -0.265006876211487  0.03063955531809437    86
#     35  163     2  -0.999952915521757  4.481327219396647e-05   163
# Total extinctions: 0
# Generation time: 1.984 sec (2.031 average)
#
#  ****** Running generation 164 ******
#
# Agent count: 50
# Population's average fitness: -0.97056 stdev: 0.14391
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  164    48  -0.265006876211487  0.03066806741457173    87
#     35  164     2  -0.999952915521757  4.481327219396647e-05   164
# Total extinctions: 0
# Generation time: 2.040 sec (2.023 average)
#
#  ****** Running generation 165 ******
#
# Agent count: 50
# Population's average fitness: -0.96947 stdev: 0.14388
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  165    48  -0.265006876211487  0.03180348378123721    88
#     35  165     2  -0.999952915521757  4.481327219396647e-05   165
# Total extinctions: 0
# Generation time: 1.938 sec (1.981 average)
#
#  ****** Running generation 166 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  166    48  -0.265006876211487  0.03063546536113071    89
#     35  166     2  -0.999952915521757  4.481327219396647e-05   166
# Total extinctions: 0
# Generation time: 1.960 sec (1.981 average)
#
#  ****** Running generation 167 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  167    48  -0.265006876211487  0.03063484415402018    90
#     35  167     2  -0.999952915521757  4.481327219396647e-05   167
# Total extinctions: 0
# Generation time: 1.913 sec (1.974 average)
#
#  ****** Running generation 168 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  168    48  -0.265006876211487  0.030630767926922764    91
#     35  168     2  -0.999952915521757  4.481327219396647e-05   168
# Total extinctions: 0
# Generation time: 1.986 sec (1.977 average)
#
#  ****** Running generation 169 ******
#
# Agent count: 50
# Population's average fitness: -0.97059 stdev: 0.14392
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  169    48  -0.265006876211487  0.030631619406826016    92
#     35  169     2  -0.999952915521757  4.481327219396647e-05   169
# Total extinctions: 0
# Generation time: 1.999 sec (1.964 average)
#
#  ****** Running generation 170 ******
#
# Agent count: 50
# Population's average fitness: -0.97057 stdev: 0.14391
# Best fitness: -0.26501 - size: (17, 499) - species 11 - id 3019
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  170    48  -0.265006876211487  0.03065700518402059    93
#     35  170     2  -0.999952915521757  4.481327219396647e-05   170
# Total extinctions: 0
# Generation time: 2.005 sec (1.973 average)
#
#  ****** Running generation 171 ******
#
# Agent count: 50
# Population's average fitness: -0.95060 stdev: 0.19783
# Best fitness: 0.00000 - size: (23, 318) - species 11 - id 7350
# Best fitness ever found! : 0.0
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  171    48        0.0  0.05145948727226424     0
#     35  171     2  -0.999952915521757  4.481327219396647e-05   171
# Total extinctions: 0
# Generation time: 13.924 sec (3.170 average)
#
#  ****** Running generation 172 ******
#
# Agent count: 50
# Population's average fitness: -0.76527 stdev: 0.41918
# Best fitness: 0.00000 - size: (23, 318) - species 11 - id 7350
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  172    48        0.0  0.24450450230976395     1
#     35  172     2  -0.999952915521757  4.481327219396647e-05   172
# Total extinctions: 0
# Generation time: 14.049 sec (4.380 average)
#
#  ****** Running generation 173 ******
#
# Agent count: 50
# Population's average fitness: -0.16000 stdev: 0.36660
# Best fitness: 0.00000 - size: (23, 318) - species 11 - id 7350
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  173    48        0.0  0.875002519110788     2
#     35  173     2  -0.999952915521757  4.481327219396647e-05   173
# Total extinctions: 0
# Generation time: 16.332 sec (5.815 average)
#
#  ****** Running generation 174 ******
#
# Agent count: 50
# Population's average fitness: -0.18000 stdev: 0.38418
# Best fitness: 0.00000 - size: (22, 331) - species 11 - id 7433
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  174    48        0.0  0.8541687886161379     3
#     35  174     2  -0.999952915521757  4.481327219396647e-05   174
# Total extinctions: 0
# Generation time: 16.301 sec (7.241 average)
#
#  ****** Running generation 175 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.29999
# Best fitness: 0.00000 - size: (22, 331) - species 11 - id 7433
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  175    48        0.0  0.9375000180247426     4
#     35  175     2  -0.999952915521757  4.481327219396647e-05   175
# Total extinctions: 0
# Generation time: 16.856 sec (8.733 average)
#
#  ****** Running generation 176 ******
#
# Agent count: 50
# Population's average fitness: -0.12000 stdev: 0.32495
# Best fitness: 0.00000 - size: (22, 331) - species 11 - id 7433
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  176    48        0.0  0.9166678418448116     5
#     35  176     2  -0.999952915521757  4.41731819305069e-05   176
# Total extinctions: 0
# Generation time: 16.743 sec (10.211 average)
#
#  ****** Running generation 177 ******
#
# Agent count: 50
# Population's average fitness: -0.08000 stdev: 0.27129
# Best fitness: 0.00000 - size: (22, 331) - species 11 - id 7433
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  177    48        0.0  0.9583333359334514     6
#     35  177     2  -0.999952915521757  4.481327219396647e-05   177
# Total extinctions: 0
# Generation time: 18.347 sec (11.854 average)
#
#  ****** Running generation 178 ******
#
# Agent count: 50
# Population's average fitness: -0.12000 stdev: 0.32495
# Best fitness: 0.00000 - size: (22, 331) - species 11 - id 7433
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     11  178    48        0.0  0.9166679886573471     7
#     35  178     2  -0.999952915521757  4.481327219396647e-05   178
# Total extinctions: 0
# Generation time: 18.234 sec (13.479 average)
#
#  ****** Running generation 179 ******
#
# Agent count: 50

# %%
env.close()
