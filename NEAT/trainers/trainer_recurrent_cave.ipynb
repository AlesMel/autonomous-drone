# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
NUM_RUNS = 5
MAX_GENS = 5000

generation = 0
SAVE_INTERVAL = 50

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=4)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = '../result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x0000029DF24D9D80>
# Name of the behavior : ForestControl?team=0
# Number of observations :  5
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.RecurrentNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1

    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")

    while not done:
        for agent in decision_steps:
            if unity_to_neat_map[agent] not in removed_agents:
                obs = np.concatenate(decision_steps[agent].obs[:])
                nn_input =  np.asarray(obs)
                #print(f"NN INPUT: {nn_input}, agent: {agent}")
                #print(f"NN INPUT[0]: {nn_input[0]}, agent: {agent}")
                actions = policies[unity_to_neat_map[agent]].activate(nn_input)
                # print(f"NN OUTPUT: {actions}, agent: {agent}")
                continous_actions = np.asarray([actions])
                # continous_actions = np.clip(continous_actions, -1, 1)
                action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                env.set_action_for_agent(behavior_name=behavior_name, 
                                        agent_id=agent, 
                                        action=action_tuple)
        env.step()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        for agent in range(agent_count):
            if agent not in removed_agents:
                local_agent = neat_to_unity_map[agent]
                if local_agent in terminal_steps:
                    episode_rewards[agent] += terminal_steps[local_agent].reward
                    removed_agents.append(agent)
                    #print(f"Finished: {agent}")
                elif local_agent in decision_steps:
                    episode_rewards[agent] += decision_steps[local_agent].reward
                 

        if len(removed_agents) >= agent_count:
            done = True
    for i, (_, genome) in enumerate(genomes):
        # print(episode_rewards[i])
        genome.fitness = episode_rewards[i]
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"../checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    # print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = '../configs/config-recurrent-cave'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (60, 3644) - species 27 - id 27
# Best fitness ever found! : -0.0999996439277871
# Population of 106 members in 50 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0     2  -0.10000000132774071  1.6237540478858392e-10     0
#      2    0     2  -0.09999998603472886  1.5455387261664733e-08     0
#      3    0     2  -0.10000000111576515  3.7435096689186764e-10     0
#      4    0     2  -0.10000000149011612      0.0     0
#      5    0     2  -0.09999995763313568  4.3856980436185466e-08     0
#      6    0     2  -0.10000000148206074  8.05537581083371e-12     0
#      7    0     2  -0.10000000149008823  2.7894353493707058e-14     0
#      8    0     2  -0.10000000149011612      0.0     0
#      9    0     2  -0.10000000149011612      0.0     0
#     10    0     2  -0.10000000149011612      0.0     0
#     11    0     2  -0.10000000149011612      0.0     0
#     12    0     2  -0.10000000148940849  7.076284003204591e-13     0
#     13    0     2  -0.10000000149011612      0.0     0
#     14    0     2  -0.10000000149011612      0.0     0
#     15    0     2  -0.09999999853683939  2.9532767342743682e-09     0
#     16    0     2  -0.10000000149011612      0.0     0
#     17    0     2  -0.10000000149011612      0.0     0
#     18    0     2  -0.10000000149011612      0.0     0
#     19    0     2  -0.09999998056068804  2.092942807951914e-08     0
#     20    0     2  -0.10000000149011612      0.0     0
#     21    0     2  -0.09999999565836504  5.831751082041592e-09     0
#     22    0     2  -0.10000000149011612      0.0     0
******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4955    24  -0.09987030283107108  1.0725672920791629e-05  1761
#     49  4955    26  -0.09982984923261866  1.155646659067866e-05  2102
# Total extinctions: 0
# Generation time: 5.044 sec (5.249 average)
#
#  ****** Running generation 4956 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4956    23  -0.09987030283107108  1.0284941813112902e-05  1762
#     49  4956    27  -0.09982984923261866  1.1989555722305423e-05  2103
# Total extinctions: 0
# Generation time: 7.127 sec (5.421 average)
#
#  ****** Running generation 4957 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4957    24  -0.09987030283107108  1.0807973116616632e-05  1763
#     49  4957    26  -0.09982984923261866  1.1545981629904056e-05  2104
# Total extinctions: 0
# Generation time: 5.055 sec (5.455 average)
#
#  ****** Running generation 4958 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4958    23  -0.09987030283107108  1.0288495706167744e-05  1764
#     49  4958    27  -0.09982984923261866  1.2170625997398599e-05  2105
# Total extinctions: 0
# Generation time: 5.479 sec (5.439 average)
#
#  ****** Running generation 4959 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4959    24  -0.09987030283107108  1.0773668400340664e-05  1765
#     49  4959    26  -0.09982984923261866  1.155176927339352e-05  2106
# Total extinctions: 0
# Generation time: 4.896 sec (5.430 average)
#
#  ****** Running generation 4960 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4960    23  -0.09987030283107108  1.02790942671932e-05  1766
#     49  4960    27  -0.09982984923261866  1.2047366980294516e-05  2107
# Total extinctions: 0
# Generation time: 7.588 sec (5.713 average)
#
#  ****** Running generation 4961 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4961    24  -0.09987030283107108  1.0731466548868918e-05  1767
#     49  4961    26  -0.09982984923261866  1.1547620623275634e-05  2108
# Total extinctions: 0
# Generation time: 6.024 sec (5.836 average)
#
#  ****** Running generation 4962 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4962    23  -0.09987030283107108  1.029527522401763e-05  1768
#     49  4962    27  -0.09982984923261866  1.1993787440670034e-05  2109
# Total extinctions: 0
# Generation time: 5.973 sec (5.915 average)
#
#  ****** Running generation 4963 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4963    24  -0.09987030283107108  1.0727938099391876e-05  1769
#     49  4963    26  -0.09982984923261866  1.1625284129637703e-05  2110
# Total extinctions: 0
# Generation time: 6.153 sec (5.835 average)
#
#  ****** Running generation 4964 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4964    23  -0.09987030283107108  1.0281043162627124e-05  1770
#     49  4964    27  -0.09982984923261866  1.198987646471028e-05  2111
# Total extinctions: 0
# Generation time: 5.236 sec (5.857 average)
#
#  ****** Running generation 4965 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4965    24  -0.09987030283107108  1.0725959200930113e-05  1771
#     49  4965    26  -0.09982984923261866  1.1554320350201652e-05  2112
# Total extinctions: 0
# Generation time: 4.904 sec (5.843 average)
#
#  ****** Running generation 4966 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4966    23  -0.09987030283107108  1.0552568022612063e-05  1772
#     49  4966    27  -0.09982984923261866  1.199200482703e-05  2113
# Total extinctions: 0
# Generation time: 5.200 sec (5.651 average)
#
#  ****** Running generation 4967 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4967    24  -0.09987030283107108  1.1141084504132093e-05  1773
#     49  4967    26  -0.09982984923261866  1.1573820873717056e-05  2114
# Total extinctions: 0
# Generation time: 4.979 sec (5.643 average)
#
#  ****** Running generation 4968 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4968    23  -0.09987030283107108  1.0297026542302468e-05  1774
#     49  4968    27  -0.09982984923261866  1.2087470019767066e-05  2115
# Total extinctions: 0
# Generation time: 5.168 sec (5.612 average)
#
#  ****** Running generation 4969 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4969    24  -0.09987030283107108  1.0853000679308944e-05  1775
#     49  4969    26  -0.09982984923261866  1.1548764831101344e-05  2116
# Total extinctions: 0
# Generation time: 5.691 sec (5.692 average)
#
#  ****** Running generation 4970 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4970    23  -0.09987030283107108  1.0281263781011796e-05  1776
#     49  4970    27  -0.09982984923261866  1.1990081353399629e-05  2117
# Total extinctions: 0
# Generation time: 5.137 sec (5.447 average)
#
#  ****** Running generation 4971 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4971    24  -0.09987030283107108  1.0728354193995093e-05  1777
#     49  4971    26  -0.09982984923261866  1.1558069124173453e-05  2118
# Total extinctions: 0
# Generation time: 6.997 sec (5.544 average)
#
#  ****** Running generation 4972 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4972    23  -0.09987030283107108  1.0435576662540247e-05  1778
#     49  4972    27  -0.09982984923261866  1.1993028739082368e-05  2119
# Total extinctions: 0
# Generation time: 5.178 sec (5.464 average)
#
#  ****** Running generation 4973 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4973    24  -0.09987030283107108  1.0901220927714284e-05  1779
#     49  4973    26  -0.09982984923261866  1.1580387676346504e-05  2120
# Total extinctions: 0
# Generation time: 4.813 sec (5.330 average)
#
#  ****** Running generation 4974 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4974    23  -0.09987030283107108  1.0309595317725684e-05  1780
#     49  4974    27  -0.09982984923261866  1.199129962740908e-05  2121
# Total extinctions: 0
# Generation time: 5.061 sec (5.313 average)
#
#  ****** Running generation 4975 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4975    24  -0.09987030283107108  1.0970669351378914e-05  1781
#     49  4975    26  -0.09982984923261866  1.1551248155897142e-05  2122
# Total extinctions: 0
# Generation time: 7.776 sec (5.600 average)
#
#  ****** Running generation 4976 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4976    23  -0.09987030283107108  1.0312048811092489e-05  1782
#     49  4976    27  -0.09982984923261866  1.208782028744304e-05  2123
# Total extinctions: 0
# Generation time: 5.061 sec (5.586 average)
#
#  ****** Running generation 4977 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4977    24  -0.09987030283107108  1.0813820170249566e-05  1783
#     49  4977    26  -0.09982984923261866  1.1775260949878352e-05  2124
# Total extinctions: 0
# Generation time: 6.542 sec (5.742 average)
#
#  ****** Running generation 4978 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4978    23  -0.09987030283107108  1.0278627184237554e-05  1784
#     49  4978    27  -0.09982984923261866  1.203592196656611e-05  2125
# Total extinctions: 0
# Generation time: 6.132 sec (5.839 average)
#
#  ****** Running generation 4979 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     27  4979    24  -0.09987030283107108  1.0729544680468384e-05  1785
#     49  4979    26  -0.09982984923261866  1.1553344587578174e-05  2126
# Total extinctions: 0
# Generation time: 6.280 sec (5.898 average)
#
#  ****** Running generation 4980 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09983 - size: (58, 3182) - species 49 - id 130486

# %%
env.close()
# Out:
# ---------------------------------------------------------------------------
# UnityEnvironmentException                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 env.close()
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:427, in UnityEnvironment.close(self)
#     425     self._close()
#     426 else:
# --> 427     raise UnityEnvironmentException("No Unity environment is loaded.")
#
# UnityEnvironmentException: No Unity environment is loaded.
