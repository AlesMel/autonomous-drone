# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
NUM_RUNS = 1
MAX_GENS = 3000

generation = 0
SAVE_INTERVAL = 50

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=4)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = '../result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x0000024518509240>
# Name of the behavior : DroneControl?team=0
# Number of observations :  1
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.RecurrentNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1

    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")
    num_runs = 10
    for i in range(num_runs):
        env.reset()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        while not done:
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    nn_input =  np.asarray(decision_steps[agent].obs[:])
                    #print(f"NN INPUT: {nn_input}, agent: {agent}")
                    #print(f"NN INPUT[0]: {nn_input[0]}, agent: {agent}")
                    actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                    #print(f"NN OUTPUT: {actions}, agent: {agent}")
                    continous_actions = np.asarray([actions])
                    # continous_actions = np.clip(continous_actions, -1, 1)
                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                        #print(f"Finished: {agent}")
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward
                    

            if len(removed_agents) >= agent_count:
                done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i] / num_runs
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"../checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    # print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = '../configs/config-recurrent'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (4, 68) - species 1 - id 23
# Best fitness ever found! : -0.09999999884548902
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0    50  -0.09999999884548902  6.568176558197081e-11     0
# Total extinctions: 0
# Generation time: 4.087 sec
#
#  ****** Running generation 1 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (4, 66) - species 1 - id 56
# Best fitness ever found! : -0.09999964092082403
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    1    50  -0.09999964092082403  7.531579776509645e-09     0
# Total extinctions: 0
# Generation time: 3.035 sec (3.561 average)
#
#  ****** Running generation 2 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.09999 - size: (5, 65) - species 1 - id 103
# Best fitness ever found! : -0.09999385330421547
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    2    50  -0.09999385330421547  1.3819860650299276e-07     0
# Total extinctions: 0
# Generation time: 2.676 sec (3.266 average)
#
#  ****** Running generation 3 ******
#
# Agent count: 50
# Population's average fitness: -0.09998 stdev: 0.00011
# Best fitness: -0.09919 - size: (6, 63) - species 1 - id 180
# Best fitness ever found! : -0.09918961316609512
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    3    50  -0.09918961316609512  1.621388749169228e-05     0
# Total extinctions: 0
# Generation time: 1.767 sec (2.891 average)
#
#  ****** Running generation 4 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (5, 64) - species 1 - id 210
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    4    50  -0.09999831981787262  4.2360664295748585e-08     1
# Total extinctions: 0
# Generation time: 2.317 sec (2.777 average)
#
#  ****** Running generation 5 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (4, 59) - species 1 - id 249
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    5    50  -0.0999985862787229  1.0508036546452715e-07     2
# Total extinctions: 0
# Generation time: 2.112 sec (2.666 average)
#
#  ****** Running generation 6 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.09997 - size: (4, 60) - species 1 - id 335
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    6    50  -0.0999718270113135  7.382755736473623e-07     3
# Total extinctions: 0
# Generation time: 3.014 sec (2.716 average)
#
#  ****** Running generation 7 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00006
# Best fitness: -0.09959 - size: (4, 59) - species 1 - id 361
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    7    50  -0.09958607278401636  8.516347624026865e-06     4
# Total extinctions: 0
# Generation time: 2.294 sec (2.663 average)
#
#  ****** Running generation 8 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.09999 - size: (4, 59) - species 1 - id 361
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    8    50  -0.09998788531931077  4.30330539452628e-07     5
# Total extinctions: 0
# Generation time: 1.956 sec (2.584 average)
#
#  ****** Running generation 9 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (5, 58) - species 1 - id 469
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    9    50  -0.09999960757456412  1.9202224102454757e-08     6
# Total extinctions: 0
# Generation time: 4.118 sec (2.738 average)
#
#  ****** Running generation 10 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00003
# Best fitness: -0.09981 - size: (4, 57) - species 1 - id 488
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   10    50  -0.09980563237158221  4.067875794558362e-06     7
# Total extinctions: 0
# Generation time: 2.945 sec (2.623 average)
#
#  ****** Running generation 11 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.10000 - size: (6, 56) - species 1 - id 537
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   11    50  -0.09999719896206045  1.4810556393796137e-07     8
# Total extinctions: 0
# Generation time: 2.122 sec (2.532 average)
#
#  ****** Running generation 12 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00006
# Best fitness: -0.09957 - size: (6, 55) - species 1 - id 596
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   12    50  -0.09957464938524936  9.676382615661505e-06     9
# Total extinctions: 0
# Generation time: 2.468 sec (2.511 average)
#
#  ****** Running generation 13 ******
#
# Agent count: 50
# Population's average fitness: -0.09998 stdev: 0.00013
# Best fitness: -0.09906 - size: (7, 55) - species 1 - id 635
# Best fitness ever found! : -0.09906279491697205
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   13    50  -0.09906279491697205  2.048329053225273e-05     0
# Total extinctions: 0
# Generation time: 2.347 sec (2.569 average)
#
#  ****** Running generation 14 ******
#
# Agent count: 50
# Population's average fitness: -0.09998 stdev: 0.00012
# Best fitness: -0.09916 - size: (6, 55) - species 1 - id 704
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14    50  -0.09915654384468268  2.4982367504006175e-05     1
# Total extinctions: 0
# Generation time: 1.708 sec (2.508 average)
#
#  ****** Running generation 15 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00000
# Best fitness: -0.09998 - size: (7, 55) - species 1 - id 730
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   15    50  -0.09997910185115091  1.35400954667797e-06     2
# Total extinctions: 0
# Generation time: 1.608 sec (2.458 average)
#
#  ****** Running generation 16 ******
#
# Agent count: 50
# Population's average fitness: -0.09998 stdev: 0.00009
# Best fitness: -0.09951 - size: (6, 56) - species 1 - id 803
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   16    50  -0.09951343680222635  2.2472565188447202e-05     3
# Total extinctions: 0
# Generation time: 2.177 sec (2.374 average)
#
#  ****** Running generation 17 ******
#
# Agent count: 50
# Population's average fitness: -0.09984 stdev: 0.00091
# Best fitness: -0.09358 - size: (7, 52) - species 1 - id 859
# Best fitness ever found! : -0.09357623265968869
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   17    50  -0.09357623265968869  0.000162966058987829     0
# Total extinctions: 0
# Generation time: 1.861 sec (2.331 average)
#
#  ****** Running generation 18 ******
#
# Agent count: 50
# Population's average fitness: -0.10000 stdev: 0.00001
# Best fitness: -0.09994 - size: (6, 49) - species 1 - id 907
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   18    50  -0.09993625736617125  4.311910309473532e-06     1
# Total extinctions: 0
# Generation time: 1.957 sec (2.331 average)
#
#  ****** Running generation 19 ******
#
# Agent count: 50
# Population's average fitness: -0.09994 stdev: 0.00027
# Best fitness: -0.09819 - size: (6, 51) - species 1 - id 946
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   19    50  -0.09818965041611279  6.209648596768036e-05     2
# Total extinctions: 0
# Generation time: 2.169 sec (2.136 average)
#
#  ****** Running generation 20 ******
#
# Agent count: 50
# Population's average fitness: -0.09961 stdev: 0.00208
# Best fitness: -0.08585 - size: (7, 54) - species 1 - id 1006
# Best fitness ever found! : -0.08585297985118812
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   20    50  -0.08585297985118812  0.00038624660239294784     0
# Total extinctions: 0
# Generation time: 1.950 sec (2.037 average)
#
#  ****** Running generation 21 ******
#
# Agent count: 50
# Population's average fitness: -0.09994 stdev: 0.00041
# Best fitness: -0.09704 - size: (7, 53) - species 1 - id 1054
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   21    50  -0.09703504745484678  6.350570403493294e-05     1
# Total extinctions: 0
# Generation time: 1.545 sec (1.979 average)
#
#  ****** Running generation 22 ******
#
# Agent count: 50
# Population's average fitness: -0.09948 stdev: 0.00209
# Best fitness: -0.08772 - size: (5, 50) - species 1 - id 1097
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   22    50  -0.08771914444810953  0.0005235956194592772     2
# Total extinctions: 0
# Generation time: 2.188 sec (1.951 average)
#
#  ****** Running generation 23 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09977 - size: (4, 45) - species 1 - id 1121
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   23    50  -0.0997723184163438  9.109237313426055e-06     3
# Total extinctions: 0
# Generation time: 1.912 sec (1.907 average)
#
#  ****** Running generation 24 ******
#
# Agent count: 50
# Population's average fitness: -0.09999 stdev: 0.00004
# Best fitness: -0.09974 - size: (10, 62) - species 1 - id 1174
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   24    50  -0.09973913847579752  8.726775155731836e-06     4
# Total extinctions: 0
# Generation time: 1.594 sec (1.896 average)
#
#  ****** Running generation 25 ******
#
# Agent count: 50
# Population's average fitness: -0.09998 stdev: 0.00014
# Best fitness: -0.09902 - size: (10, 60) - species 1 - id 1230
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   25    50  -0.09902302063729848  2.4851749918189392e-05     5
# Total extinctions: 0
# Generation time: 2.752 sec (2.010 average)
#
#  ****** Running generation 26 ******
#
# Agent count: 50
# Population's average fitness: -0.09976 stdev: 0.00096
# Best fitness: -0.09451 - size: (11, 60) - species 1 - id 1288
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   26    50  -0.09451150157542543  0.0002418361430396032     6
# Total extinctions: 0
# Generation time: 2.219 sec (2.015 average)
#
#  ****** Running generation 27 ******
#
# Agent count: 50
# Population's average fitness: -0.09894 stdev: 0.00455
# Best fitness: -0.07379 - size: (12, 63) - species 1 - id 1319
# Best fitness ever found! : -0.07378588488209062
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   27    50  -0.07378588488209062  0.0010563655688963919     0
# Total extinctions: 0
# Generation time: 2.792 sec (2.108 average)
#
#  ****** Running generation 28 ******
#
# Agent count: 50
# Population's average fitness: -0.09937 stdev: 0.00196
# Best fitness: -0.08875 - size: (10, 60) - species 1 - id 1383
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   28    50  -0.08875077997217887  0.0006330776415981176     1
# Total extinctions: 0
# Generation time: 2.823 sec (2.194 average)
#
#  ****** Running generation 29 ******
#
# Agent count: 50
# Population's average fitness: -0.09955 stdev: 0.00121
# Best fitness: -0.09528 - size: (12, 60) - species 1 - id 1364
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   29    50  -0.09528488610958448  0.000449286087214687     2
# Total extinctions: 0
# Generation time: 2.875 sec (2.265 average)
#
#  ****** Running generation 30 ******
#
# Agent count: 50
# Population's average fitness: -0.09983 stdev: 0.00066
# Best fitness: -0.09631 - size: (12, 63) - species 1 - id 1444
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   30    50  -0.09631340060441289  0.0001731470559133419     3
# Total extinctions: 0
# Generation time: 2.406 sec (2.310 average)
#
#  ****** Running generation 31 ******
#
# Agent count: 50
# Population's average fitness: -0.09948 stdev: 0.00215
# Best fitness: -0.08679 - size: (12, 60) - species 1 - id 1524
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   31    50  -0.08679404471185989  0.000515472938486361     4
# Total extinctions: 0
# Generation time: 1.522 sec (2.308 average)
#
#  ****** Running generation 32 ******
#
# Agent count: 50
# Population's average fitness: -0.09849 stdev: 0.00630
# Best fitness: -0.05640 - size: (12, 62) - species 1 - id 1541
# Best fitness ever found! : -0.05639686802474699
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   32    50  -0.05639686802474699  0.0015082382263617022     0
# Total extinctions: 0
# Generation time: 1.370 sec (2.226 average)
#
#  ****** Running generation 33 ******
#
# Agent count: 50
# Population's average fitness: -0.09745 stdev: 0.01378
# Best fitness: -0.00259 - size: (5, 41) - species 1 - id 1630
# Best fitness ever found! : -0.0025936961988918482
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   33    50  -0.0025936961988918482  0.002549950202070342     0
# Total extinctions: 0
# Generation time: 2.061 sec (2.241 average)
#
#  ****** Running generation 34 ******
#
# Agent count: 50
# Population's average fitness: -0.09964 stdev: 0.00171
# Best fitness: -0.08837 - size: (13, 64) - species 1 - id 1671
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   34    50  -0.08837148533784785  0.00035778250517513877     1
# Total extinctions: 0
# Generation time: 1.368 sec (2.219 average)
#
#  ****** Running generation 35 ******
#
# Agent count: 50
# Population's average fitness: -0.09171 stdev: 0.05692
# Best fitness: 0.30668 - size: (6, 43) - species 1 - id 1725
# Best fitness ever found! : 0.30667677817109507
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   35    50  0.30667677817109507  0.008287393110011601     0
# Total extinctions: 0
# Generation time: 2.409 sec (2.184 average)
#
#  ****** Running generation 36 ******
#
# Agent count: 50
# Population's average fitness: -0.09994 stdev: 0.00023
# Best fitness: -0.09842 - size: (6, 42) - species 1 - id 1731
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   36    50  -0.09842421883295174  5.855118317826813e-05     1
# Total extinctions: 0
# Generation time: 2.417 sec (2.204 average)
#
#  ****** Running generation 37 ******
#
# Agent count: 50
# Population's average fitness: -0.09923 stdev: 0.00291
# Best fitness: -0.08390 - size: (8, 42) - species 1 - id 1788
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   37    50  -0.08389934063889086  0.0007691520757980158     2
# Total extinctions: 0
# Generation time: 2.222 sec (2.147 average)
#
#  ****** Running generation 38 ******
#
# Agent count: 50
# Population's average fitness: -0.09481 stdev: 0.02377
# Best fitness: 0.05798 - size: (14, 63) - species 1 - id 1847
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   38    50  0.05797650518361479  0.005188924608765855     3
# Total extinctions: 0
# Generation time: 2.698 sec (2.135 average)
#
#  ****** Running generation 39 ******
#
# Agent count: 50
# Population's average fitness: -0.09189 stdev: 0.03569
# Best fitness: 0.10215 - size: (15, 66) - species 1 - id 1877
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   39    50  0.10214739707298577  0.008107260058976037     4
# Total extinctions: 0
# Generation time: 2.538 sec (2.101 average)
#
#  ****** Running generation 40 ******
#
# Agent count: 50
# Population's average fitness: -0.07921 stdev: 0.13897
# Best fitness: 0.89338 - size: (12, 60) - species 1 - id 1944
# Best fitness ever found! : 0.89338182528154
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   40    50  0.89338182528154  0.020791415044617248     0
# Total extinctions: 0
# Generation time: 2.767 sec (2.137 average)
#
#  ****** Running generation 41 ******
#
# Agent count: 50
# Population's average fitness: -0.09923 stdev: 0.00258
# Best fitness: -0.08290 - size: (15, 65) - species 1 - id 2003
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   41    50  -0.0828962046536617  0.0007684123804508614     1
# Total extinctions: 0
# Generation time: 1.992 sec (2.184 average)
#
#  ****** Running generation 42 ******
#
# Agent count: 50
# Population's average fitness: -0.09743 stdev: 0.01047
# Best fitness: -0.04144 - size: (16, 64) - species 1 - id 2030
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   42    50  -0.04144246987998486  0.0025662162319128184     2
# Total extinctions: 0
# Generation time: 2.897 sec (2.337 average)
#
#  ****** Running generation 43 ******
#
# Agent count: 50
# Population's average fitness: -0.09848 stdev: 0.00472
# Best fitness: -0.07312 - size: (17, 64) - species 1 - id 2069
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   43    50  -0.0731222416041419  0.0015239000592896235     3
# Total extinctions: 0
# Generation time: 2.478 sec (2.379 average)
#
#  ****** Running generation 44 ******
#
# Agent count: 50
# Population's average fitness: -0.07859 stdev: 0.11630
# Best fitness: 0.70075 - size: (16, 64) - species 1 - id 2126
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   44    50  0.7007511034840718  0.021406335966220894     4
# Total extinctions: 0
# Generation time: 3.737 sec (2.615 average)
#
#  ****** Running generation 45 ******
#
# Agent count: 50
# Population's average fitness: -0.09892 stdev: 0.00308
# Best fitness: -0.08188 - size: (15, 64) - species 1 - id 2151
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   45    50  -0.08188382778316736  0.001081232042501809     5
# Total extinctions: 0
# Generation time: 1.862 sec (2.561 average)
#
#  ****** Running generation 46 ******
#
# Agent count: 50
# Population's average fitness: -0.09793 stdev: 0.01062
# Best fitness: -0.02794 - size: (15, 64) - species 1 - id 2151
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   46    50  -0.027939833281561733  0.002067320262515368     6
# Total extinctions: 0
# Generation time: 2.479 sec (2.567 average)
#
#  ****** Running generation 47 ******
#
# Agent count: 50
# Population's average fitness: -0.09981 stdev: 0.00106
# Best fitness: -0.09240 - size: (13, 61) - species 1 - id 2266
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   47    50  -0.09240380219416693  0.00019199941642172869     7
# Total extinctions: 0
# Generation time: 3.437 sec (2.689 average)
#
#  ****** Running generation 48 ******
#
# Agent count: 50
# Population's average fitness: -0.07982 stdev: 0.12135
# Best fitness: 0.76558 - size: (13, 58) - species 1 - id 2311
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   48    50  0.7655814222604022  0.020176106463165255     8
# Total extinctions: 0
# Generation time: 1.469 sec (2.566 average)
#
#  ****** Running generation 49 ******
#
# Agent count: 50
# Population's average fitness: -0.09929 stdev: 0.00189
# Best fitness: -0.08985 - size: (16, 57) - species 1 - id 2378
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   49    50  -0.08984618875547312  0.0007053596520109617     9
# Total extinctions: 0
# Generation time: 2.067 sec (2.518 average)
#
#  ****** Running generation 50 ******
#
# Agent count: 50
# Population's average fitness: -0.09436 stdev: 0.03768
# Best fitness: 0.16925 - size: (14, 64) - species 1 - id 2450
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   50    50  0.16924809493406676  0.005639550023958231    10
# Total extinctions: 0
# Generation time: 3.101 sec (2.552 average)
#
#  ****** Running generation 51 ******
#
# Agent count: 50
# Population's average fitness: -0.09705 stdev: 0.01172
# Best fitness: -0.03939 - size: (16, 60) - species 1 - id 2470
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   51    50  -0.039385410980321466  0.002947297627373821    11
# Total extinctions: 0
# Generation time: 2.497 sec (2.602 average)
#
#  ****** Running generation 52 ******
#
# Agent count: 50
# Population's average fitness: -0.09801 stdev: 0.00743
# Best fitness: -0.05752 - size: (14, 57) - species 1 - id 2533
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   52    50  -0.05752242479939014  0.00198582313075428    12
# Total extinctions: 0
# Generation time: 3.084 sec (2.621 average)
#
#  ****** Running generation 53 ******
#
# Agent count: 50
# Population's average fitness: -0.09785 stdev: 0.00756
# Best fitness: -0.05699 - size: (14, 59) - species 1 - id 2552
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   53    50  -0.05698520673031453  0.0021451554956095215    13
# Total extinctions: 0
# Generation time: 3.054 sec (2.679 average)
#
#  ****** Running generation 54 ******
#
# Agent count: 50
# Population's average fitness: -0.09196 stdev: 0.03646
# Best fitness: 0.15760 - size: (15, 56) - species 1 - id 2638
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   54    50  0.15759568214416503  0.008039390495171592    14
# Total extinctions: 0
# Generation time: 2.806 sec (2.586 average)
#
#  ****** Running generation 55 ******
#
# Agent count: 50
# Population's average fitness: -0.09803 stdev: 0.00588
# Best fitness: -0.06600 - size: (18, 68) - species 1 - id 2645
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   55    50  -0.06599835275119403  0.001971851269806618    15
# Total extinctions: 0
# Generation time: 2.390 sec (2.638 average)
#
#  ****** Running generation 56 ******
#
# Agent count: 50
# Population's average fitness: -0.09320 stdev: 0.02805
# Best fitness: 0.07428 - size: (17, 68) - species 1 - id 2737
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   56    50  0.07428344641703007  0.0067952019091127025    16
# Total extinctions: 0
# Generation time: 2.661 sec (2.657 average)
#
#  ****** Running generation 57 ******
#
# Agent count: 50
# Population's average fitness: -0.09613 stdev: 0.01275
# Best fitness: -0.02644 - size: (17, 64) - species 1 - id 2739
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   57    50  -0.026437398162670434  0.0038738864638744874    17
# Total extinctions: 0
# Generation time: 3.702 sec (2.683 average)
#
#  ****** Running generation 58 ******
#
# Agent count: 50
# Population's average fitness: -0.09269 stdev: 0.03362
# Best fitness: 0.09622 - size: (17, 64) - species 1 - id 2826
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   58    50  0.09622255575432064  0.007309232890020112    18
# Total extinctions: 0
# Generation time: 2.987 sec (2.835 average)
#
#  ****** Running generation 59 ******
#
# Agent count: 50
# Population's average fitness: -0.09911 stdev: 0.00388
# Best fitness: -0.07272 - size: (17, 59) - species 1 - id 2860
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   59    50  -0.07272335808665957  0.0008938972519770549    19
# Total extinctions: 0
# Generation time: 2.231 sec (2.851 average)
#
#  ****** Running generation 60 ******
#
# Agent count: 50
# Population's average fitness: -0.09784 stdev: 0.00929
# Best fitness: -0.03610 - size: (18, 62) - species 1 - id 2895
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   60    50  -0.0361045516882302  0.0021559890164764284    20
# Total extinctions: 0
# Generation time: 2.214 sec (2.763 average)
#
#  ****** Running generation 61 ******
#
# Agent count: 50
# Population's average fitness: -0.09765 stdev: 0.00786
# Best fitness: -0.05503 - size: (16, 62) - species 1 - id 2935
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   61    50  -0.05503329728894515  0.0023472804857283813    21
# Total extinctions: 0
# Generation time: 2.380 sec (2.751 average)
#
#  ****** Running generation 62 ******
#
# Agent count: 50
# Population's average fitness: -0.09615 stdev: 0.02344
# Best fitness: 0.06764 - size: (16, 62) - species 1 - id 2935
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   62    50  0.06764097755947722  0.0038524049005016076    22
# Total extinctions: 0
# Generation time: 2.548 sec (2.697 average)
#
#  ****** Running generation 63 ******
#
# Agent count: 50
# Population's average fitness: -0.09434 stdev: 0.02057
# Best fitness: 0.02804 - size: (16, 60) - species 1 - id 3051
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   63    50  0.028039469569921493  0.005662808289382551    23
# Total extinctions: 0
# Generation time: 2.357 sec (2.628 average)
#
#  ****** Running generation 64 ******
#
# Agent count: 50
# Population's average fitness: -0.09421 stdev: 0.02265
# Best fitness: 0.03478 - size: (16, 60) - species 1 - id 3051
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   64    50  0.034784050312010886  0.005793030199300844    24
# Total extinctions: 0
# Generation time: 2.008 sec (2.548 average)
#
#  ****** Running generation 65 ******
#
# Agent count: 50
# Population's average fitness: -0.09747 stdev: 0.00823
# Best fitness: -0.05724 - size: (16, 60) - species 1 - id 3149
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   65    50  -0.05724352800093584  0.0025334526614502473    25
# Total extinctions: 0
# Generation time: 2.894 sec (2.598 average)
#
#  ****** Running generation 66 ******
#
# Agent count: 50
# Population's average fitness: -0.09753 stdev: 0.01135
# Best fitness: -0.02488 - size: (15, 55) - species 1 - id 3210
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   66    50  -0.024882912717293947  0.00246841451126395    26
# Total extinctions: 0
# Generation time: 3.093 sec (2.642 average)
#
#  ****** Running generation 67 ******
#
# Agent count: 50
# Population's average fitness: -0.09838 stdev: 0.00760
# Best fitness: -0.04855 - size: (16, 57) - species 1 - id 3262
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   67    50  -0.04854560200983542  0.0016192132817736682    27
# Total extinctions: 0
# Generation time: 3.001 sec (2.572 average)
#
#  ****** Running generation 68 ******
#
# Agent count: 50
# Population's average fitness: -0.09919 stdev: 0.00257
# Best fitness: -0.08576 - size: (16, 53) - species 1 - id 3272
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   68    50  -0.08575740082305856  0.0008135065300684946    28
# Total extinctions: 0
# Generation time: 2.113 sec (2.484 average)
#
#  ****** Running generation 69 ******
#
# Agent count: 50
# Population's average fitness: -0.09840 stdev: 0.00812
# Best fitness: -0.04203 - size: (16, 55) - species 1 - id 3357
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   69    50  -0.04203112066606991  0.0015999162953421464    29
# Total extinctions: 0
# Generation time: 1.971 sec (2.458 average)
#
#  ****** Running generation 70 ******
#
# Agent count: 50
# Population's average fitness: -0.09870 stdev: 0.00685
# Best fitness: -0.05142 - size: (14, 49) - species 1 - id 3405
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   70    50  -0.05141793880611658  0.0012976294509796787    30
# Total extinctions: 0
# Generation time: 3.602 sec (2.597 average)
#
#  ****** Running generation 71 ******
#
# Agent count: 50
# Population's average fitness: -0.09276 stdev: 0.02997
# Best fitness: 0.10879 - size: (16, 53) - species 1 - id 3413
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   71    50  0.10878588315099477  0.007238233091624552    31
# Total extinctions: 0
# Generation time: 2.328 sec (2.592 average)
#
#  ****** Running generation 72 ******
#
# Agent count: 50
# Population's average fitness: -0.09774 stdev: 0.00882
# Best fitness: -0.04457 - size: (16, 55) - species 1 - id 3491
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   72    50  -0.04457121843006462  0.0022603536833723653    32
# Total extinctions: 0
# Generation time: 3.383 sec (2.675 average)
#
#  ****** Running generation 73 ******
#
# Agent count: 50
# Population's average fitness: -0.09813 stdev: 0.00857
# Best fitness: -0.04566 - size: (17, 53) - species 1 - id 3523
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   73    50  -0.04566484116949141  0.0018691230008631154    33
# Total extinctions: 0
# Generation time: 2.002 sec (2.640 average)
#
#  ****** Running generation 74 ******
#
# Agent count: 50
# Population's average fitness: -0.09749 stdev: 0.00779
# Best fitness: -0.05526 - size: (17, 60) - species 1 - id 3555
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   74    50  -0.05526474060025066  0.002513989308272152    34
# Total extinctions: 0
# Generation time: 2.398 sec (2.679 average)
#
#  ****** Running generation 75 ******
#
# Agent count: 50
# Population's average fitness: -0.09915 stdev: 0.00410
# Best fitness: -0.07091 - size: (19, 58) - species 1 - id 3615
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   75    50  -0.07090979044296546  0.0008456071586387393    35
# Total extinctions: 0
# Generation time: 1.607 sec (2.550 average)
#
#  ****** Running generation 76 ******
#
# Agent count: 50
# Population's average fitness: -0.09344 stdev: 0.02409
# Best fitness: 0.06759 - size: (17, 53) - species 1 - id 3652
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   76    30  0.06759326552273706  0.006559103051117093    36
#      2    0    20          0        0     0
# Total extinctions: 0
# Generation time: 2.415 sec (2.482 average)
#
#  ****** Running generation 77 ******
#
# Agent count: 50
# Population's average fitness: -0.09887 stdev: 0.00372
# Best fitness: -0.08217 - size: (18, 54) - species 2 - id 3707
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   77     6  -0.08587955668335781  0.0009075763041813123    37
#      2    1    44  -0.0821710828691721  0.0014708889504692624     0
# Total extinctions: 0
# Generation time: 1.681 sec (2.350 average)
#
#  ****** Running generation 78 ******
#
# Agent count: 50
# Population's average fitness: -0.09751 stdev: 0.00922
# Best fitness: -0.05341 - size: (19, 53) - species 1 - id 3749
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   78    26  -0.05340672989550512  0.013547169557582589    38
#      2    2    24  -0.06397975715954089  0.0009802521179427676     0
# Total extinctions: 0
# Generation time: 1.393 sec (2.278 average)
#
#  ****** Running generation 79 ******
#
# Agent count: 50
# Population's average fitness: -0.09861 stdev: 0.00620
# Best fitness: -0.05789 - size: (19, 51) - species 1 - id 3828
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   79    29  -0.05789130394987296  0.0018055101800012324    39
#      2    3    21  -0.08817929337965325  0.0009432332776468377     1
# Total extinctions: 0
# Generation time: 1.757 sec (2.257 average)
#
#  ****** Running generation 80 ******
#
# Agent count: 50
# Population's average fitness: -0.09790 stdev: 0.00656
# Best fitness: -0.07056 - size: (21, 55) - species 1 - id 3867
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   80    30  -0.07056257957810885  0.0023910804282893383    40
#      2    4    20  -0.0767143152654171  0.0017081190302178917     2
# Total extinctions: 0
# Generation time: 2.285 sec (2.125 average)
#
#  ****** Running generation 81 ******
#
# Agent count: 50
# Population's average fitness: -0.09927 stdev: 0.00394
# Best fitness: -0.07196 - size: (20, 56) - species 2 - id 3894
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   81    19  -0.0967396966763772  0.0002442567832988962    41
#      2    5    31  -0.07196313047315925  0.0014704117532753636     3
# Total extinctions: 0
# Generation time: 3.288 sec (2.221 average)
#
#  ****** Running generation 82 ******
#
# Agent count: 50
# Population's average fitness: -0.09805 stdev: 0.00729
# Best fitness: -0.05425 - size: (20, 54) - species 2 - id 3971
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   82    18  -0.08431343813426792  0.0012469857759420944    42
#      2    6    32  -0.05424738154397346  0.0023784301438186106     0
# Total extinctions: 0
# Generation time: 2.797 sec (2.162 average)
#
#  ****** Running generation 83 ******
#
# Agent count: 50
# Population's average fitness: -0.09523 stdev: 0.01833
# Best fitness: 0.02152 - size: (20, 54) - species 2 - id 4020
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   83    13  -0.08550800392058591  0.0013046724913596958    43
#      2    7    37  0.02151780710555613  0.006716360280204059     0
# Total extinctions: 0
# Generation time: 3.395 sec (2.302 average)
#
#  ****** Running generation 84 ******
#
# Agent count: 50
# Population's average fitness: -0.09211 stdev: 0.02393
# Best fitness: 0.04491 - size: (21, 50) - species 1 - id 4028
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   84    22  0.04491288419812918  0.011456484001755113    44
#      2    8    28  -0.025052252909154048  0.006643106476886498     1
# Total extinctions: 0
# Generation time: 3.008 sec (2.363 average)
#
#  ****** Running generation 85 ******
#
# Agent count: 50
# Population's average fitness: -0.09579 stdev: 0.02229
# Best fitness: 0.05849 - size: (21, 51) - species 1 - id 4096
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   85    34  0.05849148016500916  0.008432655990811375    45
#      2    9    16  -0.08967344909906387  0.000889948357132922     2
# Total extinctions: 0
# Generation time: 3.218 sec (2.524 average)
#
#  ****** Running generation 86 ******
#
# Agent count: 50
# Population's average fitness: -0.09331 stdev: 0.02796
# Best fitness: 0.05785 - size: (21, 51) - species 1 - id 4145
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   86    40  0.05785099396962323  0.009659477725437474    46
#      2   10    10  -0.09691640949095018  0.00039398788255841366     3
# Total extinctions: 0
# Generation time: 3.306 sec (2.613 average)
#
#  ****** Running generation 87 ******
#
# Agent count: 50
# Population's average fitness: -0.09574 stdev: 0.01660
# Best fitness: 0.00675 - size: (21, 53) - species 1 - id 4178
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   87    27  0.006751430733129382  0.003340767292910163    47
#      2   11    23  -0.0476472573056526  0.00792469492795149     4
# Total extinctions: 0
# Generation time: 2.868 sec (2.731 average)
#
#  ****** Running generation 88 ******
#
# Agent count: 50
# Population's average fitness: -0.09962 stdev: 0.00105
# Best fitness: -0.09410 - size: (20, 55) - species 2 - id 4217
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   88    22  -0.09763246766524389  0.00025841430007010613    48
#      2   12    28  -0.09410233874805271  0.000518969486818649     5
# Total extinctions: 0
# Generation time: 3.891 sec (2.981 average)
#
#  ****** Running generation 89 ******
#
# Agent count: 50
# Population's average fitness: -0.09780 stdev: 0.00610
# Best fitness: -0.07520 - size: (21, 52) - species 1 - id 4264
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   89    25  -0.07519625325803644  0.0025791085803719693    49
#      2   13    25  -0.07571639746893197  0.0019024852741072323     6
# Total extinctions: 0
# Generation time: 2.909 sec (3.096 average)
#
#  ****** Running generation 90 ******
#
# Agent count: 50
# Population's average fitness: -0.09316 stdev: 0.01872
# Best fitness: -0.00722 - size: (23, 52) - species 1 - id 4334
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   90    27  -0.007220858987420797  0.008144860105683827    50
#      2   14    23  -0.027686892647761852  0.0055406435605135085     7
# Total extinctions: 0
# Generation time: 2.448 sec (3.113 average)
#
#  ****** Running generation 91 ******
#
# Agent count: 50
# Population's average fitness: -0.09322 stdev: 0.02996
# Best fitness: 0.10543 - size: (24, 63) - species 2 - id 4362
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   91    17  -0.06835214697057382  0.0019692840892374386    51
#      2   15    33  0.10543301608413458  0.01243388364093731     0
# Total extinctions: 0
# Generation time: 3.467 sec (3.131 average)
#
#  ****** Running generation 92 ******
#
# Agent count: 50
# Population's average fitness: -0.09553 stdev: 0.01851
# Best fitness: -0.00434 - size: (20, 52) - species 2 - id 4435
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   92    11  -0.09936895318659644  5.426976335121125e-05    52
#      2   16    39  -0.004342234914656728  0.006747747367139081     1
# Total extinctions: 0
# Generation time: 2.926 sec (3.144 average)
#
#  ****** Running generation 93 ******
#
# Agent count: 50
# Population's average fitness: -0.08542 stdev: 0.09589
# Best fitness: 0.58556 - size: (20, 46) - species 1 - id 4396
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   93    29  0.5855622081784532  0.06258893044475533    53
#      2   17    21  -0.08530566759145586  0.0010445435215214044     2
# Total extinctions: 0
# Generation time: 4.106 sec (3.215 average)
#
#  ****** Running generation 94 ******
#
# Agent count: 50
# Population's average fitness: -0.09709 stdev: 0.00944
# Best fitness: -0.05441 - size: (20, 53) - species 2 - id 4493
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   94    23  -0.05491346202325076  0.002194304108022918    54
#      2   18    27  -0.054412465542554855  0.003902089307561196     3
# Total extinctions: 0
# Generation time: 3.557 sec (3.269 average)
#
#  ****** Running generation 95 ******
#
# Agent count: 50
# Population's average fitness: -0.09522 stdev: 0.02200
# Best fitness: 0.04564 - size: (19, 51) - species 2 - id 4569
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   95    20  -0.036712385294958946  0.0032556643998957885    55
#      2   19    30  0.04564252463169396  0.006086508940696594     4
# Total extinctions: 0
# Generation time: 3.295 sec (3.277 average)
#
#  ****** Running generation 96 ******
#
# Agent count: 50
# Population's average fitness: -0.09465 stdev: 0.01784
# Best fitness: 0.01617 - size: (19, 39) - species 1 - id 4581
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   96    30  0.016165033666038654  0.0099872427868659    56
#      2   20    20  -0.06408402024535462  0.0022654286635784837     5
# Total extinctions: 0
# Generation time: 3.622 sec (3.309 average)
#
#  ****** Running generation 97 ******
#
# Agent count: 50
# Population's average fitness: -0.09728 stdev: 0.01332
# Best fitness: -0.00551 - size: (19, 40) - species 1 - id 4645
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   97    35  -0.00551295269979164  0.003900707205987619    57
#      2   21    15  -0.08964293508324617  0.0009594203322246808     6
# Total extinctions: 0
# Generation time: 3.919 sec (3.414 average)
#
#  ****** Running generation 98 ******
#
# Agent count: 50
# Population's average fitness: -0.08151 stdev: 0.11815
# Best fitness: 0.74498 - size: (19, 53) - species 2 - id 4668
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   98    19  -0.09056219645426608  0.000543607317284242    58
#      2   22    31  0.7449801659473451  0.06036189746135593     0
# Total extinctions: 0
# Generation time: 4.306 sec (3.456 average)
#
#  ****** Running generation 99 ******
#
# Agent count: 50
# Population's average fitness: -0.09635 stdev: 0.01114
# Best fitness: -0.04598 - size: (18, 49) - species 2 - id 4749
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   99    21  -0.06326015717349946  0.003311180591203694    59
#      2   23    29  -0.04597949497401714  0.0038608748437577306     1
# Total extinctions: 0
# Generation time: 4.144 sec (3.579 average)
#
#  ****** Running generation 100 ******
#
# Agent count: 50
# Population's average fitness: -0.09963 stdev: 0.00083
# Best fitness: -0.09661 - size: (21, 46) - species 1 - id 4759
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  100    29  -0.09660695420461707  0.0006050372287294131    60
#      2   24    21  -0.09701538698554941  0.0002080700203981739     2
# Total extinctions: 0
# Generation time: 2.858 sec (3.620 average)
#
#  ****** Running generation 101 ******
#
# Agent count: 50
# Population's average fitness: -0.09805 stdev: 0.00781
# Best fitness: -0.04674 - size: (19, 54) - species 2 - id 4814
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  101    19  -0.08794537932844833  0.0007980615263474267    61
#      2   25    31  -0.04674210487864912  0.003532421962055707     3
# Total extinctions: 0
# Generation time: 2.484 sec (3.522 average)
#
#  ****** Running generation 102 ******
#
# Agent count: 50
# Population's average fitness: -0.09260 stdev: 0.03226
# Best fitness: 0.08249 - size: (19, 55) - species 2 - id 4820
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  102    13  -0.09093542486079968  0.0018173426722352393    62
#      2   26    37  0.08248734614899149  0.010815620089279582     4
# Total extinctions: 0
# Generation time: 2.004 sec (3.430 average)
#
#  ****** Running generation 103 ******
#
# Agent count: 50
# Population's average fitness: -0.09781 stdev: 0.00668
# Best fitness: -0.06851 - size: (24, 51) - species 1 - id 4905
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  103    26  -0.06850739280926063  0.004663438915567544    63
#      2   27    24  -0.08344690088415518  0.0013193321070146674     5
# Total extinctions: 0
# Generation time: 2.748 sec (3.294 average)
#
#  ****** Running generation 104 ******
#
# Agent count: 50
# Population's average fitness: -0.09479 stdev: 0.03514
# Best fitness: 0.15115 - size: (20, 54) - species 2 - id 4946
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  104    15  -0.09785840386175551  0.00023708920255584298    64
#      2   28    35  0.15114736165851358  0.010595530571863479     6
# Total extinctions: 0
# Generation time: 2.960 sec (3.234 average)
#
#  ****** Running generation 105 ******
#
# Agent count: 50
# Population's average fitness: -0.09742 stdev: 0.01187
# Best fitness: -0.01724 - size: (24, 51) - species 1 - id 4991
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  105    31  -0.017242763470858336  0.008010353306010493    65
#      2   29    19  -0.09691458556872021  0.0002532795724372594     7
# Total extinctions: 0
# Generation time: 2.180 sec (3.123 average)
#
#  ****** Running generation 106 ******
#
# Agent count: 50
# Population's average fitness: -0.09894 stdev: 0.00470
# Best fitness: -0.06776 - size: (25, 54) - species 1 - id 5079
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  106    33  -0.06776389311999083  0.001381560714335886    66
#      2   30    17  -0.09151578754244838  0.0005466933192630058     8
# Total extinctions: 0
# Generation time: 2.185 sec (2.979 average)
#
#  ****** Running generation 107 ******
#
# Agent count: 50
# Population's average fitness: -0.09975 stdev: 0.00059
# Best fitness: -0.09751 - size: (21, 56) - species 2 - id 5087
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  107    29  -0.09804215056938119  0.00024354478451948935    67
#      2   31    21  -0.0975145553908078  0.00025037868907805405     9
# Total extinctions: 0
# Generation time: 2.448 sec (2.832 average)
#
#  ****** Running generation 108 ******
#
# Agent count: 50
# Population's average fitness: -0.07895 stdev: 0.12317
# Best fitness: 0.77695 - size: (25, 52) - species 1 - id 5143
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  108    38  0.7769475646317006  0.03551434397580265    68
#      2   32    12  -0.09323441198212094  0.001078825163492253    10
# Total extinctions: 0
# Generation time: 2.624 sec (2.664 average)
#
#  ****** Running generation 109 ******
#
# Agent count: 50
# Population's average fitness: -0.09891 stdev: 0.00378
# Best fitness: -0.08079 - size: (24, 49) - species 1 - id 5205
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  109    35  -0.080786505743152  0.0012210164733231221    69
#      2   33    15  -0.0954273853392806  0.0006869327282275767    11
# Total extinctions: 0
# Generation time: 2.269 sec (2.476 average)
#
#  ****** Running generation 110 ******
#
# Agent count: 50
# Population's average fitness: -0.07561 stdev: 0.13023
# Best fitness: 0.83021 - size: (19, 49) - species 2 - id 5231
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  110    19  -0.06076675743097439  0.002873801309984436    70
#      2   34    31  0.8302051273174584  0.07460151333366552     0
# Total extinctions: 0
# Generation time: 3.708 sec (2.561 average)
#
#  ****** Running generation 111 ******
#
# Agent count: 50
# Population's average fitness: -0.09574 stdev: 0.01242
# Best fitness: -0.03948 - size: (23, 53) - species 2 - id 5290
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  111    15  -0.0693640077020973  0.0016623451851029702    71
#      2   35    35  -0.03947880075429566  0.005858328192139481     1
# Total extinctions: 0
# Generation time: 3.502 sec (2.663 average)
#
#  ****** Running generation 112 ******
#
# Agent count: 50
# Population's average fitness: -0.09211 stdev: 0.03185
# Best fitness: 0.11944 - size: (20, 48) - species 2 - id 5326
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  112    21  -0.050734587898477915  0.00867431416813473    72
#      2   36    29  0.11944456356577575  0.007551948116545443     2
# Total extinctions: 0
# Generation time: 2.652 sec (2.728 average)
#
#  ****** Running generation 113 ******
#
# Agent count: 50
# Population's average fitness: -0.09698 stdev: 0.01175
# Best fitness: -0.02015 - size: (24, 55) - species 2 - id 5391
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  113    12  -0.09919970004702919  0.00011893042256201636    73
#      2   37    38  -0.02014955934791942  0.0051229250767555745     3
# Total extinctions: 0
# Generation time: 1.736 sec (2.626 average)
#
#  ****** Running generation 114 ******
#
# Agent count: 50
# Population's average fitness: -0.09815 stdev: 0.00647
# Best fitness: -0.05812 - size: (25, 55) - species 2 - id 5435
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  114    13  -0.09423101078136824  0.0007467326957805859    74
#      2   38    37  -0.058119722083210944  0.0021932829226201656     4
# Total extinctions: 0
# Generation time: 1.666 sec (2.497 average)
#
#  ****** Running generation 115 ******
#
# Agent count: 50
# Population's average fitness: -0.09647 stdev: 0.01306
# Best fitness: -0.01423 - size: (21, 49) - species 2 - id 5473
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  115     9  -0.09726755378173949  0.0002682000902103632    75
#      2   39    41  -0.01423411127179861  0.00467656444858415     5
# Total extinctions: 0
# Generation time: 1.872 sec (2.466 average)
#
#  ****** Running generation 116 ******
#
# Agent count: 50
# Population's average fitness: -0.09927 stdev: 0.00197
# Best fitness: -0.08786 - size: (27, 60) - species 2 - id 5515
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  116    16  -0.0963622251409106  0.0006686013795220852    76
#      2   40    34  -0.08786336089242633  0.0007400395905855367     6
# Total extinctions: 0
# Generation time: 1.689 sec (2.417 average)
#
#  ****** Running generation 117 ******
#
# Agent count: 50
# Population's average fitness: -0.09876 stdev: 0.00456
# Best fitness: -0.07248 - size: (27, 51) - species 1 - id 5546
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  117    24  -0.07248402602272108  0.0018112535561447957    77
#      2   41    26  -0.08214298305683769  0.0009731771776622794     7
# Total extinctions: 0
# Generation time: 1.619 sec (2.334 average)
#
#  ****** Running generation 118 ******
#
# Agent count: 50
# Population's average fitness: -0.09127 stdev: 0.02811
# Best fitness: 0.02288 - size: (27, 50) - species 1 - id 5628
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  118    27  0.022875611018389464  0.010907767711826985    78
#      2   42    23  0.013447546446695924  0.006727872676399654     8
# Total extinctions: 0
# Generation time: 1.591 sec (2.230 average)
#
#  ****** Running generation 119 ******
#
# Agent count: 50
# Population's average fitness: -0.09870 stdev: 0.00470
# Best fitness: -0.06884 - size: (21, 48) - species 2 - id 5636
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  119    18  -0.0939366070262622  0.0004733043595853831    79
#      2   43    32  -0.0688443296821788  0.0022804636983752014     9
# Total extinctions: 0
# Generation time: 1.648 sec (2.168 average)
#
#  ****** Running generation 120 ******
#
# Agent count: 50
# Population's average fitness: -0.09759 stdev: 0.01039
# Best fitness: -0.03058 - size: (27, 53) - species 1 - id 5681
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  120    29  -0.03058024428319186  0.004770076968395931    80
#      2   44    21  -0.0721502786691417  0.001089558275841812    10
# Total extinctions: 0
# Generation time: 1.514 sec (1.949 average)
#
#  ****** Running generation 121 ******
#
# Agent count: 50
# Population's average fitness: -0.09517 stdev: 0.01698
# Best fitness: -0.01073 - size: (27, 49) - species 1 - id 5760
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  121    28  -0.010726138926111161  0.005048935407255109    81
#      2   45    22  -0.01675870902836323  0.004518507246565107    11
# Total extinctions: 0
# Generation time: 1.572 sec (1.756 average)
#
#  ****** Running generation 122 ******
#
# Agent count: 50
# Population's average fitness: -0.09713 stdev: 0.01152
# Best fitness: -0.02930 - size: (28, 53) - species 1 - id 5798
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  122    32  -0.029299114493187516  0.0038952471577020087    82
#      2   46    18  -0.06847093869000673  0.0015726880472619054    12
# Total extinctions: 0
# Generation time: 2.214 sec (1.712 average)
#
#  ****** Running generation 123 ******
#
# Agent count: 50
# Population's average fitness: -0.09592 stdev: 0.01090
# Best fitness: -0.03616 - size: (27, 53) - species 1 - id 5851
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  123    31  -0.036158881383016706  0.004831119796739863    83
#      2   47    19  -0.07475990282655402  0.0027323580635782996    13
# Total extinctions: 0
# Generation time: 1.667 sec (1.705 average)
#
#  ****** Running generation 124 ******
#
# Agent count: 50
# Population's average fitness: -0.09737 stdev: 0.00999
# Best fitness: -0.03170 - size: (24, 55) - species 2 - id 5824
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  124    19  -0.08624918208515737  0.0009897411459751787    84
#      2   48    31  -0.03169996850192547  0.005297793207756724    14
# Total extinctions: 0
# Generation time: 1.599 sec (1.698 average)
#
#  ****** Running generation 125 ******
#
# Agent count: 50
# Population's average fitness: -0.09260 stdev: 0.02805
# Best fitness: 0.07831 - size: (27, 67) - species 2 - id 5947
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  125    18  -0.019692262494936587  0.004574236137480536    85
#      2   49    32  0.07830930207855999  0.009138983212757967    15
# Total extinctions: 0
# Generation time: 3.638 sec (1.875 average)
#
#  ****** Running generation 126 ******
#
# Agent count: 50
# Population's average fitness: -0.09923 stdev: 0.00252
# Best fitness: -0.08478 - size: (26, 58) - species 2 - id 5995
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  126    20  -0.09490906735300086  0.0006501194591014559    86
#      2   50    30  -0.0847790950909257  0.0008368423907959555    16
# Total extinctions: 0
# Generation time: 1.962 sec (1.902 average)
#
#  ****** Running generation 127 ******
#
# Agent count: 50
# Population's average fitness: -0.09636 stdev: 0.01679
# Best fitness: 0.00790 - size: (32, 55) - species 1 - id 6014
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  127    33  0.007896104920655489  0.00858010194967257    87
#      2   51    17  -0.09239698371384293  0.00034952948776044435    17
# Total extinctions: 0
# Generation time: 1.501 sec (1.890 average)
#
#  ****** Running generation 128 ******
#
# Agent count: 50
# Population's average fitness: -0.09891 stdev: 0.00386
# Best fitness: -0.07702 - size: (33, 57) - species 1 - id 6072
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  128    28  -0.07702175918966532  0.001032772557876066    88
#      2   52    22  -0.08549567927839234  0.0012041783802865524    18
# Total extinctions: 0
# Generation time: 1.671 sec (1.898 average)
#
#  ****** Running generation 129 ******
#
# Agent count: 50

# %%
env.close()
