# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
def add_node(g, config, new_node_id=None, bias=None, response=None, aggregation=None, activation=None):
    if new_node_id is None:
        new_node_id = config.get_new_node_key(g.nodes)
    ng = g.create_node(config, new_node_id)
    g.nodes[new_node_id] = ng
    if bias is not None:
        ng.bias = bias
    if response is not None:
        ng.response = response
    if aggregation is not None:
        ng.aggregation = aggregation
    if activation is not None:
        ng.activation = activation
    return new_node_id, ng

# %%
import neat
from random import choice, gauss, random, uniform, randint
from neat.genome import DefaultGenome
from neat.genes import DefaultNodeGene, DefaultConnectionGene
from neat.config import ConfigParameter, write_pretty_params
from neat.genes import BaseGene
from neat.attributes import FloatAttribute, BoolAttribute, StringAttribute, BaseAttribute
from neat.activations import ActivationFunctionSet
from neat.aggregations import AggregationFunctionSet
from itertools import count

class FixedFloatAttribute(BaseAttribute):
    """
    Class for floating-point numeric attributes,
    such as the response of a node or the weight of a connection.
    """
    _config_items = {"init_mean": [float, None],
                     "init_stdev": [float, None],
                     "init_type": [str, 'gaussian'],
                     "replace_rate": [float, None],
                     "mutate_rate": [float, None],
                     "mutate_power": [float, None],
                     "max_value": [float, None],
                     "min_value": [float, None]}

    def clamp(self, value, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        return max(min(value, max_value), min_value)

    def init_value(self, config):
        mean = getattr(config, self.init_mean_name)
        stdev = getattr(config, self.init_stdev_name)
        init_type = getattr(config, self.init_type_name).lower()

        if ('gauss' in init_type) or ('normal' in init_type):
            return self.clamp(gauss(mean, stdev), config)

        if 'uniform' in init_type:
            min_value = max(getattr(config, self.min_value_name),
                            (mean - (2 * stdev)))
            max_value = min(getattr(config, self.max_value_name),
                            (mean + (2 * stdev)))
            return uniform(min_value, max_value)

        raise RuntimeError(f"Unknown init_type {getattr(config, self.init_type_name)!r} for {self.init_type_name!s}")

    def mutate_value(self, value, config):
        # mutate_rate is usually no lower than replace_rate, and frequently higher -
        # so put first for efficiency
        mutate_rate = getattr(config, self.mutate_rate_name)
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        delta = choice([min_value / 10, max_value / 10])
        r = random()
        if r < mutate_rate:
            mutate_power = getattr(config, self.mutate_power_name)
            mutation = (2 * random() - 1) * delta
            return  self.clamp(value + mutation, config)

        replace_rate = getattr(config, self.replace_rate_name)

        r = random()
        if r < replace_rate:
            return self.init_value(config)

        return value

    def validate(self, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        if max_value < min_value:
            raise RuntimeError("Invalid min/max configuration for {self.name}")

class FixedStructureNodeGene(BaseGene):
    _gene_attributes = [
                        FixedFloatAttribute('bias'),
                        FloatAttribute('response'),
                        StringAttribute('activation', options=''),
                        StringAttribute('aggregation', options='')]

    def distance(self, other, config):
        return 0.0

class FixedStructureConnectionGene(BaseGene):
    _gene_attributes = [FixedFloatAttribute('weight'),
                        BoolAttribute('enabled')]

    def mutate(self, config):
        # Mutate only weights
        a = self._gene_attributes[0]
        v = getattr(self, a.name)
        setattr(self, a.name, a.mutate_value(v, config))

    def distance(self, other, config):
        d = abs(self.weight - other.weight)
        return d
    
class FixedStructureGenomeConfig(object):
    __params = [ConfigParameter('feed_forward', bool),
                ConfigParameter('num_inputs', int),
                ConfigParameter('num_outputs', int),
                ConfigParameter('num_hidden', int),
                ConfigParameter('num_hidden_layers', int),
                ConfigParameter('initial_connection', str, 'full_direct'),
                ConfigParameter('conn_add_prob', float),
                ConfigParameter('conn_delete_prob', float),
                ConfigParameter('node_add_prob', float),
                ConfigParameter('node_delete_prob', float)]


    def __init__(self, params):
        # Create full set of available activation functions.
        self.activation_defs = ActivationFunctionSet()
        self.activation_options = params.get('activation_options', 'sigmoid').strip().split()
        self.aggregation_options = params.get('aggregation_options', 'sum').strip().split()
        self.aggregation_function_defs = AggregationFunctionSet()

        # Gather configuration data from the gene classes.
        self.node_gene_type = params['node_gene_type']
        self.__params += self.node_gene_type.get_config_params()
        self.connection_gene_type = params['connection_gene_type']
        self.__params += self.connection_gene_type.get_config_params()
        self.connection_fraction = None
        self.node_indexer = None
        self.structural_mutation_surer = 'false'

        # Use the configuration data to interpret the supplied parameters.
        for p in self.__params:
            setattr(self, p.name, p.interpret(params))

        # By convention, input pins have negative keys, and the output
        # pins have keys 0,1,...
        self.input_keys = [-i - 1 for i in range(self.num_inputs)]
        self.output_keys = [i for i in range(self.num_outputs)]

    def get_new_node_key(self, node_dict):
        if self.node_indexer is None:
            if node_dict:
                self.node_indexer = count(max(list(node_dict)) + 1)
            else:
                self.node_indexer = count(max(list(node_dict)) + 1)

        new_id = next(self.node_indexer)

        assert new_id not in node_dict

        return new_id
    
    def save(self, f):
        write_pretty_params(f, self, self.__params)

class FixedStructureGenome(object):
    @classmethod
    def parse_config(cls, param_dict):
        param_dict['node_gene_type'] = FixedStructureNodeGene
        param_dict['connection_gene_type'] = FixedStructureConnectionGene
        return FixedStructureGenomeConfig(param_dict)
    
    @classmethod
    def write_config(cls, f, config):
        config.save(f)

    def __init__(self, key):
        self.key = key
        self.connections = {}
        self.nodes = {}

        # Fitness results.
        self.fitness = None

    def mutate(self, config):
        """ Mutates this genome. """
        # Mutate connection genes.
        for cg in self.connections.values():
            cg.mutate(config)

        # Mutate node genes (bias, response, etc.).
        for ng in self.nodes.values():
            ng.mutate(config)

    def configure_crossover(self, genome1, genome2, config):
        """ Configure a new genome by crossover from two parent genomes. """
        if genome1.fitness > genome2.fitness:
            parent1, parent2 = genome1, genome2
        else:
            parent1, parent2 = genome2, genome1

        # Inherit connection genes
        for key, cg1 in parent1.connections.items():
            cg2 = parent2.connections.get(key)
            if cg2 is None:
                # Excess or disjoint gene: copy from the fittest parent.
                self.connections[key] = cg1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.connections[key] = cg1.crossover(cg2)
            self.connections[key].enabled = True

        # Inherit node genes
        parent1_set = parent1.nodes
        parent2_set = parent2.nodes

        for key, ng1 in parent1_set.items():
            ng2 = parent2_set.get(key)
            assert key not in self.nodes
            if ng2 is None:
                # Extra gene: copy from the fittest parent
                self.nodes[key] = ng1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.nodes[key] = ng1.crossover(ng2)

    def distance(self, other, config):
        return 0.0
    
    def size(self):
        """Returns genome 'complexity', taken to be (number of nodes, number of enabled connections)"""
        num_enabled_connections = sum([1 for cg in self.connections.values() if cg.enabled is True])
        return len(self.nodes), num_enabled_connections

    def __str__(self):
        s = f"Key: {self.key}\nFitness: {self.fitness}\nNodes:"
        for k, ng in self.nodes.items():
            s += f"\n\t{k} {ng!s}"
        s += "\nConnections:"
        connections = list(self.connections.values())
        connections.sort()
        for c in connections:
            s += "\n\t" + str(c)
        return s

    def configure_new(self, config):
        # Create node genes for the input and output nodes
        for node_key in config.input_keys + config.output_keys:
            self.nodes[node_key] = self.create_node(config, node_key)

        # Initialize list to keep track of nodes in the last layer (start with input layer)
        last_layer_nodes = config.input_keys

        # Add hidden nodes and layers
        # config.num_hidden now represents the number of neurons PER HIDDEN LAYER
        if config.num_hidden > 0 and config.num_hidden_layers > 0:
            for _ in range(config.num_hidden_layers):
                layer_node_ids = []
                for _ in range(config.num_hidden):  # Create the specified number of nodes for this layer
                    node_key = config.get_new_node_key(self.nodes)
                    self.nodes[node_key] = self.create_node(config, node_key)
                    layer_node_ids.append(node_key)
                
                # Connect all nodes from the last layer to the current layer's nodes
                for last_layer_node in last_layer_nodes:
                    for current_layer_node in layer_node_ids:
                        connection = self.create_connection(config, last_layer_node, current_layer_node)
                        self.connections[connection.key] = connection

                # Update last_layer_nodes to reflect the current layer for next iteration
                last_layer_nodes = layer_node_ids

            # Connect all nodes from the last hidden layer to the output nodes
            for hidden_node_id in last_layer_nodes:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, hidden_node_id, output_node_id)
                    self.connections[connection.key] = connection
        else:
            # If there are no hidden layers, connect input nodes directly to output nodes
            for input_node_id in config.input_keys:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, input_node_id, output_node_id)
                    self.connections[connection.key] = connection

    @staticmethod
    def create_node(config, node_id):
        node = FixedStructureNodeGene(node_id)
        node.init_attributes(config)
        return node

    @staticmethod
    def create_connection(config, input_id, output_id):
        connection = config.connection_gene_type((input_id, output_id))
        connection.init_attributes(config)
        return connection

# %%
NUM_RUNS = 1
MAX_GENS = 1000
generation = 0
SAVE_INTERVAL = 100

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=10)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = 'result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
out_mult = 1

behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000001AA821C92A0>
# Name of the behavior : DroneControl?team=0
# Number of observations :  1
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.FeedForwardNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1
    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")

    while not done:
        for agent in decision_steps:
            if unity_to_neat_map[agent] not in removed_agents:
                nn_input =  np.asarray(decision_steps[agent].obs[:])
                #print(f"NN INPUT: {nn_input}, agent: {agent}")
                actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                continous_actions = np.asarray([actions])
                #if unity_to_neat_map[agent] == 1:
                    #print(continous_actions)
                continous_actions = np.clip(continous_actions, -1, 1)
                #print(continous_actions)
                action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                env.set_action_for_agent(behavior_name=behavior_name, 
                                        agent_id=agent, 
                                        action=action_tuple)
        env.step()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        for agent in range(agent_count):
            if agent not in removed_agents:
                local_agent = neat_to_unity_map[agent]
                if local_agent in terminal_steps:
                    episode_rewards[agent] += terminal_steps[local_agent].reward
                    removed_agents.append(agent)
                    #print(f"Finished: {agent}")
                elif local_agent in decision_steps:
                    episode_rewards[agent] += decision_steps[local_agent].reward
        if len(removed_agents) >= agent_count:
            print(".") 
            done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i]
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    #pop.add_reporter(neat.Checkpointer(generation_interval=5, time_interval_seconds=100000, filename_prefix=file_name_prefix))
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = 'config_fixed'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.83630 stdev: 0.63058
# Best fitness: 3.09032 - size: (40, 300) - species 1 - id 50
# Best fitness ever found! : 3.090324201857584
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0    50  3.090324201857584  0.04002074609521284     0
# Total extinctions: 0
# Generation time: 3.128 sec
#
#  ****** Running generation 1 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.74407 stdev: 0.64396
# Best fitness: 3.09034 - size: (40, 300) - species 1 - id 50
# Best fitness ever found! : 3.0903432611448807
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    1    50  3.0903432611448807  0.06256921282547495     0
# Total extinctions: 0
# Generation time: 2.712 sec (2.920 average)
#
#  ****** Running generation 2 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.53866 stdev: 0.74477
# Best fitness: 3.09034 - size: (40, 300) - species 1 - id 50
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    2    50  3.0903432611448807  0.11278799917609726     1
# Total extinctions: 0
# Generation time: 3.171 sec (3.004 average)
#
#  ****** Running generation 3 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.56033 stdev: 0.79190
# Best fitness: 3.09034 - size: (40, 300) - species 1 - id 50
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    3    50  3.0903432611448807  0.1074905568668954     2
# Total extinctions: 0
# Generation time: 2.492 sec (2.876 average)
#
#  ****** Running generation 4 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.62347 stdev: 0.78488
# Best fitness: 3.09034 - size: (40, 300) - species 1 - id 50
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    4    50  3.0903432611448807  0.09205408134867689     3
# Total extinctions: 0
# Generation time: 3.086 sec (2.918 average)
#
#  ****** Running generation 5 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.17515 stdev: 1.40654
# Best fitness: 6.27729 - size: (40, 300) - species 1 - id 262
# Best fitness ever found! : 6.277288948069327
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    5    50  6.277288948069327  0.11334585751333216     0
# Total extinctions: 0
# Generation time: 3.072 sec (2.944 average)
#
#  ****** Running generation 6 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.21405 stdev: 1.75201
# Best fitness: 6.65046 - size: (40, 300) - species 1 - id 326
# Best fitness ever found! : 6.650463729307376
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    6    50  6.650463729307376  0.10273280724126985     0
# Total extinctions: 0
# Generation time: 2.554 sec (2.888 average)
#
#  ****** Running generation 7 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41745 stdev: 1.54936
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    7    50  6.650408809480496  0.0761460381995383     1
# Total extinctions: 0
# Generation time: 2.637 sec (2.857 average)
#
#  ****** Running generation 8 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.36043 stdev: 1.49371
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    8    50  6.650408809480496  0.0835991450779148     2
# Total extinctions: 0
# Generation time: 2.572 sec (2.825 average)
#
#  ****** Running generation 9 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.46798 stdev: 1.47481
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    9    50  6.650408809480496  0.069541570055022     3
# Total extinctions: 0
# Generation time: 2.454 sec (2.788 average)
#
#  ****** Running generation 10 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.29935 stdev: 1.49654
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   10    50  6.650408809480496  0.09158296051945711     4
# Total extinctions: 0
# Generation time: 2.278 sec (2.703 average)
#
#  ****** Running generation 11 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.53269 stdev: 1.46983
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   11    50  6.650408809480496  0.061082535396518374     5
# Total extinctions: 0
# Generation time: 2.447 sec (2.676 average)
#
#  ****** Running generation 12 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.44018 stdev: 1.66876
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   12    50  6.650408809480496  0.0731755983545791     6
# Total extinctions: 0
# Generation time: 2.649 sec (2.624 average)
#
#  ****** Running generation 13 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49099 stdev: 1.47882
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   13    50  6.650408809480496  0.0665333089220886     7
# Total extinctions: 0
# Generation time: 2.882 sec (2.663 average)
#
#  ****** Running generation 14 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.47643 stdev: 1.48126
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14    50  6.650408809480496  0.06843724746765192     8
# Total extinctions: 0
# Generation time: 2.556 sec (2.610 average)
#
#  ****** Running generation 15 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.47111 stdev: 1.52679
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   15    50  6.650408809480496  0.06913238879049938     9
# Total extinctions: 0
# Generation time: 2.949 sec (2.598 average)
#
#  ****** Running generation 16 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49920 stdev: 1.50821
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   16    50  6.650408809480496  0.06546004279340399    10
# Total extinctions: 0
# Generation time: 2.969 sec (2.639 average)
#
#  ****** Running generation 17 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.50908 stdev: 1.49094
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   17    50  6.650408809480496  0.06416873014186832    11
# Total extinctions: 0
# Generation time: 2.204 sec (2.596 average)
#
#  ****** Running generation 18 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.24249 stdev: 1.74650
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   18    50  6.650408809480496  0.09901605032277787    12
# Total extinctions: 0
# Generation time: 2.794 sec (2.618 average)
#
#  ****** Running generation 19 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.47135 stdev: 1.48838
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   19    50  6.650408809480496  0.0691005171353434    13
# Total extinctions: 0
# Generation time: 2.696 sec (2.642 average)
#
#  ****** Running generation 20 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.52889 stdev: 1.44747
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   20    50  6.650408809480496  0.06157933014750959    14
# Total extinctions: 0
# Generation time: 2.653 sec (2.680 average)
#
#  ****** Running generation 21 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.40747 stdev: 1.56317
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   21    50  6.650408809480496  0.0774505448982255    15
# Total extinctions: 0
# Generation time: 2.576 sec (2.693 average)
#
#  ****** Running generation 22 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.26885 stdev: 1.66202
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   22    50  6.650408809480496  0.09557040689529021    16
# Total extinctions: 0
# Generation time: 2.309 sec (2.659 average)
#
#  ****** Running generation 23 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.47798 stdev: 1.52495
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   23    50  6.650408809480496  0.06823455251419747    17
# Total extinctions: 0
# Generation time: 2.536 sec (2.624 average)
#
#  ****** Running generation 24 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57003 stdev: 1.45896
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   24    50  6.650408809480496  0.05620221476912976    18
# Total extinctions: 0
# Generation time: 2.806 sec (2.649 average)
#
#  ****** Running generation 25 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.44487 stdev: 1.63376
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   25    50  6.650408809480496  0.07256221264977827    19
# Total extinctions: 0
# Generation time: 2.205 sec (2.575 average)
#
#  ****** Running generation 26 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.48005 stdev: 1.64538
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   26    50  6.650408809480496  0.06796410890567472    20
# Total extinctions: 0
# Generation time: 2.491 sec (2.527 average)
#
#  ****** Running generation 27 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.62155 stdev: 1.45732
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   27    50  6.650408809480496  0.04946739342538436    21
# Total extinctions: 0
# Generation time: 2.227 sec (2.529 average)
#
#  ****** Running generation 28 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.43030 stdev: 1.65028
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   28    50  6.650408809480496  0.07446680851639785    22
# Total extinctions: 0
# Generation time: 2.236 sec (2.474 average)
#
#  ****** Running generation 29 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.35623 stdev: 1.60039
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   29    50  6.650408809480496  0.08414821284326247    23
# Total extinctions: 0
# Generation time: 2.277 sec (2.432 average)
#
#  ****** Running generation 30 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54546 stdev: 1.48458
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   30    50  6.650408809480496  0.059413984271404985    24
# Total extinctions: 0
# Generation time: 2.583 sec (2.425 average)
#
#  ****** Running generation 31 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.63540 stdev: 1.45966
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   31    50  6.650408809480496  0.047658036195711635    25
# Total extinctions: 0
# Generation time: 2.274 sec (2.394 average)
#
#  ****** Running generation 32 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.58135 stdev: 1.51611
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   32    50  6.650408809480496  0.054722969303528324    26
# Total extinctions: 0
# Generation time: 2.170 sec (2.380 average)
#
#  ****** Running generation 33 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.53397 stdev: 1.47637
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   33    50  6.650408809480496  0.06091611570408427    27
# Total extinctions: 0
# Generation time: 2.364 sec (2.363 average)
#
#  ****** Running generation 34 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.56913 stdev: 1.45500
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   34    50  6.650408809480496  0.05631958056145231    28
# Total extinctions: 0
# Generation time: 1.947 sec (2.277 average)
#
#  ****** Running generation 35 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.65810 stdev: 1.45791
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   35    50  6.650408809480496  0.04469002421640449    29
# Total extinctions: 0
# Generation time: 2.136 sec (2.271 average)
#
#  ****** Running generation 36 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.39624 stdev: 1.73099
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   36    50  6.650408809480496  0.0789187969304818    30
# Total extinctions: 0
# Generation time: 1.900 sec (2.211 average)
#
#  ****** Running generation 37 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.65082 stdev: 1.45536
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   37    50  6.650408809480496  0.045642152264015065    31
# Total extinctions: 0
# Generation time: 1.934 sec (2.182 average)
#
#  ****** Running generation 38 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41055 stdev: 1.59002
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   38    50  6.650408809480496  0.07704839434392032    32
# Total extinctions: 0
# Generation time: 1.907 sec (2.149 average)
#
#  ****** Running generation 39 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59621 stdev: 1.46837
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   39    50  6.650408809480496  0.05278078063135562    33
# Total extinctions: 0
# Generation time: 1.958 sec (2.117 average)
#
#  ****** Running generation 40 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49753 stdev: 1.49103
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   40    50  6.650408809480496  0.06567840144413227    34
# Total extinctions: 0
# Generation time: 2.213 sec (2.080 average)
#
#  ****** Running generation 41 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49173 stdev: 1.49205
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   41    50  6.650408809480496  0.06643721823193521    35
# Total extinctions: 0
# Generation time: 1.930 sec (2.046 average)
#
#  ****** Running generation 42 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.60706 stdev: 1.47809
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   42    50  6.650408809480496  0.05136259422496718    36
# Total extinctions: 0
# Generation time: 1.981 sec (2.027 average)
#
#  ****** Running generation 43 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57497 stdev: 1.46144
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   43    50  6.650408809480496  0.05555635309874539    37
# Total extinctions: 0
# Generation time: 2.004 sec (1.991 average)
#
#  ****** Running generation 44 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54463 stdev: 1.46672
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   44    50  6.650408809480496  0.05952253969082331    38
# Total extinctions: 0
# Generation time: 2.038 sec (2.000 average)
#
#  ****** Running generation 45 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.51552 stdev: 1.46346
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   45    50  6.650408809480496  0.06332680335859732    39
# Total extinctions: 0
# Generation time: 1.923 sec (1.979 average)
#
#  ****** Running generation 46 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.51139 stdev: 1.49429
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   46    50  6.650408809480496  0.06386675952302164    40
# Total extinctions: 0
# Generation time: 2.099 sec (1.999 average)
#
#  ****** Running generation 47 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.46131 stdev: 1.59691
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   47    50  6.650408809480496  0.0704127482123169    41
# Total extinctions: 0
# Generation time: 1.911 sec (1.996 average)
#
#  ****** Running generation 48 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.60791 stdev: 1.45771
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   48    50  6.650408809480496  0.05125032427482319    42
# Total extinctions: 0
# Generation time: 2.264 sec (2.032 average)
#
#  ****** Running generation 49 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59989 stdev: 1.45442
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   49    50  6.650408809480496  0.05229882584667043    43
# Total extinctions: 0
# Generation time: 1.975 sec (2.034 average)
#
#  ****** Running generation 50 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54955 stdev: 1.48489
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   50    50  6.650408809480496  0.058879232656337474    44
# Total extinctions: 0
# Generation time: 1.925 sec (2.005 average)
#
#  ****** Running generation 51 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59643 stdev: 1.46380
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   51    50  6.650408809480496  0.05275186628548886    45
# Total extinctions: 0
# Generation time: 2.158 sec (2.028 average)
#
#  ****** Running generation 52 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.64762 stdev: 1.45598
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   52    50  6.650408809480496  0.04606056486217281    46
# Total extinctions: 0
# Generation time: 1.873 sec (2.017 average)
#
#  ****** Running generation 53 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59565 stdev: 1.45583
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   53    50  6.650408809480496  0.05285382157572606    47
# Total extinctions: 0
# Generation time: 1.945 sec (2.011 average)
#
#  ****** Running generation 54 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59709 stdev: 1.46813
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   54    50  6.650408809480496  0.052664511800205274    48
# Total extinctions: 0
# Generation time: 1.921 sec (1.999 average)
#
#  ****** Running generation 55 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.48505 stdev: 1.52414
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   55    50  6.650408809480496  0.0673099587236144    49
# Total extinctions: 0
# Generation time: 2.082 sec (2.015 average)
#
#  ****** Running generation 56 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.39494 stdev: 1.63056
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   56    50  6.650408809480496  0.07908796518517794    50
# Total extinctions: 0
# Generation time: 2.148 sec (2.020 average)
#
#  ****** Running generation 57 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41910 stdev: 1.53448
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   57    50  6.650408809480496  0.07593106359571831    51
# Total extinctions: 0
# Generation time: 2.057 sec (2.035 average)
#
#  ****** Running generation 58 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.35395 stdev: 1.57512
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   58    50  6.650408809480496  0.08444600421527827    52
# Total extinctions: 0
# Generation time: 1.928 sec (2.001 average)
#
#  ****** Running generation 59 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54188 stdev: 1.45593
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   59    50  6.650408809480496  0.05988221613058608    53
# Total extinctions: 0
# Generation time: 1.943 sec (1.998 average)
#
#  ****** Running generation 60 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.50327 stdev: 1.50358
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   60    50  6.650408809480496  0.06492847697708994    54
# Total extinctions: 0
# Generation time: 1.973 sec (2.003 average)
#
#  ****** Running generation 61 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41943 stdev: 1.52797
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   61    50  6.650408809480496  0.07588787202460832    55
# Total extinctions: 0
# Generation time: 1.897 sec (1.977 average)
#
#  ****** Running generation 62 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.53889 stdev: 1.45406
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   62    50  6.650408809480496  0.06027304890326544    56
# Total extinctions: 0
# Generation time: 2.180 sec (2.007 average)
#
#  ****** Running generation 63 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.64802 stdev: 1.45573
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   63    50  6.650408809480496  0.04600809733176862    57
# Total extinctions: 0
# Generation time: 1.982 sec (2.011 average)
#
#  ****** Running generation 64 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54059 stdev: 1.48209
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   64    50  6.650408809480496  0.06004974882607143    58
# Total extinctions: 0
# Generation time: 1.965 sec (2.016 average)
#
#  ****** Running generation 65 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57624 stdev: 1.46309
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   65    50  6.650408809480496  0.055390601095453636    59
# Total extinctions: 0
# Generation time: 1.901 sec (1.997 average)
#
#  ****** Running generation 66 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.61254 stdev: 1.46018
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   66    50  6.650408809480496  0.05064526515173673    60
# Total extinctions: 0
# Generation time: 1.920 sec (1.975 average)
#
#  ****** Running generation 67 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.52788 stdev: 1.48540
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   67    50  6.650408809480496  0.06171127484697933    61
# Total extinctions: 0
# Generation time: 1.930 sec (1.962 average)
#
#  ****** Running generation 68 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.55084 stdev: 1.45735
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   68    50  6.650408809480496  0.05871066165471346    62
# Total extinctions: 0
# Generation time: 1.890 sec (1.958 average)
#
#  ****** Running generation 69 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59798 stdev: 1.45841
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   69    50  6.650408809480496  0.05254884357192603    63
# Total extinctions: 0
# Generation time: 1.915 sec (1.955 average)
#
#  ****** Running generation 70 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.52783 stdev: 1.49078
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   70    50  6.650408809480496  0.06171774073275747    64
# Total extinctions: 0
# Generation time: 1.921 sec (1.950 average)
#
#  ****** Running generation 71 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57238 stdev: 1.46149
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   71    50  6.650408809480496  0.05589499619016672    65
# Total extinctions: 0
# Generation time: 1.917 sec (1.952 average)
#
#  ****** Running generation 72 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.60485 stdev: 1.45556
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   72    50  6.650408809480496  0.05165112434709546    66
# Total extinctions: 0
# Generation time: 1.944 sec (1.928 average)
#
#  ****** Running generation 73 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57310 stdev: 1.46849
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   73    50  6.650408809480496  0.055801102368571484    67
# Total extinctions: 0
# Generation time: 2.097 sec (1.940 average)
#
#  ****** Running generation 74 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.61692 stdev: 1.46905
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   74    50  6.650408809480496  0.050073316335144065    68
# Total extinctions: 0
# Generation time: 1.936 sec (1.937 average)
#
#  ****** Running generation 75 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59792 stdev: 1.45697
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   75    50  6.650408809480496  0.05255654742594746    69
# Total extinctions: 0
# Generation time: 1.958 sec (1.943 average)
#
#  ****** Running generation 76 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.58777 stdev: 1.45590
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   76    50  6.650408809480496  0.053883941069754034    70
# Total extinctions: 0
# Generation time: 2.015 sec (1.952 average)
#
#  ****** Running generation 77 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.61534 stdev: 1.46106
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   77    50  6.650408809480496  0.050280292010466555    71
# Total extinctions: 0
# Generation time: 1.887 sec (1.948 average)
#
#  ****** Running generation 78 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.47472 stdev: 1.71028
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   78    50  6.650408809480496  0.0686598613848215    72
# Total extinctions: 0
# Generation time: 1.908 sec (1.950 average)
#
#  ****** Running generation 79 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.63240 stdev: 1.45734
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   79    50  6.650408809480496  0.04805020262207801    73
# Total extinctions: 0
# Generation time: 1.921 sec (1.950 average)
#
#  ****** Running generation 80 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.52342 stdev: 1.48928
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   80    50  6.650408809480496  0.06229418935111578    74
# Total extinctions: 0
# Generation time: 2.606 sec (2.019 average)
#
#  ****** Running generation 81 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57532 stdev: 1.45907
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   81    50  6.650408809480496  0.05551052810257557    75
# Total extinctions: 0
# Generation time: 1.971 sec (2.024 average)
#
#  ****** Running generation 82 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.50736 stdev: 1.55481
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   82    50  6.650408809480496  0.06439384898526557    76
# Total extinctions: 0
# Generation time: 1.854 sec (2.015 average)
#
#  ****** Running generation 83 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.62551 stdev: 1.46550
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   83    50  6.650408809480496  0.0489505821189262    77
# Total extinctions: 0
# Generation time: 2.125 sec (2.018 average)
#
#  ****** Running generation 84 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.63956 stdev: 1.45612
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   84    50  6.650408809480496  0.04711360417165966    78
# Total extinctions: 0
# Generation time: 1.891 sec (2.014 average)
#
#  ****** Running generation 85 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54881 stdev: 1.50452
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   85    50  6.650408809480496  0.05897559096106821    79
# Total extinctions: 0
# Generation time: 1.904 sec (2.008 average)
#
#  ****** Running generation 86 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.51731 stdev: 1.46281
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   86    50  6.650408809480496  0.06309356921180324    80
# Total extinctions: 0
# Generation time: 1.934 sec (2.000 average)
#
#  ****** Running generation 87 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.55643 stdev: 1.47521
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   87    50  6.650408809480496  0.05798045805553105    81
# Total extinctions: 0
# Generation time: 1.872 sec (1.999 average)
#
#  ****** Running generation 88 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.60814 stdev: 1.46850
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   88    50  6.650408809480496  0.051220824202120034    82
# Total extinctions: 0
# Generation time: 1.869 sec (1.995 average)
#
#  ****** Running generation 89 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.53411 stdev: 1.46313
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   89    50  6.650408809480496  0.06089764921583186    83
# Total extinctions: 0
# Generation time: 1.944 sec (1.997 average)
#
#  ****** Running generation 90 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41249 stdev: 1.54517
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   90    50  6.650408809480496  0.07679493229208431    84
# Total extinctions: 0
# Generation time: 4.307 sec (2.167 average)
#
#  ****** Running generation 91 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.46612 stdev: 1.51550
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   91    50  6.650408809480496  0.06978390833167185    85
# Total extinctions: 0
# Generation time: 1.902 sec (2.160 average)
#
#  ****** Running generation 92 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41747 stdev: 1.55499
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   92    50  6.650408809480496  0.07614328495895861    86
# Total extinctions: 0
# Generation time: 1.916 sec (2.166 average)
#
#  ****** Running generation 93 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49080 stdev: 1.49960
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   93    50  6.650408809480496  0.06655905630840095    87
# Total extinctions: 0
# Generation time: 1.877 sec (2.142 average)
#
#  ****** Running generation 94 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.50961 stdev: 1.47171
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   94    50  6.650408809480496  0.06409924422301229    88
# Total extinctions: 0
# Generation time: 2.187 sec (2.171 average)
#
#  ****** Running generation 95 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54875 stdev: 1.46990
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   95    50  6.650408809480496  0.05898344719306139    89
# Total extinctions: 0
# Generation time: 2.366 sec (2.217 average)
#
#  ****** Running generation 96 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.46757 stdev: 1.49765
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   96    50  6.650408809480496  0.06959529793962393    90
# Total extinctions: 0
# Generation time: 1.895 sec (2.213 average)
#
#  ****** Running generation 97 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.66878 stdev: 1.45768
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   97    50  6.650408809480496  0.04329428708347693    91
# Total extinctions: 0
# Generation time: 2.288 sec (2.255 average)
#
#  ****** Running generation 98 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49205 stdev: 1.56938
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   98    50  6.650408809480496  0.06639543873690809    92
# Total extinctions: 0
# Generation time: 1.905 sec (2.259 average)
#
#  ****** Running generation 99 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.44006 stdev: 1.62752
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   99    50  6.650408809480496  0.07319088574636064    93
# Total extinctions: 0
# Generation time: 2.020 sec (2.266 average)
#
#  ****** Running generation 100 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.50973 stdev: 1.53640
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  100    50  6.650408809480496  0.06408400153439262    94
# Total extinctions: 0
# Generation time: 2.341 sec (2.070 average)
#
#  ****** Running generation 101 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.51561 stdev: 1.47776
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  101    50  6.650408809480496  0.06331520290335292    95
# Total extinctions: 0
# Generation time: 1.972 sec (2.077 average)
#
#  ****** Running generation 102 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54264 stdev: 1.46571
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  102    50  6.650408809480496  0.05978235175974264    96
# Total extinctions: 0
# Generation time: 1.922 sec (2.077 average)
#
#  ****** Running generation 103 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.60045 stdev: 1.44906
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  103    50  6.650408809480496  0.05222594358712364    97
# Total extinctions: 0
# Generation time: 1.895 sec (2.079 average)
#
#  ****** Running generation 104 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.45907 stdev: 1.58488
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  104    50  6.650408809480496  0.07070569426455925    98
# Total extinctions: 0
# Generation time: 1.988 sec (2.059 average)
#
#  ****** Running generation 105 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.40472 stdev: 1.51046
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  105    50  6.650408809480496  0.07781054771502867    99
# Total extinctions: 0
# Generation time: 2.106 sec (2.033 average)
#
#  ****** Running generation 106 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.36140 stdev: 1.63488
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  106    50  6.650408809480496  0.08347222952640813   100
# Total extinctions: 0
# Generation time: 1.863 sec (2.030 average)
#
#  ****** Running generation 107 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.46766 stdev: 1.54082
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  107    50  6.650408809480496  0.06958315096196441   101
# Total extinctions: 0
# Generation time: 1.917 sec (1.993 average)
#
#  ****** Running generation 108 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.47374 stdev: 1.47816
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  108    50  6.650408809480496  0.06878808057613346   102
# Total extinctions: 0
# Generation time: 1.963 sec (1.999 average)
#
#  ****** Running generation 109 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.43871 stdev: 1.49500
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  109    50  6.650408809480496  0.07336742146687766   103
# Total extinctions: 0
# Generation time: 1.941 sec (1.991 average)
#
#  ****** Running generation 110 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.53777 stdev: 1.47053
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  110    50  6.650408809480496  0.060418606967373216   104
# Total extinctions: 0
# Generation time: 1.920 sec (1.949 average)
#
#  ****** Running generation 111 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.51695 stdev: 1.50275
# Best fitness: 6.65041 - size: (40, 300) - species 1 - id 326
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
# ...
# 	FixedStructureConnectionGene(key=(-5, 933), weight=0.0920280357381047, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 924), weight=0.21796373277144623, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 925), weight=-0.0891547284605344, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 926), weight=-0.055534453774254755, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 927), weight=0.21770969093537457, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 928), weight=-0.07949326410493963, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 929), weight=0.17584292445537467, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 930), weight=-0.14734808820272954, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 931), weight=0.08341142364206762, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 932), weight=-0.05987199818933154, enabled=True)
# 	FixedStructureConnectionGene(key=(-4, 933), weight=-0.03211925267848472, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 924), weight=0.028344891937838686, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 925), weight=0.20146179950367116, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 926), weight=-0.16264649709119028, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 927), weight=0.022669673199053268, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 928), weight=-0.15308236717090767, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 929), weight=-0.09517795858485861, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 930), weight=-0.15582430419297158, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 931), weight=0.008224031378640102, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 932), weight=0.06687911078486458, enabled=True)
# 	FixedStructureConnectionGene(key=(-3, 933), weight=-0.03566383055262823, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 924), weight=-0.04688525142615671, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 925), weight=0.10778893524814159, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 926), weight=-0.002148819781405681, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 927), weight=-0.10542168466919954, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 928), weight=0.2224667705818243, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 929), weight=0.1728718688220248, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 930), weight=-0.31672489799163384, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 931), weight=-0.22797845005072595, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 932), weight=0.17127457852481587, enabled=True)
# 	FixedStructureConnectionGene(key=(-2, 933), weight=0.003962039767052973, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 924), weight=-0.05415249512576794, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 925), weight=-0.13675779286800785, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 926), weight=0.022132188688236177, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 927), weight=-0.07167901842983021, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 928), weight=0.17135728781333587, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 929), weight=0.2015319790509091, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 930), weight=0.22660085819296563, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 931), weight=-0.24933143730187937, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 932), weight=-0.022358709094709203, enabled=True)
# 	FixedStructureConnectionGene(key=(-1, 933), weight=0.205566947114378, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 934), weight=-0.077349508806458, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 935), weight=0.027643373906921453, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 936), weight=-0.17417336134782319, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 937), weight=-0.00043162018840003924, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 938), weight=0.14836153076552133, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 939), weight=0.18041771907042026, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 940), weight=-0.2045099946433924, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 941), weight=0.24747683812300048, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 942), weight=0.03922772435141435, enabled=True)
# 	FixedStructureConnectionGene(key=(924, 943), weight=-0.19839336240216274, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 934), weight=-0.04556331759956819, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 935), weight=0.03785515799617746, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 936), weight=0.09101884249034552, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 937), weight=-0.2227558894352843, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 938), weight=-0.1569288171329064, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 939), weight=0.04821039084756819, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 940), weight=-0.04507231708846088, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 941), weight=-0.2546521568125841, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 942), weight=0.1542460890814027, enabled=True)
# 	FixedStructureConnectionGene(key=(925, 943), weight=-0.07763909528085478, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 934), weight=0.02073554672017739, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 935), weight=-0.1687229230106156, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 936), weight=-0.015856375552192374, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 937), weight=-0.05425300707683465, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 938), weight=0.016595608156160346, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 939), weight=0.18646285662437012, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 940), weight=-0.3088472064141371, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 941), weight=0.0056310660430112305, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 942), weight=-0.2442471688892114, enabled=True)
# 	FixedStructureConnectionGene(key=(926, 943), weight=-0.09628167470707051, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 934), weight=0.08422781330073298, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 935), weight=-0.05053145475865105, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 936), weight=0.12029625146555628, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 937), weight=0.05039968718941602, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 938), weight=-0.2790970886002773, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 939), weight=-0.3589937663084015, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 940), weight=0.08508209122380142, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 941), weight=-0.06197574380728478, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 942), weight=-0.21107156139302982, enabled=True)
# 	FixedStructureConnectionGene(key=(927, 943), weight=-0.005582595172292787, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 934), weight=0.030694587735008445, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 935), weight=-0.010902470325293463, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 936), weight=-0.0029330218604545024, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 937), weight=-0.025981999803016922, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 938), weight=-0.23936434241224525, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 939), weight=0.06009959475995724, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 940), weight=-0.1362514988687249, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 941), weight=-0.1391599455105071, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 942), weight=-0.17995360430125923, enabled=True)
# 	FixedStructureConnectionGene(key=(928, 943), weight=0.047851885164786244, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 934), weight=-0.11317403244968055, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 935), weight=0.023276364253104392, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 936), weight=0.16941702204527853, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 937), weight=0.07042424796177975, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 938), weight=-0.14518370221919613, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 939), weight=0.03845766851660104, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 940), weight=0.1606871182192361, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 941), weight=0.2129016578420849, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 942), weight=-0.058019530568294994, enabled=True)
# 	FixedStructureConnectionGene(key=(929, 943), weight=0.10272956031689118, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 934), weight=0.28210598371953954, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 935), weight=-0.0684889868952732, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 936), weight=-0.11197240337556744, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 937), weight=-0.014771596482809058, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 938), weight=-0.005285013195331069, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 939), weight=-0.0729380034188934, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 940), weight=0.11241523774444342, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 941), weight=0.21061865940617194, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 942), weight=-0.021024638142808943, enabled=True)
# 	FixedStructureConnectionGene(key=(930, 943), weight=-0.027257179138170985, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 934), weight=0.058690912095375115, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 935), weight=0.12213236289955218, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 936), weight=0.12970047478394853, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 937), weight=-0.05367532501706153, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 938), weight=0.27386078599068986, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 939), weight=-0.1505090390338018, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 940), weight=0.06038848606324951, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 941), weight=-0.05730395119447063, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 942), weight=0.035053659107120896, enabled=True)
# 	FixedStructureConnectionGene(key=(931, 943), weight=-0.013511696294721383, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 934), weight=-0.02865034131817911, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 935), weight=-0.17461725329823566, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 936), weight=0.21778172372547755, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 937), weight=0.10688210747066819, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 938), weight=0.09006126176331189, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 939), weight=0.14141718966506828, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 940), weight=0.09966104117453681, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 941), weight=-0.19461015209336638, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 942), weight=0.018550971549962506, enabled=True)
# 	FixedStructureConnectionGene(key=(932, 943), weight=-0.10898633352961687, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 934), weight=0.00870948412175269, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 935), weight=0.13818839266295124, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 936), weight=-0.23869138931783113, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 937), weight=0.15693918223357137, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 938), weight=-0.07846839066946514, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 939), weight=0.014832589398082519, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 940), weight=0.19710867199238513, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 941), weight=-0.09806965509821765, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 942), weight=0.08223402171998731, enabled=True)
# 	FixedStructureConnectionGene(key=(933, 943), weight=0.01992013294165578, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 0), weight=0.14958166220882085, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 1), weight=-0.02126340701304977, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 2), weight=0.08187257232284023, enabled=True)
# 	FixedStructureConnectionGene(key=(934, 3), weight=-0.15319548302806432, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 0), weight=0.02280710433743731, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 1), weight=-0.07454730182891639, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 2), weight=-0.1783431583638341, enabled=True)
# 	FixedStructureConnectionGene(key=(935, 3), weight=0.15682244169403176, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 0), weight=0.12341721439908926, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 1), weight=-0.17832353501894388, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 2), weight=0.07417436512104139, enabled=True)
# 	FixedStructureConnectionGene(key=(936, 3), weight=0.0023395333908544508, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 0), weight=-0.17996398436846248, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 1), weight=-0.1589064553095146, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 2), weight=-0.2703371800781085, enabled=True)
# 	FixedStructureConnectionGene(key=(937, 3), weight=-0.6050238277909609, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 0), weight=0.1959623285520906, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 1), weight=0.03772843645543714, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 2), weight=0.00713336620764881, enabled=True)
# 	FixedStructureConnectionGene(key=(938, 3), weight=-0.029114002262680433, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 0), weight=-0.07146114836333461, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 1), weight=-0.343378280305886, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 2), weight=0.09651565363860959, enabled=True)
# 	FixedStructureConnectionGene(key=(939, 3), weight=0.16467407751304697, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 0), weight=0.041718877521857836, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 1), weight=-0.0121519624209563, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 2), weight=0.0013822132296902184, enabled=True)
# 	FixedStructureConnectionGene(key=(940, 3), weight=0.02849672398019669, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 0), weight=0.14709600990254112, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 1), weight=0.020323297333882787, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 2), weight=-0.20552842184976194, enabled=True)
# 	FixedStructureConnectionGene(key=(941, 3), weight=-0.06983229276791673, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 0), weight=-0.30002539267838924, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 1), weight=-0.0997375013261924, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 2), weight=-0.07545604944634685, enabled=True)
# 	FixedStructureConnectionGene(key=(942, 3), weight=0.17116418121322574, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 0), weight=0.17951590867162015, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 1), weight=-0.1507826418292435, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 2), weight=-0.34481294709261695, enabled=True)
# 	FixedStructureConnectionGene(key=(943, 3), weight=-0.1527496318919843, enabled=True)
# Finished running!

# %%
env.close()

# %%
import visualize
with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    print('\nBest genome:\n{!s}'.format(genome))
print(genome.fitness)
config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'fixed_config')
visualize.draw_net(config, genome, True)
# Out:
# Best genome:
# (26595, <__main__.FixedStructureGenome object at 0x000001AAAC284F70>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 5
#       3     genome = pickle.load(f)
#       4     print('\nBest genome:\n{!s}'.format(genome))
# ----> 5 print(genome.fitness)
#       6 config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
#       7                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
#       8                     'fixed_config')
#       9 visualize.draw_net(config, genome, True)
#
# AttributeError: 'tuple' object has no attribute 'fitness'
