# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
def add_node(g, config, new_node_id=None, bias=None, response=None, aggregation=None, activation=None):
    if new_node_id is None:
        new_node_id = config.get_new_node_key(g.nodes)
    ng = g.create_node(config, new_node_id)
    g.nodes[new_node_id] = ng
    if bias is not None:
        ng.bias = bias
    if response is not None:
        ng.response = response
    if aggregation is not None:
        ng.aggregation = aggregation
    if activation is not None:
        ng.activation = activation
    return new_node_id, ng

# %%
import neat
from random import choice, gauss, random, uniform, randint
from neat.genome import DefaultGenome
from neat.genes import DefaultNodeGene, DefaultConnectionGene
from neat.config import ConfigParameter, write_pretty_params
from neat.genes import BaseGene
from neat.attributes import FloatAttribute, BoolAttribute, StringAttribute, BaseAttribute
from neat.activations import ActivationFunctionSet
from neat.aggregations import AggregationFunctionSet
from itertools import count

class FixedFloatAttribute(BaseAttribute):
    """
    Class for floating-point numeric attributes,
    such as the response of a node or the weight of a connection.
    """
    _config_items = {"init_mean": [float, None],
                     "init_stdev": [float, None],
                     "init_type": [str, 'gaussian'],
                     "replace_rate": [float, None],
                     "mutate_rate": [float, None],
                     "mutate_power": [float, None],
                     "max_value": [float, None],
                     "min_value": [float, None]}

    def clamp(self, value, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        return max(min(value, max_value), min_value)

    def init_value(self, config):
        mean = getattr(config, self.init_mean_name)
        stdev = getattr(config, self.init_stdev_name)
        init_type = getattr(config, self.init_type_name).lower()

        if ('gauss' in init_type) or ('normal' in init_type):
            return self.clamp(gauss(mean, stdev), config)

        if 'uniform' in init_type:
            min_value = max(getattr(config, self.min_value_name),
                            (mean - (2 * stdev)))
            max_value = min(getattr(config, self.max_value_name),
                            (mean + (2 * stdev)))
            return uniform(min_value, max_value)

        raise RuntimeError(f"Unknown init_type {getattr(config, self.init_type_name)!r} for {self.init_type_name!s}")

    def mutate_value(self, value, config):
        # mutate_rate is usually no lower than replace_rate, and frequently higher -
        # so put first for efficiency
        mutate_rate = getattr(config, self.mutate_rate_name)
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        delta = choice([min_value / 10, max_value / 10])
        r = random()
        if r < mutate_rate:
            mutate_power = getattr(config, self.mutate_power_name)
            mutation = (2 * random() - 1) * delta
            return  self.clamp(value + mutation, config)

        replace_rate = getattr(config, self.replace_rate_name)

        r = random()
        if r < replace_rate:
            return self.init_value(config)

        return value

    def validate(self, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        if max_value < min_value:
            raise RuntimeError("Invalid min/max configuration for {self.name}")

class FixedStructureNodeGene(BaseGene):
    _gene_attributes = [
                        FixedFloatAttribute('bias'),
                        FloatAttribute('response'),
                        StringAttribute('activation', options=''),
                        StringAttribute('aggregation', options='')]

    def distance(self, other, config):
        return 0.0

class FixedStructureConnectionGene(BaseGene):
    _gene_attributes = [FixedFloatAttribute('weight'),
                        BoolAttribute('enabled')]

    def mutate(self, config):
        # Mutate only weights
        a = self._gene_attributes[0]
        v = getattr(self, a.name)
        setattr(self, a.name, a.mutate_value(v, config))

    def distance(self, other, config):
        d = abs(self.weight - other.weight)
        return d
    
class FixedStructureGenomeConfig(object):
    __params = [ConfigParameter('feed_forward', bool),
                ConfigParameter('num_inputs', int),
                ConfigParameter('num_outputs', int),
                ConfigParameter('num_hidden', int),
                ConfigParameter('num_hidden_layers', int),
                ConfigParameter('initial_connection', str, 'full_direct'),
                ConfigParameter('conn_add_prob', float),
                ConfigParameter('conn_delete_prob', float),
                ConfigParameter('node_add_prob', float),
                ConfigParameter('node_delete_prob', float)]


    def __init__(self, params):
        # Create full set of available activation functions.
        self.activation_defs = ActivationFunctionSet()
        self.activation_options = params.get('activation_options', 'sigmoid').strip().split()
        self.aggregation_options = params.get('aggregation_options', 'sum').strip().split()
        self.aggregation_function_defs = AggregationFunctionSet()

        # Gather configuration data from the gene classes.
        self.node_gene_type = params['node_gene_type']
        self.__params += self.node_gene_type.get_config_params()
        self.connection_gene_type = params['connection_gene_type']
        self.__params += self.connection_gene_type.get_config_params()
        self.connection_fraction = None
        self.node_indexer = None
        self.structural_mutation_surer = 'false'

        # Use the configuration data to interpret the supplied parameters.
        for p in self.__params:
            setattr(self, p.name, p.interpret(params))

        # By convention, input pins have negative keys, and the output
        # pins have keys 0,1,...
        self.input_keys = [-i - 1 for i in range(self.num_inputs)]
        self.output_keys = [i for i in range(self.num_outputs)]

    def get_new_node_key(self, node_dict):
        if self.node_indexer is None:
            if node_dict:
                self.node_indexer = count(max(list(node_dict)) + 1)
            else:
                self.node_indexer = count(max(list(node_dict)) + 1)

        new_id = next(self.node_indexer)

        assert new_id not in node_dict

        return new_id
    
    def save(self, f):
        write_pretty_params(f, self, self.__params)

class FixedStructureGenome(object):
    @classmethod
    def parse_config(cls, param_dict):
        param_dict['node_gene_type'] = FixedStructureNodeGene
        param_dict['connection_gene_type'] = FixedStructureConnectionGene
        return FixedStructureGenomeConfig(param_dict)
    
    @classmethod
    def write_config(cls, f, config):
        config.save(f)

    def __init__(self, key):
        self.key = key
        self.connections = {}
        self.nodes = {}

        # Fitness results.
        self.fitness = None

    def mutate(self, config):
        """ Mutates this genome. """
        # Mutate connection genes.
        for cg in self.connections.values():
            cg.mutate(config)

        # Mutate node genes (bias, response, etc.).
        for ng in self.nodes.values():
            ng.mutate(config)

    def configure_crossover(self, genome1, genome2, config):
        """ Configure a new genome by crossover from two parent genomes. """
        if genome1.fitness > genome2.fitness:
            parent1, parent2 = genome1, genome2
        else:
            parent1, parent2 = genome2, genome1

        # Inherit connection genes
        for key, cg1 in parent1.connections.items():
            cg2 = parent2.connections.get(key)
            if cg2 is None:
                # Excess or disjoint gene: copy from the fittest parent.
                self.connections[key] = cg1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.connections[key] = cg1.crossover(cg2)
            self.connections[key].enabled = True

        # Inherit node genes
        parent1_set = parent1.nodes
        parent2_set = parent2.nodes

        for key, ng1 in parent1_set.items():
            ng2 = parent2_set.get(key)
            assert key not in self.nodes
            if ng2 is None:
                # Extra gene: copy from the fittest parent
                self.nodes[key] = ng1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.nodes[key] = ng1.crossover(ng2)

    def distance(self, other, config):
        return 0.0
    
    def size(self):
        """Returns genome 'complexity', taken to be (number of nodes, number of enabled connections)"""
        num_enabled_connections = sum([1 for cg in self.connections.values() if cg.enabled is True])
        return len(self.nodes), num_enabled_connections

    def __str__(self):
        s = f"Key: {self.key}\nFitness: {self.fitness}\nNodes:"
        for k, ng in self.nodes.items():
            s += f"\n\t{k} {ng!s}"
        s += "\nConnections:"
        connections = list(self.connections.values())
        connections.sort()
        for c in connections:
            s += "\n\t" + str(c)
        return s

    def configure_new(self, config):
        # Create node genes for the input and output nodes
        for node_key in config.input_keys + config.output_keys:
            self.nodes[node_key] = self.create_node(config, node_key)

        # Initialize list to keep track of nodes in the last layer (start with input layer)
        last_layer_nodes = config.input_keys

        # Add hidden nodes and layers
        # config.num_hidden now represents the number of neurons PER HIDDEN LAYER
        if config.num_hidden > 0 and config.num_hidden_layers > 0:
            for _ in range(config.num_hidden_layers):
                layer_node_ids = []
                for _ in range(config.num_hidden):  # Create the specified number of nodes for this layer
                    node_key = config.get_new_node_key(self.nodes)
                    self.nodes[node_key] = self.create_node(config, node_key)
                    layer_node_ids.append(node_key)
                
                # Connect all nodes from the last layer to the current layer's nodes
                for last_layer_node in last_layer_nodes:
                    for current_layer_node in layer_node_ids:
                        connection = self.create_connection(config, last_layer_node, current_layer_node)
                        self.connections[connection.key] = connection

                # Update last_layer_nodes to reflect the current layer for next iteration
                last_layer_nodes = layer_node_ids

            # Connect all nodes from the last hidden layer to the output nodes
            for hidden_node_id in last_layer_nodes:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, hidden_node_id, output_node_id)
                    self.connections[connection.key] = connection
        else:
            # If there are no hidden layers, connect input nodes directly to output nodes
            for input_node_id in config.input_keys:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, input_node_id, output_node_id)
                    self.connections[connection.key] = connection

    @staticmethod
    def create_node(config, node_id):
        node = FixedStructureNodeGene(node_id)
        node.init_attributes(config)
        return node

    @staticmethod
    def create_connection(config, input_id, output_id):
        connection = config.connection_gene_type((input_id, output_id))
        connection.init_attributes(config)
        return connection

# %%
NUM_RUNS = 1
MAX_GENS = 1000
generation = 0
SAVE_INTERVAL = 50

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=10)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = 'result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
out_mult = 1

behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000001C3B6A03D90>
# Name of the behavior : ForestControl?team=0
# Number of observations :  5
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.FeedForwardNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1
    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")

    while not done:
        for agent in decision_steps:
            if unity_to_neat_map[agent] not in removed_agents:
                obs = np.concatenate(decision_steps[agent].obs[:])
                nn_input =  np.asarray(obs)
                #print(f"NN INPUT: {nn_input}, agent: {agent}")
                actions = policies[unity_to_neat_map[agent]].activate(nn_input)
                continous_actions = np.asarray([actions])
                # if unity_to_neat_map[agent] == 1:
                #     print(continous_actions)
                continous_actions = np.clip(continous_actions, -1, 1)
                #print(continous_actions)
                action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                env.set_action_for_agent(behavior_name=behavior_name, 
                                        agent_id=agent, 
                                        action=action_tuple)
        env.step()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        for agent in range(agent_count):
            if agent not in removed_agents:
                local_agent = neat_to_unity_map[agent]
                if local_agent in terminal_steps:
                    episode_rewards[agent] += terminal_steps[local_agent].reward
                    removed_agents.append(agent)
                    #print(f"Finished: {agent}")
                elif local_agent in decision_steps:
                    episode_rewards[agent] += decision_steps[local_agent].reward
        if len(removed_agents) >= agent_count:
            print(".") 
            done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i]
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"forest-env-fixed-nn/checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    #pop.add_reporter(neat.Checkpointer(generation_interval=5, time_interval_seconds=100000, filename_prefix=file_name_prefix))
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = '../configs/config_fixed_forest'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# .
# Population's average fitness: -1.00000 stdev: 0.00000
# Best fitness: -1.00000 - size: (68, 580) - species 1 - id 1
# Best fitness ever found! : -1.0
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0    50       -1.0      0.0     0
# Total extinctions: 0
# Generation time: 3.042 sec
#
#  ****** Running generation 1 ******
#
# Agent count: 50
# .
# Population's average fitness: -1.00000 stdev: 0.00000
# Best fitness: -0.99997 - size: (68, 580) - species 1 - id 93
# Best fitness ever found! : -0.9999684483465192
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    1    50  -0.9999684483465192  6.310332513193018e-07     0
# Total extinctions: 0
# Generation time: 2.582 sec (2.812 average)
#
#  ****** Running generation 2 ******
#
# Agent count: 50
# .
# Population's average fitness: -1.00000 stdev: 0.00001
# Best fitness: -0.99993 - size: (68, 580) - species 1 - id 144
# Best fitness ever found! : -0.9999294825611287
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    2    50  -0.9999294825611287  3.0615199989592057e-06     0
# Total extinctions: 0
# Generation time: 1.449 sec (2.358 average)
#
#  ****** Running generation 3 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99996 stdev: 0.00023
# Best fitness: -0.99835 - size: (68, 580) - species 1 - id 189
# Best fitness ever found! : -0.9983540320136512
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    3    50  -0.9983540320136512  3.9830717225131096e-05     0
# Total extinctions: 0
# Generation time: 1.494 sec (2.142 average)
#
#  ****** Running generation 4 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99994 stdev: 0.00024
# Best fitness: -0.99835 - size: (68, 580) - species 1 - id 189
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    4    50  -0.9983540320136512  5.9124441022073704e-05     1
# Total extinctions: 0
# Generation time: 1.439 sec (2.001 average)
#
#  ****** Running generation 5 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99995 stdev: 0.00025
# Best fitness: -0.99835 - size: (68, 580) - species 1 - id 189
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    5    50  -0.9983540320136512  5.286501559742529e-05     2
# Total extinctions: 0
# Generation time: 1.225 sec (1.872 average)
#
#  ****** Running generation 6 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99989 stdev: 0.00032
# Best fitness: -0.99835 - size: (68, 580) - species 1 - id 189
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    6    50  -0.9983540320136512  0.00011069880149949807     3
# Total extinctions: 0
# Generation time: 1.318 sec (1.793 average)
#
#  ****** Running generation 7 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99990 stdev: 0.00038
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Best fitness ever found! : -0.9981620753937221
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    7    50  -0.9981620753937221  0.00010144207860418586     0
# Total extinctions: 0
# Generation time: 1.099 sec (1.706 average)
#
#  ****** Running generation 8 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99987 stdev: 0.00036
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    8    50  -0.9981620753937221  0.00012512603362424546     1
# Total extinctions: 0
# Generation time: 1.188 sec (1.649 average)
#
#  ****** Running generation 9 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99991 stdev: 0.00035
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    9    50  -0.9981620753937221  9.34393229776731e-05     2
# Total extinctions: 0
# Generation time: 1.018 sec (1.586 average)
#
#  ****** Running generation 10 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99991 stdev: 0.00034
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   10    50  -0.9981620753937221  8.578175242679453e-05     3
# Total extinctions: 0
# Generation time: 1.275 sec (1.409 average)
#
#  ****** Running generation 11 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99989 stdev: 0.00036
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   11    50  -0.9981620753937221  0.00010601192613890476     4
# Total extinctions: 0
# Generation time: 1.119 sec (1.263 average)
#
#  ****** Running generation 12 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99987 stdev: 0.00042
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   12    50  -0.9981620753937221  0.00013420848364731341     5
# Total extinctions: 0
# Generation time: 1.073 sec (1.225 average)
#
#  ****** Running generation 13 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99984 stdev: 0.00037
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   13    50  -0.9981620753937221  0.0001629029766847534     6
# Total extinctions: 0
# Generation time: 0.967 sec (1.172 average)
#
#  ****** Running generation 14 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99989 stdev: 0.00036
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14    50  -0.9981620753937221  0.00011059686053160878     7
# Total extinctions: 0
# Generation time: 1.386 sec (1.167 average)
#
#  ****** Running generation 15 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99989 stdev: 0.00035
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   15    50  -0.9981620753937221  0.00011320801462033625     8
# Total extinctions: 0
# Generation time: 1.116 sec (1.156 average)
#
#  ****** Running generation 16 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99988 stdev: 0.00036
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   16    50  -0.9981620753937221  0.00011991559995350176     9
# Total extinctions: 0
# Generation time: 1.284 sec (1.153 average)
#
#  ****** Running generation 17 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99985 stdev: 0.00037
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   17    50  -0.9981620753937221  0.00014778941801751877    10
# Total extinctions: 0
# Generation time: 1.828 sec (1.226 average)
#
#  ****** Running generation 18 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99988 stdev: 0.00036
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   18    50  -0.9981620753937221  0.0001179896808767289    11
# Total extinctions: 0
# Generation time: 1.186 sec (1.225 average)
#
#  ****** Running generation 19 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99988 stdev: 0.00037
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   19    50  -0.9981620753937221  0.00011585564964311512    12
# Total extinctions: 0
# Generation time: 1.268 sec (1.250 average)
#
#  ****** Running generation 20 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99990 stdev: 0.00035
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   20    50  -0.9981620753937221  0.00010097413384324572    13
# Total extinctions: 0
# Generation time: 1.317 sec (1.254 average)
#
#  ****** Running generation 21 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99991 stdev: 0.00035
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   21    50  -0.9981620753937221  8.951458841877091e-05    14
# Total extinctions: 0
# Generation time: 1.560 sec (1.299 average)
#
#  ****** Running generation 22 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99989 stdev: 0.00037
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   22    50  -0.9981620753937221  0.00011083313401893946    15
# Total extinctions: 0
# Generation time: 0.973 sec (1.289 average)
#
#  ****** Running generation 23 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99987 stdev: 0.00038
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   23    50  -0.9981620753937221  0.0001264292152839408    16
# Total extinctions: 0
# Generation time: 1.185 sec (1.310 average)
#
#  ****** Running generation 24 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99984 stdev: 0.00039
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   24    50  -0.9981620753937221  0.0001632178722428268    17
# Total extinctions: 0
# Generation time: 1.099 sec (1.282 average)
#
#  ****** Running generation 25 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99987 stdev: 0.00037
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   25    50  -0.9981620753937221  0.00013367644055439776    18
# Total extinctions: 0
# Generation time: 1.174 sec (1.287 average)
#
#  ****** Running generation 26 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99989 stdev: 0.00035
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   26    50  -0.9981620753937221  0.00010963058162516415    19
# Total extinctions: 0
# Generation time: 1.615 sec (1.320 average)
#
#  ****** Running generation 27 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99987 stdev: 0.00037
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   27    50  -0.9981620753937221  0.0001349631728139178    20
# Total extinctions: 0
# Generation time: 1.146 sec (1.252 average)
#
#  ****** Running generation 28 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99990 stdev: 0.00035
# Best fitness: -0.99816 - size: (68, 580) - species 1 - id 370
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   28    50  -0.9981620753937221  9.848516914634509e-05    21
# Total extinctions: 0
# Generation time: 1.032 sec (1.237 average)
#
#  ****** Running generation 29 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99980 stdev: 0.00055
# Best fitness: -0.99691 - size: (68, 580) - species 1 - id 1401
# Best fitness ever found! : -0.9969144331606898
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   29    50  -0.9969144331606898  0.0001956787767032342     0
# Total extinctions: 0
# Generation time: 1.142 sec (1.224 average)
#
#  ****** Running generation 30 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99987 stdev: 0.00050
# Best fitness: -0.99691 - size: (68, 580) - species 1 - id 1401
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   30    50  -0.9969144331606898  0.00012972745348927006     1
# Total extinctions: 0
# Generation time: 1.140 sec (1.206 average)
#
#  ****** Running generation 31 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99980 stdev: 0.00058
# Best fitness: -0.99691 - size: (68, 580) - species 1 - id 1401
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   31    50  -0.9969144331606898  0.0002007943160982073     2
# Total extinctions: 0
# Generation time: 1.093 sec (1.160 average)
#
#  ****** Running generation 32 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99979 stdev: 0.00058
# Best fitness: -0.99691 - size: (68, 580) - species 1 - id 1401
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   32    50  -0.9969144331606898  0.00021351233423172467     3
# Total extinctions: 0
# Generation time: 1.135 sec (1.176 average)
#
#  ****** Running generation 33 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99975 stdev: 0.00062
# Best fitness: -0.99691 - size: (68, 580) - species 1 - id 1401
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   33    50  -0.9969144331606898  0.00025223097303705977     4
# Total extinctions: 0
# Generation time: 1.087 sec (1.166 average)
#
#  ****** Running generation 34 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99982 stdev: 0.00054
# Best fitness: -0.99691 - size: (68, 580) - species 1 - id 1401
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   34    50  -0.9969144331606898  0.00017557165920778495     5
# Total extinctions: 0
# Generation time: 1.050 sec (1.161 average)
#
#  ****** Running generation 35 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99971 stdev: 0.00074
# Best fitness: -0.99679 - size: (68, 580) - species 1 - id 1701
# Best fitness ever found! : -0.9967853834311944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   35    50  -0.9967853834311944  0.00028651211858576886     0
# Total extinctions: 0
# Generation time: 1.693 sec (1.213 average)
#
#  ****** Running generation 36 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99981 stdev: 0.00064
# Best fitness: -0.99679 - size: (68, 580) - species 1 - id 1701
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   36    50  -0.9967853834311944  0.00018965822250482933     1
# Total extinctions: 0
# Generation time: 1.663 sec (1.218 average)
#
#  ****** Running generation 37 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99962 stdev: 0.00092
# Best fitness: -0.99594 - size: (68, 580) - species 1 - id 1809
# Best fitness ever found! : -0.9959384658438755
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   37    50  -0.9959384658438755  0.0003799759436030614     0
# Total extinctions: 0
# Generation time: 1.620 sec (1.265 average)
#
#  ****** Running generation 38 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99977 stdev: 0.00073
# Best fitness: -0.99594 - size: (68, 580) - species 1 - id 1809
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   38    50  -0.9959384658438755  0.0002286882505585508     1
# Total extinctions: 0
# Generation time: 1.332 sec (1.295 average)
#
#  ****** Running generation 39 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99972 stdev: 0.00082
# Best fitness: -0.99594 - size: (68, 580) - species 1 - id 1809
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   39    50  -0.9959384658438755  0.00027609114954463276     2
# Total extinctions: 0
# Generation time: 1.594 sec (1.341 average)
#
#  ****** Running generation 40 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99976 stdev: 0.00075
# Best fitness: -0.99594 - size: (68, 580) - species 1 - id 1809
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   40    50  -0.9959384658438755  0.0002359773234438256     3
# Total extinctions: 0
# Generation time: 1.595 sec (1.386 average)
#
#  ****** Running generation 41 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99970 stdev: 0.00077
# Best fitness: -0.99594 - size: (68, 580) - species 1 - id 1809
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   41    50  -0.9959384658438755  0.0003007463990358783     4
# Total extinctions: 0
# Generation time: 2.068 sec (1.484 average)
#
#  ****** Running generation 42 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99956 stdev: 0.00138
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Best fitness ever found! : -0.9915484344692231
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   42    50  -0.9915484344692231  0.00043699146584375015     0
# Total extinctions: 0
# Generation time: 1.372 sec (1.507 average)
#
#  ****** Running generation 43 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99957 stdev: 0.00133
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   43    50  -0.9915484344692231  0.00043013861717755564     1
# Total extinctions: 0
# Generation time: 1.618 sec (1.561 average)
#
#  ****** Running generation 44 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99960 stdev: 0.00130
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   44    50  -0.9915484344692231  0.00040063076377305773     2
# Total extinctions: 0
# Generation time: 1.158 sec (1.571 average)
#
#  ****** Running generation 45 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99954 stdev: 0.00138
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   45    50  -0.9915484344692231  0.00045928619854007646     3
# Total extinctions: 0
# Generation time: 1.268 sec (1.529 average)
#
#  ****** Running generation 46 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99968 stdev: 0.00130
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   46    50  -0.9915484344692231  0.0003177880577689418     4
# Total extinctions: 0
# Generation time: 1.072 sec (1.470 average)
#
#  ****** Running generation 47 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99966 stdev: 0.00130
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   47    50  -0.9915484344692231  0.0003429480380333638     5
# Total extinctions: 0
# Generation time: 1.167 sec (1.424 average)
#
#  ****** Running generation 48 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99958 stdev: 0.00135
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   48    50  -0.9915484344692231  0.0004185076002909405     6
# Total extinctions: 0
# Generation time: 1.453 sec (1.437 average)
#
#  ****** Running generation 49 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99972 stdev: 0.00130
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   49    50  -0.9915484344692231  0.0002834214498836918     7
# Total extinctions: 0
# Generation time: 1.074 sec (1.385 average)
#
#  ****** Running generation 50 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99967 stdev: 0.00130
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   50    50  -0.9915484344692231  0.00033144952606989353     8
# Total extinctions: 0
# Generation time: 1.560 sec (1.381 average)
#
#  ****** Running generation 51 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99965 stdev: 0.00131
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   51    50  -0.9915484344692231  0.000349438253144041     9
# Total extinctions: 0
# Generation time: 1.258 sec (1.300 average)
#
#  ****** Running generation 52 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00135
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   52    50  -0.9915484344692231  0.0003884630521102661    10
# Total extinctions: 0
# Generation time: 1.092 sec (1.272 average)
#
#  ****** Running generation 53 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99939 stdev: 0.00163
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   53    50  -0.9915484344692231  0.0006142997006114426    11
# Total extinctions: 0
# Generation time: 1.817 sec (1.292 average)
#
#  ****** Running generation 54 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99964 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   54    50  -0.9915484344692231  0.0003614217024101585    12
# Total extinctions: 0
# Generation time: 1.192 sec (1.295 average)
#
#  ****** Running generation 55 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99959 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   55    50  -0.9915484344692231  0.0004081536352771309    13
# Total extinctions: 0
# Generation time: 2.223 sec (1.391 average)
#
#  ****** Running generation 56 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99958 stdev: 0.00149
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   56    50  -0.9915484344692231  0.00041921230860964    14
# Total extinctions: 0
# Generation time: 1.122 sec (1.396 average)
#
#  ****** Running generation 57 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99966 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   57    50  -0.9915484344692231  0.00034468047851421435    15
# Total extinctions: 0
# Generation time: 1.268 sec (1.406 average)
#
#  ****** Running generation 58 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99964 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   58    50  -0.9915484344692231  0.00036230234037037956    16
# Total extinctions: 0
# Generation time: 1.080 sec (1.369 average)
#
#  ****** Running generation 59 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99964 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   59    50  -0.9915484344692231  0.00035632978384170233    17
# Total extinctions: 0
# Generation time: 1.013 sec (1.363 average)
#
#  ****** Running generation 60 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99952 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   60    50  -0.9915484344692231  0.00047788676736515434    18
# Total extinctions: 0
# Generation time: 1.554 sec (1.362 average)
#
#  ****** Running generation 61 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99945 stdev: 0.00157
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   61    50  -0.9915484344692231  0.0005549832575698632    19
# Total extinctions: 0
# Generation time: 1.153 sec (1.352 average)
#
#  ****** Running generation 62 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99954 stdev: 0.00145
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   62    50  -0.9915484344692231  0.0004594031683798905    20
# Total extinctions: 0
# Generation time: 1.085 sec (1.351 average)
#
#  ****** Running generation 63 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99963 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   63    50  -0.9915484344692231  0.00036656792405875827    21
# Total extinctions: 0
# Generation time: 1.117 sec (1.281 average)
#
#  ****** Running generation 64 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99957 stdev: 0.00144
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   64    50  -0.9915484344692231  0.00043103870932259536    22
# Total extinctions: 0
# Generation time: 1.085 sec (1.270 average)
#
#  ****** Running generation 65 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99962 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   65    50  -0.9915484344692231  0.00037885720278607593    23
# Total extinctions: 0
# Generation time: 1.086 sec (1.156 average)
#
#  ****** Running generation 66 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99962 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   66    50  -0.9915484344692231  0.0003835923358631588    24
# Total extinctions: 0
# Generation time: 1.074 sec (1.152 average)
#
#  ****** Running generation 67 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99957 stdev: 0.00142
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   67    50  -0.9915484344692231  0.00042565974844366306    25
# Total extinctions: 0
# Generation time: 1.113 sec (1.136 average)
#
#  ****** Running generation 68 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   68    50  -0.9915484344692231  0.00039267804925002814    26
# Total extinctions: 0
# Generation time: 1.200 sec (1.148 average)
#
#  ****** Running generation 69 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99947 stdev: 0.00151
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   69    50  -0.9915484344692231  0.000532860850574135    27
# Total extinctions: 0
# Generation time: 1.253 sec (1.172 average)
#
#  ****** Running generation 70 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99962 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   70    50  -0.9915484344692231  0.0003803060595802821    28
# Total extinctions: 0
# Generation time: 1.005 sec (1.117 average)
#
#  ****** Running generation 71 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00142
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   71    50  -0.9915484344692231  0.00038518414360166897    29
# Total extinctions: 0
# Generation time: 1.335 sec (1.135 average)
#
#  ****** Running generation 72 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99945 stdev: 0.00147
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   72    50  -0.9915484344692231  0.0005463535884310255    30
# Total extinctions: 0
# Generation time: 1.445 sec (1.171 average)
#
#  ****** Running generation 73 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99954 stdev: 0.00145
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   73    50  -0.9915484344692231  0.0004636501255252945    31
# Total extinctions: 0
# Generation time: 1.752 sec (1.235 average)
#
#  ****** Running generation 74 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99951 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   74    50  -0.9915484344692231  0.00048510833199355563    32
# Total extinctions: 0
# Generation time: 0.930 sec (1.219 average)
#
#  ****** Running generation 75 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   75    50  -0.9915484344692231  0.0003949393419414582    33
# Total extinctions: 0
# Generation time: 1.184 sec (1.229 average)
#
#  ****** Running generation 76 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   76    50  -0.9915484344692231  0.0003906851942560019    34
# Total extinctions: 0
# Generation time: 0.951 sec (1.217 average)
#
#  ****** Running generation 77 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99964 stdev: 0.00142
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   77    50  -0.9915484344692231  0.00036447788290905336    35
# Total extinctions: 0
# Generation time: 1.019 sec (1.207 average)
#
#  ****** Running generation 78 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99946 stdev: 0.00147
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   78    50  -0.9915484344692231  0.0005380010398563506    36
# Total extinctions: 0
# Generation time: 1.272 sec (1.215 average)
#
#  ****** Running generation 79 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99958 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   79    50  -0.9915484344692231  0.0004227878957422382    37
# Total extinctions: 0
# Generation time: 1.272 sec (1.217 average)
#
#  ****** Running generation 80 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99964 stdev: 0.00142
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   80    50  -0.9915484344692231  0.00036290647927161857    38
# Total extinctions: 0
# Generation time: 2.028 sec (1.319 average)
#
#  ****** Running generation 81 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99954 stdev: 0.00144
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   81    50  -0.9915484344692231  0.00046325483140063906    39
# Total extinctions: 0
# Generation time: 1.039 sec (1.289 average)
#
#  ****** Running generation 82 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99963 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   82    50  -0.9915484344692231  0.0003701222940449833    40
# Total extinctions: 0
# Generation time: 1.242 sec (1.269 average)
#
#  ****** Running generation 83 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99962 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   83    50  -0.9915484344692231  0.0003785592376394087    41
# Total extinctions: 0
# Generation time: 1.705 sec (1.264 average)
#
#  ****** Running generation 84 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99940 stdev: 0.00147
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   84    50  -0.9915484344692231  0.0006023782213802065    42
# Total extinctions: 0
# Generation time: 1.952 sec (1.367 average)
#
#  ****** Running generation 85 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99954 stdev: 0.00146
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   85    50  -0.9915484344692231  0.0004567344725753264    43
# Total extinctions: 0
# Generation time: 1.508 sec (1.399 average)
#
#  ****** Running generation 86 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99959 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   86    50  -0.9915484344692231  0.00040689892014766915    44
# Total extinctions: 0
# Generation time: 1.358 sec (1.440 average)
#
#  ****** Running generation 87 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99957 stdev: 0.00144
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   87    50  -0.9915484344692231  0.00042793862903611757    45
# Total extinctions: 0
# Generation time: 1.468 sec (1.485 average)
#
#  ****** Running generation 88 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99954 stdev: 0.00145
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   88    50  -0.9915484344692231  0.00046123446595591755    46
# Total extinctions: 0
# Generation time: 1.263 sec (1.484 average)
#
#  ****** Running generation 89 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00142
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   89    50  -0.9915484344692231  0.0003917518389817687    47
# Total extinctions: 0
# Generation time: 1.141 sec (1.470 average)
#
#  ****** Running generation 90 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00142
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   90    50  -0.9915484344692231  0.0003879682361794812    48
# Total extinctions: 0
# Generation time: 1.208 sec (1.388 average)
#
#  ****** Running generation 91 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99958 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   91    50  -0.9915484344692231  0.000417764877548632    49
# Total extinctions: 0
# Generation time: 1.586 sec (1.443 average)
#
#  ****** Running generation 92 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99960 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   92    50  -0.9915484344692231  0.00039673493791525516    50
# Total extinctions: 0
# Generation time: 1.485 sec (1.467 average)
#
#  ****** Running generation 93 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99955 stdev: 0.00144
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   93    50  -0.9915484344692231  0.0004497862009675835    51
# Total extinctions: 0
# Generation time: 1.123 sec (1.409 average)
#
#  ****** Running generation 94 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99955 stdev: 0.00144
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   94    50  -0.9915484344692231  0.00045063458535576917    52
# Total extinctions: 0
# Generation time: 1.384 sec (1.352 average)
#
#  ****** Running generation 95 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99958 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   95    50  -0.9915484344692231  0.0004163835344718203    53
# Total extinctions: 0
# Generation time: 1.399 sec (1.341 average)
#
#  ****** Running generation 96 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99952 stdev: 0.00143
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   96    50  -0.9915484344692231  0.0004841869411407185    54
# Total extinctions: 0
# Generation time: 1.287 sec (1.334 average)
#
#  ****** Running generation 97 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99958 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   97    50  -0.9915484344692231  0.0004196111655603296    55
# Total extinctions: 0
# Generation time: 1.030 sec (1.290 average)
#
#  ****** Running generation 98 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99961 stdev: 0.00141
# Best fitness: -0.99155 - size: (68, 580) - species 1 - id 2041
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   98    50  -0.9915484344692231  0.00038731604296005084    56
# Total extinctions: 0
# Generation time: 2.242 sec (1.388 average)
#
#  ****** Running generation 99 ******

# %%
env.close()

# %%
import NEAT.trainers.visualize as visualize
with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    print('\nBest genome:\n{!s}'.format(genome))
print(genome.fitness)
config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'fixed_config')
visualize.draw_net(config, genome, True)
# Out:
# Best genome:
# (26595, <__main__.FixedStructureGenome object at 0x000001AAAC284F70>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 5
#       3     genome = pickle.load(f)
#       4     print('\nBest genome:\n{!s}'.format(genome))
# ----> 5 print(genome.fitness)
#       6 config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
#       7                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
#       8                     'fixed_config')
#       9 visualize.draw_net(config, genome, True)
#
# AttributeError: 'tuple' object has no attribute 'fitness'
