# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
def add_node(g, config, new_node_id=None, bias=None, response=None, aggregation=None, activation=None):
    if new_node_id is None:
        new_node_id = config.get_new_node_key(g.nodes)
    ng = g.create_node(config, new_node_id)
    g.nodes[new_node_id] = ng
    if bias is not None:
        ng.bias = bias
    if response is not None:
        ng.response = response
    if aggregation is not None:
        ng.aggregation = aggregation
    if activation is not None:
        ng.activation = activation
    return new_node_id, ng

# %%
import neat
from random import choice, gauss, random, uniform, randint
from neat.genome import DefaultGenome
from neat.genes import DefaultNodeGene, DefaultConnectionGene
from neat.config import ConfigParameter, write_pretty_params
from neat.genes import BaseGene
from neat.attributes import FloatAttribute, BoolAttribute, StringAttribute, BaseAttribute
from neat.activations import ActivationFunctionSet
from neat.aggregations import AggregationFunctionSet
from itertools import count

class FixedFloatAttribute(BaseAttribute):
    """
    Class for floating-point numeric attributes,
    such as the response of a node or the weight of a connection.
    """
    _config_items = {"init_mean": [float, None],
                     "init_stdev": [float, None],
                     "init_type": [str, 'gaussian'],
                     "replace_rate": [float, None],
                     "mutate_rate": [float, None],
                     "mutate_power": [float, None],
                     "max_value": [float, None],
                     "min_value": [float, None]}

    def clamp(self, value, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        return max(min(value, max_value), min_value)

    def init_value(self, config):
        mean = getattr(config, self.init_mean_name)
        stdev = getattr(config, self.init_stdev_name)
        init_type = getattr(config, self.init_type_name).lower()

        if ('gauss' in init_type) or ('normal' in init_type):
            return self.clamp(gauss(mean, stdev), config)

        if 'uniform' in init_type:
            min_value = max(getattr(config, self.min_value_name),
                            (mean - (2 * stdev)))
            max_value = min(getattr(config, self.max_value_name),
                            (mean + (2 * stdev)))
            return uniform(min_value, max_value)

        raise RuntimeError(f"Unknown init_type {getattr(config, self.init_type_name)!r} for {self.init_type_name!s}")

    def mutate_value(self, value, config):
        # mutate_rate is usually no lower than replace_rate, and frequently higher -
        # so put first for efficiency
        mutate_rate = getattr(config, self.mutate_rate_name)
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        delta = choice([min_value / 10, max_value / 10])
        r = random()
        if r < mutate_rate:
            mutate_power = getattr(config, self.mutate_power_name)
            mutation = (2 * random() - 1) * delta
            return  self.clamp(value + mutation, config)

        replace_rate = getattr(config, self.replace_rate_name)

        r = random()
        if r < replace_rate:
            return self.init_value(config)

        return value

    def validate(self, config):
        min_value = getattr(config, self.min_value_name)
        max_value = getattr(config, self.max_value_name)
        if max_value < min_value:
            raise RuntimeError("Invalid min/max configuration for {self.name}")

class FixedStructureNodeGene(BaseGene):
    _gene_attributes = [
                        FixedFloatAttribute('bias'),
                        FloatAttribute('response'),
                        StringAttribute('activation', options=''),
                        StringAttribute('aggregation', options='')]

    def distance(self, other, config):
        return 0.0

class FixedStructureConnectionGene(BaseGene):
    _gene_attributes = [FixedFloatAttribute('weight'),
                        BoolAttribute('enabled')]

    def mutate(self, config):
        # Mutate only weights
        a = self._gene_attributes[0]
        v = getattr(self, a.name)
        setattr(self, a.name, a.mutate_value(v, config))

    def distance(self, other, config):
        d = abs(self.weight - other.weight)
        return d
    
class FixedStructureGenomeConfig(object):
    __params = [ConfigParameter('feed_forward', bool),
                ConfigParameter('num_inputs', int),
                ConfigParameter('num_outputs', int),
                ConfigParameter('num_hidden', int),
                ConfigParameter('num_hidden_layers', int),
                ConfigParameter('initial_connection', str, 'full_direct'),
                ConfigParameter('conn_add_prob', float),
                ConfigParameter('conn_delete_prob', float),
                ConfigParameter('node_add_prob', float),
                ConfigParameter('node_delete_prob', float)]


    def __init__(self, params):
        # Create full set of available activation functions.
        self.activation_defs = ActivationFunctionSet()
        self.activation_options = params.get('activation_options', 'sigmoid').strip().split()
        self.aggregation_options = params.get('aggregation_options', 'sum').strip().split()
        self.aggregation_function_defs = AggregationFunctionSet()

        # Gather configuration data from the gene classes.
        self.node_gene_type = params['node_gene_type']
        self.__params += self.node_gene_type.get_config_params()
        self.connection_gene_type = params['connection_gene_type']
        self.__params += self.connection_gene_type.get_config_params()
        self.connection_fraction = None
        self.node_indexer = None
        self.structural_mutation_surer = 'false'

        # Use the configuration data to interpret the supplied parameters.
        for p in self.__params:
            setattr(self, p.name, p.interpret(params))

        # By convention, input pins have negative keys, and the output
        # pins have keys 0,1,...
        self.input_keys = [-i - 1 for i in range(self.num_inputs)]
        self.output_keys = [i for i in range(self.num_outputs)]

    def get_new_node_key(self, node_dict):
        if self.node_indexer is None:
            if node_dict:
                self.node_indexer = count(max(list(node_dict)) + 1)
            else:
                self.node_indexer = count(max(list(node_dict)) + 1)

        new_id = next(self.node_indexer)

        assert new_id not in node_dict

        return new_id
    
    def save(self, f):
        write_pretty_params(f, self, self.__params)

class FixedStructureGenome(object):
    @classmethod
    def parse_config(cls, param_dict):
        param_dict['node_gene_type'] = FixedStructureNodeGene
        param_dict['connection_gene_type'] = FixedStructureConnectionGene
        return FixedStructureGenomeConfig(param_dict)
    
    @classmethod
    def write_config(cls, f, config):
        config.save(f)

    def __init__(self, key):
        self.key = key
        self.connections = {}
        self.nodes = {}

        # Fitness results.
        self.fitness = None

    def mutate(self, config):
        """ Mutates this genome. """
        # Mutate connection genes.
        for cg in self.connections.values():
            cg.mutate(config)

        # Mutate node genes (bias, response, etc.).
        for ng in self.nodes.values():
            ng.mutate(config)

    def configure_crossover(self, genome1, genome2, config):
        """ Configure a new genome by crossover from two parent genomes. """
        if genome1.fitness > genome2.fitness:
            parent1, parent2 = genome1, genome2
        else:
            parent1, parent2 = genome2, genome1

        # Inherit connection genes
        for key, cg1 in parent1.connections.items():
            cg2 = parent2.connections.get(key)
            if cg2 is None:
                # Excess or disjoint gene: copy from the fittest parent.
                self.connections[key] = cg1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.connections[key] = cg1.crossover(cg2)
            self.connections[key].enabled = True

        # Inherit node genes
        parent1_set = parent1.nodes
        parent2_set = parent2.nodes

        for key, ng1 in parent1_set.items():
            ng2 = parent2_set.get(key)
            assert key not in self.nodes
            if ng2 is None:
                # Extra gene: copy from the fittest parent
                self.nodes[key] = ng1.copy()
            else:
                # Homologous gene: combine genes from both parents.
                self.nodes[key] = ng1.crossover(ng2)

    def distance(self, other, config):
        return 0.0
    
    def size(self):
        """Returns genome 'complexity', taken to be (number of nodes, number of enabled connections)"""
        num_enabled_connections = sum([1 for cg in self.connections.values() if cg.enabled is True])
        return len(self.nodes), num_enabled_connections

    def __str__(self):
        s = f"Key: {self.key}\nFitness: {self.fitness}\nNodes:"
        for k, ng in self.nodes.items():
            s += f"\n\t{k} {ng!s}"
        s += "\nConnections:"
        connections = list(self.connections.values())
        connections.sort()
        for c in connections:
            s += "\n\t" + str(c)
        return s

    def configure_new(self, config):
        # Create node genes for the input and output nodes
        for node_key in config.input_keys + config.output_keys:
            self.nodes[node_key] = self.create_node(config, node_key)

        # Initialize list to keep track of nodes in the last layer (start with input layer)
        last_layer_nodes = config.input_keys

        # Add hidden nodes and layers
        # config.num_hidden now represents the number of neurons PER HIDDEN LAYER
        if config.num_hidden > 0 and config.num_hidden_layers > 0:
            for _ in range(config.num_hidden_layers):
                layer_node_ids = []
                for _ in range(config.num_hidden):  # Create the specified number of nodes for this layer
                    node_key = config.get_new_node_key(self.nodes)
                    self.nodes[node_key] = self.create_node(config, node_key)
                    layer_node_ids.append(node_key)
                
                # Connect all nodes from the last layer to the current layer's nodes
                for last_layer_node in last_layer_nodes:
                    for current_layer_node in layer_node_ids:
                        connection = self.create_connection(config, last_layer_node, current_layer_node)
                        self.connections[connection.key] = connection

                # Update last_layer_nodes to reflect the current layer for next iteration
                last_layer_nodes = layer_node_ids

            # Connect all nodes from the last hidden layer to the output nodes
            for hidden_node_id in last_layer_nodes:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, hidden_node_id, output_node_id)
                    self.connections[connection.key] = connection
        else:
            # If there are no hidden layers, connect input nodes directly to output nodes
            for input_node_id in config.input_keys:
                for output_node_id in config.output_keys:
                    connection = self.create_connection(config, input_node_id, output_node_id)
                    self.connections[connection.key] = connection

    @staticmethod
    def create_node(config, node_id):
        node = FixedStructureNodeGene(node_id)
        node.init_attributes(config)
        return node

    @staticmethod
    def create_connection(config, input_id, output_id):
        connection = config.connection_gene_type((input_id, output_id))
        connection.init_attributes(config)
        return connection

# %%
NUM_RUNS = 1
MAX_GENS = 1000
generation = 0
SAVE_INTERVAL = 100

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=10)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = 'result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
out_mult = 1

behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x0000024E1317FCA0>
# Name of the behavior : ForestControl?team=0
# Number of observations :  5
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.FeedForwardNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1
    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")

    while not done:
        for agent in decision_steps:
            if unity_to_neat_map[agent] not in removed_agents:
                obs = np.concatenate(decision_steps[agent].obs[:])
                nn_input =  np.asarray(obs)
                #print(f"NN INPUT: {nn_input}, agent: {agent}")
                actions = policies[unity_to_neat_map[agent]].activate(nn_input)
                continous_actions = np.asarray([actions])
                #if unity_to_neat_map[agent] == 1:
                    #print(continous_actions)
                continous_actions = np.clip(continous_actions, -1, 1)
                #print(continous_actions)
                action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                env.set_action_for_agent(behavior_name=behavior_name, 
                                        agent_id=agent, 
                                        action=action_tuple)
        env.step()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        for agent in range(agent_count):
            if agent not in removed_agents:
                local_agent = neat_to_unity_map[agent]
                if local_agent in terminal_steps:
                    episode_rewards[agent] += terminal_steps[local_agent].reward
                    removed_agents.append(agent)
                    #print(f"Finished: {agent}")
                elif local_agent in decision_steps:
                    episode_rewards[agent] += decision_steps[local_agent].reward
        if len(removed_agents) >= agent_count:
            print(".") 
            done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i]
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    #pop.add_reporter(neat.Checkpointer(generation_interval=5, time_interval_seconds=100000, filename_prefix=file_name_prefix))
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = '../configs/config_fixed_forest'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#
#  ****** Running generation 0 ******
#
# Agent count: 50
# .
# Population's average fitness: -1.00000 stdev: 0.00000
# Best fitness: -0.99999 - size: (100, 900) - species 1 - id 5
# Best fitness ever found! : -0.9999886772766331
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0    50  -0.9999886772766331  5.45486915193294e-07     0
# Total extinctions: 0
# Generation time: 4.298 sec
#
#  ****** Running generation 1 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99918 stdev: 0.00571
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Best fitness ever found! : -0.9592185799174526
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    1    50  -0.9592185799174526  0.0008241324448730047     0
# Total extinctions: 0
# Generation time: 2.079 sec (3.189 average)
#
#  ****** Running generation 2 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99831 stdev: 0.00758
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    2    50  -0.9592185799174526  0.0016906644584679942     1
# Total extinctions: 0
# Generation time: 2.025 sec (2.801 average)
#
#  ****** Running generation 3 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99796 stdev: 0.00772
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    3    50  -0.9592185799174526  0.0020431595599794683     2
# Total extinctions: 0
# Generation time: 2.068 sec (2.617 average)
#
#  ****** Running generation 4 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99806 stdev: 0.00767
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    4    50  -0.9592185799174526  0.001937701360460009     3
# Total extinctions: 0
# Generation time: 1.401 sec (2.374 average)
#
#  ****** Running generation 5 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99669 stdev: 0.00947
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    5    50  -0.9592185799174526  0.003312980247986985     4
# Total extinctions: 0
# Generation time: 1.352 sec (2.204 average)
#
#  ****** Running generation 6 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99811 stdev: 0.00767
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    6    50  -0.9592185799174526  0.0018887827223289522     5
# Total extinctions: 0
# Generation time: 1.346 sec (2.081 average)
#
#  ****** Running generation 7 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99837 stdev: 0.00755
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    7    50  -0.9592185799174526  0.0016316486169136724     6
# Total extinctions: 0
# Generation time: 1.611 sec (2.023 average)
#
#  ****** Running generation 8 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99793 stdev: 0.00790
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    8    50  -0.9592185799174526  0.0020725741455533964     7
# Total extinctions: 0
# Generation time: 1.674 sec (1.984 average)
#
#  ****** Running generation 9 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99802 stdev: 0.00774
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    9    50  -0.9592185799174526  0.0019802677420969195     8
# Total extinctions: 0
# Generation time: 1.482 sec (1.934 average)
#
#  ****** Running generation 10 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99780 stdev: 0.00776
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   10    50  -0.9592185799174526  0.002196669052429212     9
# Total extinctions: 0
# Generation time: 1.455 sec (1.649 average)
#
#  ****** Running generation 11 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99737 stdev: 0.00851
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   11    50  -0.9592185799174526  0.0026327212775089093    10
# Total extinctions: 0
# Generation time: 1.521 sec (1.593 average)
#
#  ****** Running generation 12 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99790 stdev: 0.00793
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   12    50  -0.9592185799174526  0.002098369590183502    11
# Total extinctions: 0
# Generation time: 1.287 sec (1.520 average)
#
#  ****** Running generation 13 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99836 stdev: 0.00754
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   13    50  -0.9592185799174526  0.0016413277172989682    12
# Total extinctions: 0
# Generation time: 2.197 sec (1.533 average)
#
#  ****** Running generation 14 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99825 stdev: 0.00763
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   14    50  -0.9592185799174526  0.0017451699803454623    13
# Total extinctions: 0
# Generation time: 1.383 sec (1.531 average)
#
#  ****** Running generation 15 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99817 stdev: 0.00754
# Best fitness: -0.95922 - size: (100, 900) - species 1 - id 65
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   15    50  -0.9592185799174526  0.0018251347957682906    14
# Total extinctions: 0
# Generation time: 1.401 sec (1.536 average)
#
#  ****** Running generation 16 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99298 stdev: 0.02692
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Best fitness ever found! : -0.8592002407495241
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   16    50  -0.8592002407495241  0.007015065901295525     0
# Total extinctions: 0
# Generation time: 1.344 sec (1.535 average)
#
#  ****** Running generation 17 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99446 stdev: 0.02616
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   17    50  -0.8592002407495241  0.005540817301019962     1
# Total extinctions: 0
# Generation time: 1.508 sec (1.525 average)
#
#  ****** Running generation 18 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99410 stdev: 0.02621
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   18    50  -0.8592002407495241  0.005898861137501932     2
# Total extinctions: 0
# Generation time: 1.432 sec (1.501 average)
#
#  ****** Running generation 19 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99248 stdev: 0.02661
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   19    50  -0.8592002407495241  0.007519115318544989     3
# Total extinctions: 0
# Generation time: 1.652 sec (1.518 average)
#
#  ****** Running generation 20 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99245 stdev: 0.02647
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   20    50  -0.8592002407495241  0.007545631929769758     4
# Total extinctions: 0
# Generation time: 1.529 sec (1.525 average)
#
#  ****** Running generation 21 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99327 stdev: 0.02647
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   21    50  -0.8592002407495241  0.006726781181504271     5
# Total extinctions: 0
# Generation time: 1.384 sec (1.512 average)
#
#  ****** Running generation 22 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99383 stdev: 0.02631
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   22    50  -0.8592002407495241  0.006169290237339586     6
# Total extinctions: 0
# Generation time: 1.680 sec (1.551 average)
#
#  ****** Running generation 23 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99404 stdev: 0.02620
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   23    50  -0.8592002407495241  0.005957253741007973     7
# Total extinctions: 0
# Generation time: 1.894 sec (1.521 average)
#
#  ****** Running generation 24 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99368 stdev: 0.02644
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   24    50  -0.8592002407495241  0.0063217878672319205     8
# Total extinctions: 0
# Generation time: 2.028 sec (1.585 average)
#
#  ****** Running generation 25 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99310 stdev: 0.02635
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   25    50  -0.8592002407495241  0.006904449662755385     9
# Total extinctions: 0
# Generation time: 1.646 sec (1.610 average)
#
#  ****** Running generation 26 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99407 stdev: 0.02616
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   26    50  -0.8592002407495241  0.005930352943142481    10
# Total extinctions: 0
# Generation time: 1.699 sec (1.645 average)
#
#  ****** Running generation 27 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99404 stdev: 0.02622
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   27    50  -0.8592002407495241  0.0059638138502100535    11
# Total extinctions: 0
# Generation time: 1.495 sec (1.644 average)
#
#  ****** Running generation 28 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99423 stdev: 0.02622
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   28    50  -0.8592002407495241  0.005773782044159348    12
# Total extinctions: 0
# Generation time: 1.485 sec (1.649 average)
#
#  ****** Running generation 29 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99197 stdev: 0.02745
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   29    50  -0.8592002407495241  0.008033232181408279    13
# Total extinctions: 0
# Generation time: 1.726 sec (1.657 average)
#
#  ****** Running generation 30 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98946 stdev: 0.03188
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   30    50  -0.8592002407495241  0.010540168296182761    14
# Total extinctions: 0
# Generation time: 2.298 sec (1.734 average)
#
#  ****** Running generation 31 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99019 stdev: 0.02832
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   31    50  -0.8592002407495241  0.009814928390299404    15
# Total extinctions: 0
# Generation time: 1.542 sec (1.749 average)
#
#  ****** Running generation 32 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99001 stdev: 0.03164
# Best fitness: -0.85920 - size: (100, 900) - species 1 - id 799
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   32    50  -0.8592002407495241  0.009987496443568222    16
# Total extinctions: 0
# Generation time: 1.508 sec (1.732 average)
#
#  ****** Running generation 33 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98980 stdev: 0.03569
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Best fitness ever found! : -0.8290316659147772
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   33    50  -0.8290316659147772  0.010199030890022387     0
# Total extinctions: 0
# Generation time: 1.671 sec (1.710 average)
#
#  ****** Running generation 34 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99128 stdev: 0.03139
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   34    50  -0.8290316659147772  0.008724032950493621     1
# Total extinctions: 0
# Generation time: 1.663 sec (1.673 average)
#
#  ****** Running generation 35 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99092 stdev: 0.03110
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   35    50  -0.8290316659147772  0.009081399537382961     2
# Total extinctions: 0
# Generation time: 1.647 sec (1.674 average)
#
#  ****** Running generation 36 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99154 stdev: 0.03122
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   36    50  -0.8290316659147772  0.008458632263250498     3
# Total extinctions: 0
# Generation time: 1.945 sec (1.698 average)
#
#  ****** Running generation 37 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99248 stdev: 0.03094
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   37    50  -0.8290316659147772  0.007524068455160515     4
# Total extinctions: 0
# Generation time: 1.989 sec (1.747 average)
#
#  ****** Running generation 38 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98759 stdev: 0.03597
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   38    50  -0.8290316659147772  0.012414099654199151     5
# Total extinctions: 0
# Generation time: 2.161 sec (1.815 average)
#
#  ****** Running generation 39 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99048 stdev: 0.03153
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   39    50  -0.8290316659147772  0.009518092736505945     6
# Total extinctions: 0
# Generation time: 1.553 sec (1.798 average)
#
#  ****** Running generation 40 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99021 stdev: 0.03234
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   40    50  -0.8290316659147772  0.00978983082883933     7
# Total extinctions: 0
# Generation time: 1.750 sec (1.743 average)
#
#  ****** Running generation 41 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.99154 stdev: 0.03158
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   41    50  -0.8290316659147772  0.008456638463147925     8
# Total extinctions: 0
# Generation time: 1.522 sec (1.741 average)
#
#  ****** Running generation 42 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98967 stdev: 0.03137
# Best fitness: -0.82903 - size: (100, 900) - species 1 - id 1598
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   42    50  -0.8290316659147772  0.01032947162678699     9
# Total extinctions: 0
# Generation time: 1.698 sec (1.760 average)
#
#  ****** Running generation 43 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98910 stdev: 0.03894
# Best fitness: -0.82112 - size: (100, 900) - species 1 - id 2096
# Best fitness ever found! : -0.8211173141105577
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   43    50  -0.8211173141105577  0.010903445601576411     0
# Total extinctions: 0
# Generation time: 1.637 sec (1.756 average)
#
#  ****** Running generation 44 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98824 stdev: 0.03590
# Best fitness: -0.82112 - size: (100, 900) - species 1 - id 2096
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   44    50  -0.8211173141105577  0.01176229241770832     1
# Total extinctions: 0
# Generation time: 1.506 sec (1.741 average)
#
#  ****** Running generation 45 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98419 stdev: 0.04289
# Best fitness: -0.82051 - size: (100, 900) - species 1 - id 2209
# Best fitness ever found! : -0.8205081099420088
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   45    50  -0.8205081099420088  0.015805303357224743     0
# Total extinctions: 0
# Generation time: 1.696 sec (1.746 average)
#
#  ****** Running generation 46 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.97904 stdev: 0.04785
# Best fitness: -0.77900 - size: (100, 900) - species 1 - id 2227
# Best fitness ever found! : -0.7789971247672093
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   46    50  -0.7789971247672093  0.020964902251722317     0
# Total extinctions: 0
# Generation time: 1.562 sec (1.707 average)
#
#  ****** Running generation 47 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.98123 stdev: 0.05518
# Best fitness: -0.73489 - size: (100, 900) - species 1 - id 2272
# Best fitness ever found! : -0.7348851043439231
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   47    50  -0.7348851043439231  0.01877085936370182     0
# Total extinctions: 0
# Generation time: 1.647 sec (1.673 average)
#
#  ****** Running generation 48 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.96168 stdev: 0.11747
# Best fitness: -0.29445 - size: (100, 900) - species 1 - id 2342
# Best fitness ever found! : -0.29445188621932195
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   48    50  -0.29445188621932195  0.038318602266049884     0
# Total extinctions: 0
# Generation time: 1.539 sec (1.611 average)
#
#  ****** Running generation 49 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.95147 stdev: 0.12280
# Best fitness: -0.29445 - size: (100, 900) - species 1 - id 2342
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   49    50  -0.29445188621932195  0.04852788750074877     1
# Total extinctions: 0
# Generation time: 1.600 sec (1.616 average)
#
#  ****** Running generation 50 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.95714 stdev: 0.11496
# Best fitness: -0.29445 - size: (100, 900) - species 1 - id 2342
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   50    50  -0.29445188621932195  0.042856078334305714     2
# Total extinctions: 0
# Generation time: 1.812 sec (1.622 average)
#
#  ****** Running generation 51 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.94949 stdev: 0.13029
# Best fitness: -0.29445 - size: (100, 900) - species 1 - id 2342
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   51    50  -0.29445188621932195  0.050506980164330195     3
# Total extinctions: 0
# Generation time: 2.271 sec (1.697 average)
#
#  ****** Running generation 52 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.93140 stdev: 0.16554
# Best fitness: -0.29445 - size: (100, 900) - species 1 - id 2342
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   52    50  -0.29445188621932195  0.06860038317367112     4
# Total extinctions: 0
# Generation time: 2.366 sec (1.764 average)
#
#  ****** Running generation 53 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.90174 stdev: 0.17966
# Best fitness: -0.29445 - size: (100, 900) - species 1 - id 2342
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   53    50  -0.29445188621932195  0.09825936168850224     5
# Total extinctions: 0
# Generation time: 1.824 sec (1.782 average)
#
#  ****** Running generation 54 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.90498 stdev: 0.20719
# Best fitness: -0.08363 - size: (100, 900) - species 1 - id 2632
# Best fitness ever found! : -0.08363056835639504
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   54    50  -0.08363056835639504  0.09502427709819983     0
# Total extinctions: 0
# Generation time: 1.807 sec (1.813 average)
#
#  ****** Running generation 55 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.88809 stdev: 0.26015
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Best fitness ever found! : 0.3466023043969302
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   55    50  0.3466023043969302  0.08310324061013782     0
# Total extinctions: 0
# Generation time: 2.677 sec (1.911 average)
#
#  ****** Running generation 56 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.91072 stdev: 0.24071
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   56    50  0.3466023043969302  0.06630029952629152     1
# Total extinctions: 0
# Generation time: 2.533 sec (2.008 average)
#
#  ****** Running generation 57 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.91549 stdev: 0.24286
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   57    50  0.3466023043969302  0.06275952273799612     2
# Total extinctions: 0
# Generation time: 2.348 sec (2.078 average)
#
#  ****** Running generation 58 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.89749 stdev: 0.24365
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   58    50  0.3466023043969302  0.07612544448769386     3
# Total extinctions: 0
# Generation time: 1.894 sec (2.113 average)
#
#  ****** Running generation 59 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.90287 stdev: 0.25194
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   59    50  0.3466023043969302  0.07212890064147259     4
# Total extinctions: 0
# Generation time: 1.944 sec (2.148 average)
#
#  ****** Running generation 60 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.89482 stdev: 0.25564
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   60    50  0.3466023043969302  0.07811045461500504     5
# Total extinctions: 0
# Generation time: 2.064 sec (2.173 average)
#
#  ****** Running generation 61 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.85687 stdev: 0.33303
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   61    50  0.3466023043969302  0.10628963207069542     6
# Total extinctions: 0
# Generation time: 2.126 sec (2.158 average)
#
#  ****** Running generation 62 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.86217 stdev: 0.29893
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   62    50  0.3466023043969302  0.10235338745211192     7
# Total extinctions: 0
# Generation time: 2.469 sec (2.169 average)
#
#  ****** Running generation 63 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.87055 stdev: 0.29943
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   63    50  0.3466023043969302  0.09613450241990583     8
# Total extinctions: 0
# Generation time: 2.120 sec (2.198 average)
#
#  ****** Running generation 64 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.85422 stdev: 0.31666
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   64    50  0.3466023043969302  0.10826025981939702     9
# Total extinctions: 0
# Generation time: 1.926 sec (2.210 average)
#
#  ****** Running generation 65 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.86065 stdev: 0.32097
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   65    50  0.3466023043969302  0.10348479824192613    10
# Total extinctions: 0
# Generation time: 2.211 sec (2.163 average)
#
#  ****** Running generation 66 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.85334 stdev: 0.31299
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   66    50  0.3466023043969302  0.10890770395345412    11
# Total extinctions: 0
# Generation time: 1.857 sec (2.096 average)
#
#  ****** Running generation 67 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.86300 stdev: 0.30048
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   67    50  0.3466023043969302  0.10173950117324923    12
# Total extinctions: 0
# Generation time: 2.525 sec (2.114 average)
#
#  ****** Running generation 68 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.81946 stdev: 0.31716
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   68    50  0.3466023043969302  0.1340729789327307    13
# Total extinctions: 0
# Generation time: 2.067 sec (2.131 average)
#
#  ****** Running generation 69 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.91574 stdev: 0.25408
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   69    50  0.3466023043969302  0.0625714781433577    14
# Total extinctions: 0
# Generation time: 2.912 sec (2.228 average)
#
#  ****** Running generation 70 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.89794 stdev: 0.27023
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   70    50  0.3466023043969302  0.07578729929338472    15
# Total extinctions: 0
# Generation time: 2.430 sec (2.264 average)
#
#  ****** Running generation 71 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.82694 stdev: 0.31921
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   71    50  0.3466023043969302  0.1285166207110023    16
# Total extinctions: 0
# Generation time: 2.368 sec (2.289 average)
#
#  ****** Running generation 72 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.84163 stdev: 0.29424
# Best fitness: 0.34660 - size: (100, 900) - species 1 - id 2680
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   72    50  0.3466023043969302  0.1176056609864266    17
# Total extinctions: 0
# Generation time: 2.998 sec (2.341 average)
#
#  ****** Running generation 73 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.83769 stdev: 0.33366
# Best fitness: 0.38243 - size: (100, 900) - species 1 - id 3521
# Best fitness ever found! : 0.3824335774667693
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   73    50  0.3824335774667693  0.1174054132528372     0
# Total extinctions: 0
# Generation time: 3.928 sec (2.522 average)
#
#  ****** Running generation 74 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.81065 stdev: 0.30673
# Best fitness: 0.38243 - size: (100, 900) - species 1 - id 3521
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   74    50  0.3824335774667693  0.13696641412757818     1
# Total extinctions: 0
# Generation time: 3.181 sec (2.648 average)
#
#  ****** Running generation 75 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.83401 stdev: 0.33950
# Best fitness: 0.38243 - size: (100, 900) - species 1 - id 3521
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   75    50  0.3824335774667693  0.1200688999993136     2
# Total extinctions: 0
# Generation time: 2.609 sec (2.688 average)
#
#  ****** Running generation 76 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.74300 stdev: 0.39683
# Best fitness: 0.38243 - size: (100, 900) - species 1 - id 3521
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   76    50  0.3824335774667693  0.1859006849200874     3
# Total extinctions: 0
# Generation time: 2.271 sec (2.729 average)
#
#  ****** Running generation 77 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.70679 stdev: 0.45174
# Best fitness: 0.38243 - size: (100, 900) - species 1 - id 3521
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   77    50  0.3824335774667693  0.21209405437923273     4
# Total extinctions: 0
# Generation time: 2.088 sec (2.685 average)
#
#  ****** Running generation 78 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.68031 stdev: 0.47240
# Best fitness: 0.54424 - size: (100, 900) - species 1 - id 3772
# Best fitness ever found! : 0.5442405733510929
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   78    50  0.5442405733510929  0.20702350908835634     0
# Total extinctions: 0
# Generation time: 2.009 sec (2.679 average)
#
#  ****** Running generation 79 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.64451 stdev: 0.49740
# Best fitness: 0.69437 - size: (100, 900) - species 1 - id 3825
# Best fitness ever found! : 0.6943692478327246
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   79    50  0.6943692478327246  0.20980469245974068     0
# Total extinctions: 0
# Generation time: 2.151 sec (2.603 average)
#
#  ****** Running generation 80 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.48516 stdev: 0.56808
# Best fitness: 1.05954 - size: (100, 900) - species 1 - id 3886
# Best fitness ever found! : 1.0595386869408365
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   80    50  1.0595386869408365  0.2499800213103086     0
# Total extinctions: 0
# Generation time: 2.089 sec (2.569 average)
#
#  ****** Running generation 81 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.51176 stdev: 0.59633
# Best fitness: 1.08639 - size: (100, 900) - species 1 - id 3904
# Best fitness ever found! : 1.086386893931893
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   81    50  1.086386893931893  0.23401035765399503     0
# Total extinctions: 0
# Generation time: 2.620 sec (2.594 average)
#
#  ****** Running generation 82 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.63373 stdev: 0.59418
# Best fitness: 1.08639 - size: (100, 900) - species 1 - id 3904
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   82    50  1.086386893931893  0.17555445510851983     1
# Total extinctions: 0
# Generation time: 2.274 sec (2.522 average)
#
#  ****** Running generation 83 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59678 stdev: 0.56393
# Best fitness: 1.08639 - size: (100, 900) - species 1 - id 3904
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   83    50  1.086386893931893  0.19326325468111377     2
# Total extinctions: 0
# Generation time: 2.526 sec (2.382 average)
#
#  ****** Running generation 84 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.57851 stdev: 0.58684
# Best fitness: 1.08639 - size: (100, 900) - species 1 - id 3904
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   84    50  1.086386893931893  0.20202122146254128     3
# Total extinctions: 0
# Generation time: 2.316 sec (2.295 average)
#
#  ****** Running generation 85 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.58222 stdev: 0.57840
# Best fitness: 1.08639 - size: (100, 900) - species 1 - id 3904
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   85    50  1.086386893931893  0.20024283747066413     4
# Total extinctions: 0
# Generation time: 2.301 sec (2.264 average)
#
#  ****** Running generation 86 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.42768 stdev: 0.64181
# Best fitness: 1.53461 - size: (100, 900) - species 1 - id 4175
# Best fitness ever found! : 1.5346089937990195
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   86    50  1.5346089937990195  0.22580108823611075     0
# Total extinctions: 0
# Generation time: 2.268 sec (2.264 average)
#
#  ****** Running generation 87 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.37977 stdev: 0.59539
# Best fitness: 1.53461 - size: (100, 900) - species 1 - id 4175
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   87    50  1.5346089937990195  0.24470372173202418     1
# Total extinctions: 0
# Generation time: 2.637 sec (2.319 average)
#
#  ****** Running generation 88 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.39074 stdev: 0.64867
# Best fitness: 1.53461 - size: (100, 900) - species 1 - id 4175
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   88    50  1.5346089937990195  0.24037576702276295     2
# Total extinctions: 0
# Generation time: 2.935 sec (2.412 average)
#
#  ****** Running generation 89 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59378 stdev: 0.59377
# Best fitness: 1.53461 - size: (100, 900) - species 1 - id 4175
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   89    50  1.5346089937990195  0.16026984494649352     3
# Total extinctions: 0
# Generation time: 2.329 sec (2.429 average)
#
#  ****** Running generation 90 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.50468 stdev: 0.62710
# Best fitness: 1.53461 - size: (100, 900) - species 1 - id 4175
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   90    50  1.5346089937990195  0.19542198296450153     4
# Total extinctions: 0
# Generation time: 2.818 sec (2.502 average)
#
#  ****** Running generation 91 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.49767 stdev: 0.64094
# Best fitness: 1.53461 - size: (100, 900) - species 1 - id 4175
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   91    50  1.5346089937990195  0.19818827100986142     5
# Total extinctions: 0
# Generation time: 2.584 sec (2.499 average)
#
#  ****** Running generation 92 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.55336 stdev: 0.65608
# Best fitness: 1.55803 - size: (100, 900) - species 1 - id 4455
# Best fitness ever found! : 1.558033482811715
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   92    50  1.558033482811715  0.174601297344018     0
# Total extinctions: 0
# Generation time: 3.047 sec (2.576 average)
#
#  ****** Running generation 93 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.37465 stdev: 0.71883
# Best fitness: 1.55803 - size: (100, 900) - species 1 - id 4455
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   93    50  1.558033482811715  0.24446367393467866     1
# Total extinctions: 0
# Generation time: 2.901 sec (2.614 average)
#
#  ****** Running generation 94 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.36193 stdev: 0.86476
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Best fitness ever found! : 2.556442522202408
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   94    50  2.556442522202408  0.17941135237739958     0
# Total extinctions: 0
# Generation time: 2.504 sec (2.632 average)
#
#  ****** Running generation 95 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54973 stdev: 0.70155
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   95    50  2.556442522202408  0.12660696958704498     1
# Total extinctions: 0
# Generation time: 3.394 sec (2.742 average)
#
#  ****** Running generation 96 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.42463 stdev: 0.83241
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   96    50  2.556442522202408  0.16178324432748734     2
# Total extinctions: 0
# Generation time: 2.375 sec (2.752 average)
#
#  ****** Running generation 97 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.45336 stdev: 0.78456
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   97    50  2.556442522202408  0.1537055525031401     3
# Total extinctions: 0
# Generation time: 2.797 sec (2.768 average)
#
#  ****** Running generation 98 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.54990 stdev: 0.76847
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   98    50  2.556442522202408  0.12655947214830432     4
# Total extinctions: 0
# Generation time: 2.539 sec (2.729 average)
#
#  ****** Running generation 99 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.59284 stdev: 0.72247
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1   99    50  2.556442522202408  0.11448505684170954     5
# Total extinctions: 0
# Generation time: 3.882 sec (2.884 average)
#
#  ****** Running generation 100 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.46721 stdev: 0.75314
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  100    50  2.556442522202408  0.14980852128737937     6
# Total extinctions: 0
# Generation time: 3.419 sec (2.944 average)
#
#  ****** Running generation 101 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.25941 stdev: 0.77431
# Best fitness: 2.55644 - size: (100, 900) - species 1 - id 4530
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  101    50  2.556442522202408  0.20823842968938588     7
# Total extinctions: 0
# Generation time: 2.775 sec (2.963 average)
#
#  ****** Running generation 102 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.23867 stdev: 0.94315
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Best fitness ever found! : 3.1694052030631994
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  102    50  3.1694052030631994  0.18259947074695523     0
# Total extinctions: 0
# Generation time: 2.555 sec (2.914 average)
#
#  ****** Running generation 103 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.37474 stdev: 0.85366
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  103    50  3.1694052030631994  0.14996402493068833     1
# Total extinctions: 0
# Generation time: 3.903 sec (3.014 average)
#
#  ****** Running generation 104 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.20918 stdev: 0.84210
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  104    50  3.1694052030631994  0.1896716107393148     2
# Total extinctions: 0
# Generation time: 3.420 sec (3.106 average)
#
#  ****** Running generation 105 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.41770 stdev: 0.85446
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  105    50  3.1694052030631994  0.13965951335004773     3
# Total extinctions: 0
# Generation time: 3.036 sec (3.070 average)
#
#  ****** Running generation 106 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.31257 stdev: 0.88160
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  106    50  3.1694052030631994  0.16487408077945254     4
# Total extinctions: 0
# Generation time: 2.563 sec (3.089 average)
#
#  ****** Running generation 107 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.32664 stdev: 0.87727
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  107    50  3.1694052030631994  0.16150029593616774     5
# Total extinctions: 0
# Generation time: 3.089 sec (3.118 average)
#
#  ****** Running generation 108 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.25918 stdev: 0.83558
# Best fitness: 3.16941 - size: (100, 900) - species 1 - id 4944
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  108    50  3.1694052030631994  0.17768114197244372     6
# Total extinctions: 0
# ...
#
#  ****** Running generation 187 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.25353 stdev: 0.98813
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  187    50  4.089173829102137  0.14667758498637842    48
# Total extinctions: 0
# Generation time: 2.697 sec (2.827 average)
#
#  ****** Running generation 188 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.12884 stdev: 1.03492
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  188    50  4.089173829102137  0.17117990663497462    49
# Total extinctions: 0
# Generation time: 2.645 sec (2.793 average)
#
#  ****** Running generation 189 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.21975 stdev: 0.97262
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  189    50  4.089173829102137  0.15331587931567625    50
# Total extinctions: 0
# Generation time: 3.352 sec (2.861 average)
#
#  ****** Running generation 190 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.23306 stdev: 1.13016
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  190    50  4.089173829102137  0.15070069479192635    51
# Total extinctions: 0
# Generation time: 3.974 sec (2.995 average)
#
#  ****** Running generation 191 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.21787 stdev: 1.09942
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  191    50  4.089173829102137  0.15368490475906424    52
# Total extinctions: 0
# Generation time: 4.127 sec (3.128 average)
#
#  ****** Running generation 192 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.22574 stdev: 1.04680
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  192    50  4.089173829102137  0.1521387596913892    53
# Total extinctions: 0
# Generation time: 2.627 sec (3.138 average)
#
#  ****** Running generation 193 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.45252 stdev: 1.03077
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  193    50  4.089173829102137  0.10757681189727088    54
# Total extinctions: 0
# Generation time: 2.556 sec (3.125 average)
#
#  ****** Running generation 194 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.38945 stdev: 1.07184
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  194    50  4.089173829102137  0.11997023717453881    55
# Total extinctions: 0
# Generation time: 3.965 sec (3.173 average)
#
#  ****** Running generation 195 ******
#
# Agent count: 50
# .
# Population's average fitness: 0.05767 stdev: 1.12383
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  195    50  4.089173829102137  0.20782681841178555    56
# Total extinctions: 0
# Generation time: 4.128 sec (3.271 average)
#
#  ****** Running generation 196 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.08653 stdev: 1.10456
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  196    50  4.089173829102137  0.17949225040679326    57
# Total extinctions: 0
# Generation time: 3.977 sec (3.405 average)
#
#  ****** Running generation 197 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.13078 stdev: 1.19556
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  197    50  4.089173829102137  0.1707980258975466    58
# Total extinctions: 0
# Generation time: 3.185 sec (3.453 average)
#
#  ****** Running generation 198 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.39466 stdev: 1.03756
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  198    50  4.089173829102137  0.11894681194313428    59
# Total extinctions: 0
# Generation time: 3.197 sec (3.509 average)
#
#  ****** Running generation 199 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.11526 stdev: 1.03479
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  199    50  4.089173829102137  0.17384826443138746    60
# Total extinctions: 0
# Generation time: 3.168 sec (3.490 average)
#
#  ****** Running generation 200 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.20173 stdev: 1.02784
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  200    50  4.089173829102137  0.15685739247701436    61
# Total extinctions: 0
# Generation time: 2.633 sec (3.356 average)
#
#  ****** Running generation 201 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.15303 stdev: 1.00809
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  201    50  4.089173829102137  0.16642487905952877    62
# Total extinctions: 0
# Generation time: 2.635 sec (3.207 average)
#
#  ****** Running generation 202 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.21155 stdev: 1.04908
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  202    50  4.089173829102137  0.15492532066270984    63
# Total extinctions: 0
# Generation time: 3.707 sec (3.315 average)
#
#  ****** Running generation 203 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.21290 stdev: 1.03141
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  203    50  4.089173829102137  0.15466145628836742    64
# Total extinctions: 0
# Generation time: 3.154 sec (3.375 average)
#
#  ****** Running generation 204 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.19050 stdev: 1.07630
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  204    50  4.089173829102137  0.1590634216411327    65
# Total extinctions: 0
# Generation time: 2.915 sec (3.270 average)
#
#  ****** Running generation 205 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.01109 stdev: 1.18293
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  205    50  4.089173829102137  0.19431566491437924    66
# Total extinctions: 0
# Generation time: 3.269 sec (3.184 average)
#
#  ****** Running generation 206 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.02914 stdev: 1.16461
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  206    50  4.089173829102137  0.19076968338557998    67
# Total extinctions: 0
# Generation time: 3.406 sec (3.127 average)
#
#  ****** Running generation 207 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.03685 stdev: 1.18346
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  207    50  4.089173829102137  0.189254043762481    68
# Total extinctions: 0
# Generation time: 3.190 sec (3.127 average)
#
#  ****** Running generation 208 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.13412 stdev: 1.05297
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  208    50  4.089173829102137  0.17014101320006927    69
# Total extinctions: 0
# Generation time: 2.914 sec (3.099 average)
#
#  ****** Running generation 209 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.08582 stdev: 0.99849
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  209    50  4.089173829102137  0.17962746946187605    70
# Total extinctions: 0
# Generation time: 2.956 sec (3.078 average)
#
#  ****** Running generation 210 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.28583 stdev: 1.02129
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  210    50  4.089173829102137  0.14033074333849016    71
# Total extinctions: 0
# Generation time: 2.687 sec (3.083 average)
#
#  ****** Running generation 211 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.15730 stdev: 1.02524
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  211    50  4.089173829102137  0.16558606390760514    72
# Total extinctions: 0
# Generation time: 2.665 sec (3.086 average)
#
#  ****** Running generation 212 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.20049 stdev: 1.05217
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  212    50  4.089173829102137  0.15710066803900058    73
# Total extinctions: 0
# Generation time: 2.342 sec (2.950 average)
#
#  ****** Running generation 213 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.22212 stdev: 1.07608
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  213    50  4.089173829102137  0.15284972348447143    74
# Total extinctions: 0
# Generation time: 2.616 sec (2.896 average)
#
#  ****** Running generation 214 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.09768 stdev: 1.08743
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  214    50  4.089173829102137  0.17730158899781978    75
# Total extinctions: 0
# Generation time: 3.002 sec (2.905 average)
#
#  ****** Running generation 215 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.27491 stdev: 1.04907
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  215    50  4.089173829102137  0.14247775818381825    76
# Total extinctions: 0
# Generation time: 3.062 sec (2.884 average)
#
#  ****** Running generation 216 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.07519 stdev: 1.05888
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  216    50  4.089173829102137  0.18172045051750693    77
# Total extinctions: 0
# Generation time: 2.485 sec (2.792 average)
#
#  ****** Running generation 217 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.15560 stdev: 1.04319
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  217    50  4.089173829102137  0.16592061141232223    78
# Total extinctions: 0
# Generation time: 2.755 sec (2.748 average)
#
#  ****** Running generation 218 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.16114 stdev: 1.08326
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  218    50  4.089173829102137  0.16483241333310944    79
# Total extinctions: 0
# Generation time: 3.369 sec (2.794 average)
#
#  ****** Running generation 219 ******
#
# Agent count: 50
# .
# Population's average fitness: 0.01774 stdev: 1.09621
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  219    50  4.089173829102137  0.19998062593651236    80
# Total extinctions: 0
# Generation time: 3.024 sec (2.801 average)
#
#  ****** Running generation 220 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.21162 stdev: 1.06367
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  220    50  4.089173829102137  0.15491252759410953    81
# Total extinctions: 0
# Generation time: 2.849 sec (2.817 average)
#
#  ****** Running generation 221 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.09538 stdev: 1.08482
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  221    50  4.089173829102137  0.17775313793157815    82
# Total extinctions: 0
# Generation time: 2.920 sec (2.842 average)
#
#  ****** Running generation 222 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.22079 stdev: 1.10253
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  222    50  4.089173829102137  0.15311188299663647    83
# Total extinctions: 0
# Generation time: 2.997 sec (2.908 average)
#
#  ****** Running generation 223 ******
#
# Agent count: 50
# .
# Population's average fitness: -0.20464 stdev: 1.10342
# Best fitness: 4.08917 - size: (100, 900) - species 1 - id 6691
# Population of 50 members in 1 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1  223    50  4.089173829102137  0.15628478704992496    84
# Total extinctions: 0
# Generation time: 2.333 sec (2.879 average)
#
#  ****** Running generation 224 ******
#
# Agent count: 50

# %%
env.close()

# %%
import visualize
with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    print('\nBest genome:\n{!s}'.format(genome))
print(genome.fitness)
config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'fixed_config')
visualize.draw_net(config, genome, True)
# Out:
# Best genome:
# (26595, <__main__.FixedStructureGenome object at 0x000001AAAC284F70>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 5
#       3     genome = pickle.load(f)
#       4     print('\nBest genome:\n{!s}'.format(genome))
# ----> 5 print(genome.fitness)
#       6 config = neat.Config(FixedStructureGenome, neat.DefaultReproduction,
#       7                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
#       8                     'fixed_config')
#       9 visualize.draw_net(config, genome, True)
#
# AttributeError: 'tuple' object has no attribute 'fitness'
