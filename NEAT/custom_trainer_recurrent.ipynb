# %%
import pickle
import numpy as np
import neat
import datetime
import os
import math

from comunication_channel import AgentLogChannel

from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
NUM_RUNS = 5
MAX_GENS = 3000

generation = 0
SAVE_INTERVAL = 100

# %%
engine_config_channel = EngineConfigurationChannel()
engine_config_channel.set_configuration_parameters(time_scale=10)
agent_count_channel = AgentLogChannel()

env_path = "../Builds/train-env/autonomous-drone.exe"
save_nn_destination = 'result/best.pkl'

env = UnityEnvironment(file_name=None, worker_id=0, no_graphics=True, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1

# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000001A96312F0A0>
# Name of the behavior : DroneControl?team=0
# Number of observations :  1
# There are 4 continuous actions

# %%
def create_folder(file_name_prefix):
    directory = os.path.dirname(f"{file_name_prefix}")
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
def get_observation_for_agent(agent: int, observations):
    for observation in observations:
        key = int(observation.split("=")[2])
        if key == agent:
            return observations[observation]

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def create_policies(genomes, cfg):
    policies = []
    for _, g in genomes:
        g.fitness = 0
        policy = neat.nn.RecurrentNetwork.create(g, cfg)
        policies.append(policy)
    return policies

# %%
def eval_genomes(genomes, cfg):
    global generation 
    generation += 1

    policies = create_policies(genomes, cfg)
    set_agents_and_double_reset(len(policies))
    decision_steps, terminal_steps = env.get_steps(behavior_name)
    agent_count = len(decision_steps.agent_id)

    unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

    done = False  # Vectorized initialization
    removed_agents = []

    episode_rewards = [0] * agent_count
    print(f"Agent count: {agent_count}")

    while not done:
        for agent in decision_steps:
            if unity_to_neat_map[agent] not in removed_agents:
                nn_input =  np.asarray(decision_steps[agent].obs[:])
                #print(f"NN INPUT: {nn_input}, agent: {agent}")
                #print(f"NN INPUT[0]: {nn_input[0]}, agent: {agent}")
                actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                #print(f"NN OUTPUT: {actions}, agent: {agent}")
                continous_actions = np.asarray([actions])
                # continous_actions = np.clip(continous_actions, -1, 1)
                action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                env.set_action_for_agent(behavior_name=behavior_name, 
                                        agent_id=agent, 
                                        action=action_tuple)
        env.step()
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        for agent in range(agent_count):
            if agent not in removed_agents:
                local_agent = neat_to_unity_map[agent]
                if local_agent in terminal_steps:
                    episode_rewards[agent] += terminal_steps[local_agent].reward
                    removed_agents.append(agent)
                    #print(f"Finished: {agent}")
                elif local_agent in decision_steps:
                    episode_rewards[agent] += decision_steps[local_agent].reward
                 

        if len(removed_agents) >= agent_count:
            done = True
    for i, (_, genome) in enumerate(genomes):
        genome.fitness = episode_rewards[i]
    if generation % SAVE_INTERVAL == 0:
      global file_name_prefix
      best_genome_current_generation = max(genomes, key=lambda x: x[1].fitness) 
      with open(file_name_prefix+'best-'+str(generation)+'.pkl', 'wb') as f:
          pickle.dump(best_genome_current_generation, f)

# %%
def run(config_file, run, datte):
    print(f"Running {run}")
    global file_name_prefix
    file_name_prefix = f"checkpoints/{datte}/run-{run}/"
    create_folder(file_name_prefix=file_name_prefix)

    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    pop = neat.Population(config)

    stats = neat.StatisticsReporter()

    pop.add_reporter(stats)
    pop.add_reporter(neat.TBReporter(True, 0, run, datte))
    #pop.add_reporter(neat.StdOutReporter(True))
    best = pop.run(eval_genomes, MAX_GENS)
    # Display the winning genome.
    # print('\nBest genome:\n{!s}'.format(best))
    print("Finished running!")
    
    # Save best genome
    with open(f'logs/{datte}/{run}/best.pkl', 'wb') as f:
        pickle.dump(best, f)

# %%
config_path = 'config-recurrent'
datte = datetime.datetime.now().strftime("%d-%m-%Y--%H_%M")
# pre create folders for checkpointer
for r in range(NUM_RUNS):
    run(config_path, r, datte)
# Out:
# Running 0
#  ****** Running generation 0 ******
#
# Agent count: 50
# Population's average fitness: 0.00000 stdev: 0.00000
# Best fitness: 0.00000 - size: (8, 64) - species 35 - id 35
# Best fitness ever found! : 1.1205944395600819e-09
# Population of 106 members in 50 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#      1    0     2  3.6079766880240915e-13  7.868703008289101e-14     0
#      2    0     2  2.8211063871951813e-13      0.0     0
#      3    0     2  5.072990616152927e-13  2.2518842289577457e-13     0
#      4    0     2  7.194228055624162e-13  4.3731216684289806e-13     0
#      5    0     2  2.9770855089250074e-13  1.5597912172982607e-14     0
#      6    0     2  4.823344926290661e-13  2.0022385390954793e-13     0
#      7    0     2  3.608278086301875e-13  7.871716991066937e-14     0
#      8    0     2  4.2515892980418257e-13  1.4304829108466443e-13     0
#      9    0     2  7.882738260630232e-13  5.061631873435051e-13     0
#     10    0     2  1.3914433641132933e-11  1.3632323002413415e-11     0
#     11    0     2  3.4736105434894493e-13  6.52504156294268e-14     0
#     12    0     2  1.6210890233585386e-12  1.3389783846390205e-12     0
#     13    0     2  3.163949718808466e-13  3.4284333161328444e-14     0
#     14    0     2  1.1805930548219792e-12  8.98482416102461e-13     0
#     15    0     2  3.425901521021565e-13  6.047951338263835e-14     0
#     16    0     2  3.2458052343781016e-13  4.2469884718292024e-14     0
#     17    0     2  3.333590011233831e-13  5.1248362403864965e-14     0
#     18    0     2  3.734258816574101e-13  9.131524293789195e-14     0
#     19    0     2  7.5813478832321e-13  4.760241496036918e-13     0
#     20    0     2  7.358342478032019e-13  4.5372360908368376e-13     0
#     21    0     2  3.5340853655205523e-13  7.12978978325371e-14     0
#      7   12     2  3.3573789686027517e-13  5.362725814075704e-14     1
#      8   12     2  8.381812614334026e-13  5.560706227138845e-13     5
#      9   12     2  6.244078446034254e-13  3.422972058839072e-13     1
#     10   12     2  7.92045728220803e-12  7.638346643488511e-12    10
#     11   12     2  3.4848867042296885e-13  6.637803170345072e-14    10
#     12   12     2  1.3383818657754976e-12  1.0562712270559794e-12    10
# ...
# Total extinctions: 0
# Generation time: 3.441 sec (3.352 average)
#
#  ****** Running generation 778 ******
#
# Agent count: 50
# Population's average fitness: 0.42593 stdev: 1.12484
# Best fitness: 4.62064 - size: (76, 92) - species 10 - id 34563
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  778    48  0.44367213101330405  0.09601961049794902    46
#     43  778     2  7.954528371871149e-11  1.7131032145767035e-11   735
# Total extinctions: 0
# Generation time: 3.584 sec (3.414 average)
#
#  ****** Running generation 779 ******
#
# Agent count: 50
# Population's average fitness: 0.20200 stdev: 0.61577
# Best fitness: 3.81346 - size: (76, 92) - species 10 - id 34563
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  779    48  0.21042034058915762  0.05517828253871334    47
#     43  779     2  7.614936152129768e-11  1.0010084743890023e-14   736
# Total extinctions: 0
# Generation time: 3.392 sec (3.439 average)
#
#  ****** Running generation 780 ******
#
# Agent count: 50
# Population's average fitness: 0.29942 stdev: 0.66357
# Best fitness: 3.81346 - size: (76, 92) - species 10 - id 34563
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  780    48  0.3118993930929932  0.08178901711487181    48
#     43  780     2  7.614936152129768e-11  1.0010084743890023e-14   737
# Total extinctions: 0
# Generation time: 3.669 sec (3.459 average)
#
#  ****** Running generation 781 ******
#
# Agent count: 50
# Population's average fitness: 0.26921 stdev: 0.59807
# Best fitness: 2.41669 - size: (76, 84) - species 10 - id 34773
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  781    48  0.28042545390567564  0.11603723603696472    49
#     43  781     2  5.617794328433596e-12  1.666426316609768e-15   738
# Total extinctions: 0
# Generation time: 3.246 sec (3.470 average)
#
#  ****** Running generation 782 ******
#
# Agent count: 50
# Population's average fitness: 0.29373 stdev: 0.74028
# Best fitness: 2.99492 - size: (76, 90) - species 10 - id 34878
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  782    48  0.3059736984861616  0.1021643497544199    50
#     43  782     2  5.993717585115275e-11  5.254088980292284e-12   739
# Total extinctions: 0
# Generation time: 3.097 sec (3.474 average)
#
#  ****** Running generation 783 ******
#
# Agent count: 50
# Population's average fitness: 0.42703 stdev: 0.80624
# Best fitness: 3.62666 - size: (76, 85) - species 10 - id 34972
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  783    48  0.4448191975706682  0.1226527203450998    51
#     43  783     2  3.556011236998547e-11  6.989458162617364e-15   740
# Total extinctions: 0
# Generation time: 3.242 sec (3.419 average)
#
#  ****** Running generation 784 ******
#
# Agent count: 50
# Population's average fitness: 0.27429 stdev: 0.64126
# Best fitness: 3.14103 - size: (76, 85) - species 10 - id 34972
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  784    48  0.28571655417013697  0.09096280836492104    52
#     43  784     2  5.617794328433596e-12  1.2821375745992352e-15   741
# Total extinctions: 0
# Generation time: 3.459 sec (3.422 average)
#
#  ****** Running generation 785 ******
#
# Agent count: 50
# Population's average fitness: 0.27012 stdev: 0.77251
# Best fitness: 3.61752 - size: (76, 85) - species 10 - id 34972
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  785    48  0.2813724769633426  0.0777805088310746    53
#     43  785     2  7.614936152129768e-11  1.0552283750919793e-14   742
# Total extinctions: 0
# Generation time: 3.964 sec (3.452 average)
#
#  ****** Running generation 786 ******
#
# Agent count: 50
# Population's average fitness: 0.29636 stdev: 0.81626
# Best fitness: 3.44819 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  786    48  0.308704630997216  0.08952663615862658    54
#     43  786     2  5.617794328433596e-12  7.016597264606985e-14   743
# Total extinctions: 0
# Generation time: 3.775 sec (3.487 average)
#
#  ****** Running generation 787 ******
#
# Agent count: 50
# Population's average fitness: 0.22622 stdev: 0.53730
# Best fitness: 3.09552 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  787    48  0.2356411043321556  0.07612323070119133    55
#     43  787     2  1.5058493749291503e-11  2.0679752797989863e-14   744
# Total extinctions: 0
# Generation time: 3.249 sec (3.468 average)
#
#  ****** Running generation 788 ******
#
# Agent count: 50
# Population's average fitness: 0.21767 stdev: 0.54555
# Best fitness: 3.09552 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  788    48  0.2267380259172835  0.07324711494842388    56
#     43  788     2  1.5058493749291503e-11  2.0679752797989863e-14   745
# Total extinctions: 0
# Generation time: 3.277 sec (3.437 average)
#
#  ****** Running generation 789 ******
#
# Agent count: 50
# Population's average fitness: 0.25886 stdev: 0.63162
# Best fitness: 3.44819 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  789    48  0.26964448899321963  0.0781989048244013    57
#     43  789     2  5.617794328433596e-12  3.272532755906493e-14   746
# Total extinctions: 0
# Generation time: 3.146 sec (3.412 average)
#
#  ****** Running generation 790 ******
#
# Agent count: 50
# Population's average fitness: 0.16659 stdev: 0.39326
# Best fitness: 2.28104 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  790    48  0.17352896016511363  0.07607460649934898    58
#     43  790     2  1.591779420273632e-14  2.4475524625581153e-17   747
# Total extinctions: 0
# Generation time: 3.304 sec (3.376 average)
#
#  ****** Running generation 791 ******
#
# Agent count: 50
# Population's average fitness: 0.20104 stdev: 0.56269
# Best fitness: 3.29779 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  791    48  0.20941225703950406  0.0635008154366359    59
#     43  791     2  3.556011236998547e-11  7.686472038216424e-15   748
# Total extinctions: 0
# Generation time: 3.545 sec (3.406 average)
#
#  ****** Running generation 792 ******
#
# Agent count: 50
# Population's average fitness: 0.27267 stdev: 0.56760
# Best fitness: 3.06572 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  792    48  0.28403397659472357  0.09264842452938148    60
#     43  792     2  7.614936152129768e-11  1.2451596512950658e-14   749
# Total extinctions: 0
# Generation time: 3.892 sec (3.485 average)
#
#  ****** Running generation 793 ******
#
# Agent count: 50
# Population's average fitness: 0.23318 stdev: 0.71727
# Best fitness: 3.84705 - size: (75, 90) - species 10 - id 35431
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  793    48  0.24289640047393377  0.06313829126479004    61
#     43  793     2  1.5058493749291503e-11  1.6639908199203563e-14   750
# Total extinctions: 0
# Generation time: 3.498 sec (3.511 average)
#
#  ****** Running generation 794 ******
#
# Agent count: 50
# Population's average fitness: 0.28191 stdev: 0.67165
# Best fitness: 3.06572 - size: (76, 91) - species 10 - id 35074
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  794    48  0.2936592810340451  0.0957880816325533    62
#     43  794     2  7.614936152129768e-11  1.2451596512950658e-14   751
# Total extinctions: 0
# Generation time: 3.371 sec (3.502 average)
#
#  ****** Running generation 795 ******
#
# Agent count: 50
# Population's average fitness: 0.34807 stdev: 0.83409
# Best fitness: 3.84705 - size: (75, 90) - species 10 - id 35431
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  795    48  0.3625684024706389  0.09424573338427832    63
#     43  795     2  1.5058493749291503e-11  1.6639908199203563e-14   752
# Total extinctions: 0
# Generation time: 3.246 sec (3.430 average)
#
#  ****** Running generation 796 ******
#
# Agent count: 50
# Population's average fitness: 0.15999 stdev: 0.44758
# Best fitness: 2.55327 - size: (75, 90) - species 10 - id 35431
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  796    48  0.16665676807551338  0.06527193318301222    64
#     43  796     2  3.556011236998547e-11  1.588776281168641e-13   753
# Total extinctions: 0
# Generation time: 3.235 sec (3.376 average)
#
#  ****** Running generation 797 ******
#
# Agent count: 50
# Population's average fitness: 0.19961 stdev: 0.53121
# Best fitness: 2.55327 - size: (75, 90) - species 10 - id 35431
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  797    48  0.2079315636730533  0.08143740748160457    65
#     43  797     2  3.556011236998547e-11  5.362901884856706e-13   754
# Total extinctions: 0
# Generation time: 3.781 sec (3.429 average)
#
#  ****** Running generation 798 ******
#
# Agent count: 50
# Population's average fitness: 0.20326 stdev: 0.56575
# Best fitness: 3.27493 - size: (75, 90) - species 10 - id 35431
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  798    48  0.21173393158965645  0.06465293603665223    66
#     43  798     2  1.591779420273632e-14  1.70475530055171e-17   755
# Total extinctions: 0
# Generation time: 3.268 sec (3.428 average)
#
#  ****** Running generation 799 ******
#
# Agent count: 50
# Population's average fitness: 0.19306 stdev: 0.55920
# Best fitness: 3.46540 - size: (76, 91) - species 10 - id 35653
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  799    48  0.20110433556745186  0.058031998050661004    67
#     43  799     2  7.954528371871149e-11  2.286149672332206e-11   756
# Total extinctions: 0
# Generation time: 3.228 sec (3.437 average)
#
#  ****** Running generation 800 ******
#
# Agent count: 50
# Population's average fitness: 0.11257 stdev: 0.29308
# Best fitness: 1.90086 - size: (76, 91) - species 10 - id 35653
# Population of 50 members in 2 species:
#    ID   age  size   fitness   adj fit  stag
#   ====  ===  ====  =========  =======  ====
#     10  800    48  0.11726163355763032  0.061688679784418395    68
#     43  800     2  1.5058493749291503e-11  3.3676637074593546e-14   757
# Total extinctions: 0
# Generation time: 3.549 sec (3.461 average)
#
#  ****** Running generation 801 ******
#
# Agent count: 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 5
#       3 # pre create folders for checkpointer
#       4 for r in range(NUM_RUNS):
# ----> 5     run(config_path, r, datte)
#
# Cell In[11], line 18, in run(config_file, run, datte)
#      16 pop.add_reporter(neat.TBReporter(True, 0, run, datte))
#      17 #pop.add_reporter(neat.StdOutReporter(True))
# ---> 18 best = pop.run(eval_genomes, MAX_GENS)
#      19 # Display the winning genome.
#      20 # print('\nBest genome:\n{!s}'.format(best))
#      21 print("Finished running!")
#
# File c:\users\alesm\documents\neat-python-plus\neat\population.py:88, in Population.run(self, fitness_function, n)
#      85 self.reporters.start_generation(self.generation)
#      87 # Evaluate all genomes using the user-provided function.
# ---> 88 fitness_function(list(self.population.items()), self.config)
#      90 # Gather and report statistics.
#      91 best = None
#
# Cell In[10], line 32, in eval_genomes(genomes, cfg)
#      28         action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
#      29         env.set_action_for_agent(behavior_name=behavior_name,
#      30                                 agent_id=agent,
#      31                                 action=action_tuple)
# ---> 32 env.step()
#      33 decision_steps, terminal_steps = env.get_steps(behavior_name)
#      34 for agent in range(agent_count):
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:348, in UnityEnvironment.step(self)
#     346 step_input = self._generate_step_input(self._env_actions)
#     347 with hierarchical_timer("communicator.exchange"):
# --> 348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
#     350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\rpc_communicator.py:142, in RpcCommunicator.exchange(self, inputs, poll_callback)
#     140 message.unity_input.CopyFrom(inputs)
#     141 self.unity_to_external.parent_conn.send(message)
# --> 142 self.poll_for_timeout(poll_callback)
#     143 output = self.unity_to_external.parent_conn.recv()
#     144 if output.header.status != 200:
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\rpc_communicator.py:106, in RpcCommunicator.poll_for_timeout(self, poll_callback)
#     104 callback_timeout_wait = self.timeout_wait // 10
#     105 while time.monotonic() < deadline:
# --> 106     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#     107         # Got an acknowledgment from the connection
#     108         return
#     109     if poll_callback:
#     110         # Fire the callback - if it detects something wrong, it should raise an exception.
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\multiprocessing\connection.py:330, in PipeConnection._poll(self, timeout)
#     327 if (self._got_empty_message or
#     328             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329     return True
# --> 330 return bool(wait([self], timeout))
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\multiprocessing\connection.py:879, in wait(object_list, timeout)
#     876                 ready_objects.add(o)
#     877                 timeout = 0
# --> 879     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     880 finally:
#     881     # request that overlapped reads stop
#     882     for ov in ov_list:
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\multiprocessing\connection.py:811, in _exhaustive_wait(handles, timeout)
#     809 ready = []
#     810 while L:
# --> 811     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     812     if res == WAIT_TIMEOUT:
#     813         break
#
# KeyboardInterrupt:

# %%
env.close()
