# %%
import pickle
import numpy as np
import neat
import os
import keyboard

#from game_config import game_config
# MLAGENTS stuff
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel

# %%
engine_config_channel = EngineConfigurationChannel()
from comunication_channel import AgentLogChannel
agent_count_channel = AgentLogChannel()
engine_config_channel.set_configuration_parameters(time_scale=0.1)

env_path = "../Builds/train-env/autonomous-drone.exe"

env = UnityEnvironment(file_name=None, seed=0, no_graphics=False, side_channels=[engine_config_channel, agent_count_channel])
env.reset()

# %%
num_actions = 4
num_inputs = 14
out_mult = 1

behavior_specs = env.behavior_specs
print(f"Behaviour specs {behavior_specs}")
behavior_name = list(behavior_specs)[0]
spec = env.behavior_specs[behavior_name]

print(f"Name of the behavior : {behavior_name}")
print("Number of observations : ", len(spec.observation_specs)) # vector if 1
# Out:
# Behaviour specs <mlagents_envs.base_env.BehaviorMapping object at 0x000001B2203CEEF0>
# Name of the behavior : My Behavior?team=0
# Number of observations :  1

# %%
# Is the Action continuous or multi-discrete ?
if spec.action_spec.continuous_size > 0:
  print(f"There are {spec.action_spec.continuous_size} continuous actions")
if spec.action_spec.is_discrete():
  print(f"There are {spec.action_spec.discrete_size} discrete actions")
# Out:
# There are 4 continuous actions

# %%
def map_agent_ids(decision_steps):
    """
    Map agent ids between NEAT and UNITY.

    Args:
        decision_steps: An iterable containing decision steps.

    Returns:
        A tuple of two dictionaries: (unity_to_neat_map, neat_to_unity_map)
    """
    unity_to_neat_map = {}
    neat_to_unity_map = {}
    id_count = 0
    for step in decision_steps:
        unity_to_neat_map[step] = id_count
        neat_to_unity_map[id_count] = step
        id_count += 1
    return unity_to_neat_map, neat_to_unity_map

# %%
def set_agents_and_double_reset(num_agents: int):
    agent_count_channel.send_int(data=num_agents) 
    env.reset()
    env.reset()

# %%
set_agents_and_double_reset(2)
# Out:
# Sending: 2

# %%
import time
import random
import math

def eval_agent(genome, cfg):
    i = 0
    send_array = [2, 1, 2]

    while True:
        policy = neat.nn.FeedForwardNetwork.create(genome, cfg)
        #policy = neat.nn.RecurrentNetwork.create(genome, cfg)
        set_agents_and_double_reset(random.randint(1, 2))
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        agent_count = len(decision_steps.agent_id)
        policies = [policy] * agent_count

        unity_to_neat_map, neat_to_unity_map = map_agent_ids(decision_steps)

        done = False  # Vectorized initialization
        removed_agents = []

        episode_rewards = [0] * agent_count
        print(f"Agent count: {agent_count}")
        while not done:
            # if keyboard.is_pressed('q'):  # Check if 'q' is pressed
            #     env.close()
            #     return
            for agent in decision_steps:
                if unity_to_neat_map[agent] not in removed_agents:
                    nn_input = np.asarray(decision_steps[agent].obs[:])
                    print(f"{agent} {nn_input}")
                    actions = policies[unity_to_neat_map[agent]].activate(nn_input[0])
                    print(f"{agent} {actions}")
                    continous_actions = np.asarray([actions])
                    continous_actions = np.clip(continous_actions, -1, 1)

                    action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
                    env.set_action_for_agent(behavior_name=behavior_name, 
                                            agent_id=agent, 
                                            action=action_tuple)
            env.step()
            decision_steps, terminal_steps = env.get_steps(behavior_name)
            for agent in range(agent_count):
                if agent not in removed_agents:
                    local_agent = neat_to_unity_map[agent]
                    if local_agent in terminal_steps:
                        episode_rewards[agent] += terminal_steps[local_agent].reward
                        removed_agents.append(agent)
                    elif local_agent in decision_steps:
                        episode_rewards[agent] += decision_steps[local_agent].reward                             
            if len(removed_agents) >= agent_count:
                print(".") 
                done = True
        print(round(max(episode_rewards), 2))
        for reward in episode_rewards:
            print(reward)
        #while keyboard.is_pressed('c') == False:
        #    time.sleep(0.1)

# %%
save_nn_destination = 'result/best.pkl'

with open(save_nn_destination, "rb") as f:
    genome = pickle.load(f)
    print(genome)
print(genome.fitness)
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                    neat.DefaultSpeciesSet, neat.DefaultStagnation,
                    'config')

eval_agent(genome, config)
# Out:
# Key: 75543
# Fitness: -1897.0006994844853
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	128 DefaultNodeGene(key=128, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	129 DefaultNodeGene(key=129, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	130 DefaultNodeGene(key=130, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	299 DefaultNodeGene(key=299, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	365 DefaultNodeGene(key=365, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	406 DefaultNodeGene(key=406, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	3879 DefaultNodeGene(key=3879, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	4134 DefaultNodeGene(key=4134, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	4228 DefaultNodeGene(key=4228, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	4309 DefaultNodeGene(key=4309, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	4355 DefaultNodeGene(key=4355, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	5168 DefaultNodeGene(key=5168, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	5807 DefaultNodeGene(key=5807, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	7443 DefaultNodeGene(key=7443, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	11841 DefaultNodeGene(key=11841, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	26655 DefaultNodeGene(key=26655, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# 	45466 DefaultNodeGene(key=45466, bias=0.0, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-12, 0), weight=0.40910906673577574, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=1.5093202890384358, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=-1.5042152145082939, enabled=True)
# 	DefaultConnectionGene(key=(-12, 129), weight=0.7244277548966731, enabled=True)
# 	DefaultConnectionGene(key=(-12, 130), weight=-0.08421182881964456, enabled=True)
# 	DefaultConnectionGene(key=(-12, 4228), weight=0.2171275449117658, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=2.8862052666157694, enabled=False)
# 	DefaultConnectionGene(key=(-11, 1), weight=0.5109408173611298, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=-1.588175209669919, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=2.8370261378806383, enabled=True)
# 	DefaultConnectionGene(key=(-11, 128), weight=1.2733779344789256, enabled=True)
# 	DefaultConnectionGene(key=(-11, 129), weight=2.337549569379164, enabled=True)
# 	DefaultConnectionGene(key=(-11, 130), weight=1.5678974705892763, enabled=False)
# 	DefaultConnectionGene(key=(-11, 406), weight=-3.2377132450144828, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-1.2793074410259178, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=0.5584501535127436, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=1.3547473949620443, enabled=False)
# 	DefaultConnectionGene(key=(-10, 128), weight=-1.8043329109927018, enabled=True)
# 	DefaultConnectionGene(key=(-10, 129), weight=1.5223797305210578, enabled=False)
# 	DefaultConnectionGene(key=(-10, 130), weight=-0.1627978638455868, enabled=False)
# 	DefaultConnectionGene(key=(-10, 406), weight=2.3573785284961204, enabled=True)
# 	DefaultConnectionGene(key=(-10, 45466), weight=1.067060669251458, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=2.6273457115856393, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=-0.1816395987683099, enabled=True)
# 	DefaultConnectionGene(key=(-9, 128), weight=-2.413031066091369, enabled=True)
# 	DefaultConnectionGene(key=(-9, 129), weight=-0.7100636047722012, enabled=False)
# 	DefaultConnectionGene(key=(-9, 130), weight=0.35686593669581307, enabled=True)
# 	DefaultConnectionGene(key=(-9, 299), weight=-0.9592136312942933, enabled=True)
# 	DefaultConnectionGene(key=(-9, 365), weight=-0.15546578958846177, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=0.6468222557919171, enabled=False)
# 	DefaultConnectionGene(key=(-8, 1), weight=-2.0060015650714984, enabled=False)
# 	DefaultConnectionGene(key=(-8, 2), weight=-1.0167925475344755, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=1.2495751193749993, enabled=True)
# 	DefaultConnectionGene(key=(-8, 128), weight=-1.803794144850868, enabled=False)
# 	DefaultConnectionGene(key=(-8, 129), weight=-1.202784184396112, enabled=True)
# 	DefaultConnectionGene(key=(-8, 130), weight=-1.4275578650475391, enabled=True)
# 	DefaultConnectionGene(key=(-8, 7443), weight=2.157527782483399, enabled=True)
# 	DefaultConnectionGene(key=(-8, 11841), weight=-0.040773191737816905, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=2.311425312258808, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=0.2594449171435176, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=1.0582001167507586, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=2.44882996196979, enabled=True)
# 	DefaultConnectionGene(key=(-7, 128), weight=-0.05255086536458746, enabled=True)
# 	DefaultConnectionGene(key=(-7, 129), weight=1.290074488304087, enabled=True)
# 	DefaultConnectionGene(key=(-7, 130), weight=-1.4346944086016828, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=0.5973506912080366, enabled=False)
# 	DefaultConnectionGene(key=(-6, 1), weight=-0.0944261714743494, enabled=False)
# 	DefaultConnectionGene(key=(-6, 2), weight=0.39410778888277165, enabled=True)
# 	DefaultConnectionGene(key=(-6, 3), weight=-1.6414235065658203, enabled=False)
# 	DefaultConnectionGene(key=(-6, 128), weight=0.2833929165411533, enabled=True)
# 	DefaultConnectionGene(key=(-6, 129), weight=-1.3515370401472209, enabled=True)
# 	DefaultConnectionGene(key=(-6, 130), weight=2.281145366949407, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.8053431621196259, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=0.9404028983631276, enabled=False)
# 	DefaultConnectionGene(key=(-5, 2), weight=1.4564792769061863, enabled=False)
# 	DefaultConnectionGene(key=(-5, 3), weight=-1.3197829868888054, enabled=False)
# 	DefaultConnectionGene(key=(-5, 128), weight=1.4160758098738448, enabled=True)
# 	DefaultConnectionGene(key=(-5, 129), weight=1.6672298995468404, enabled=True)
# 	DefaultConnectionGene(key=(-5, 130), weight=0.5787800803561105, enabled=True)
# 	DefaultConnectionGene(key=(-5, 4134), weight=-0.8177507698545696, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=1.1304816299720406, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-3.625630668753011, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=-0.6959350406166445, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=-0.028869477458934284, enabled=True)
# 	DefaultConnectionGene(key=(-4, 128), weight=3.79299630271211, enabled=True)
# 	DefaultConnectionGene(key=(-4, 129), weight=0.8915834736156238, enabled=True)
# 	DefaultConnectionGene(key=(-4, 130), weight=-0.8804608800297313, enabled=True)
# 	DefaultConnectionGene(key=(-4, 5168), weight=-0.5756286170974796, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-2.207289112146006, enabled=False)
# 	DefaultConnectionGene(key=(-3, 1), weight=-0.1412557028158841, enabled=False)
# 	DefaultConnectionGene(key=(-3, 2), weight=0.2915555452686587, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=3.012291680044491, enabled=True)
# 	DefaultConnectionGene(key=(-3, 129), weight=1.9788563027599282, enabled=False)
# 	DefaultConnectionGene(key=(-3, 130), weight=-1.7589558721128877, enabled=True)
# 	DefaultConnectionGene(key=(-3, 4309), weight=0.08485744699153691, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.07630769931373904, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=0.5626074465383247, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.6400893535623045, enabled=True)
# 	DefaultConnectionGene(key=(-2, 128), weight=-1.480079175733484, enabled=True)
# 	DefaultConnectionGene(key=(-2, 129), weight=0.1113885654231268, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3879), weight=-0.4826180590417264, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.263573680555623, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=-2.161057612733575, enabled=False)
# 	DefaultConnectionGene(key=(-1, 2), weight=-0.214146075517349, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=-0.8681058081467553, enabled=True)
# 	DefaultConnectionGene(key=(-1, 128), weight=-1.791642698384696, enabled=False)
# 	DefaultConnectionGene(key=(-1, 129), weight=-0.36863433328488565, enabled=True)
# 	DefaultConnectionGene(key=(-1, 130), weight=1.83931277902232, enabled=True)
# 	DefaultConnectionGene(key=(1, 5807), weight=1.6786256638834582, enabled=True)
# 	DefaultConnectionGene(key=(128, 0), weight=1.5124997512650724, enabled=False)
# 	DefaultConnectionGene(key=(128, 1), weight=-0.1539344062298258, enabled=True)
# 	DefaultConnectionGene(key=(128, 2), weight=-0.9384173252623393, enabled=True)
# 	DefaultConnectionGene(key=(128, 3), weight=1.522136385091492, enabled=True)
# 	DefaultConnectionGene(key=(129, 0), weight=3.3885281985986366, enabled=True)
# 	DefaultConnectionGene(key=(129, 1), weight=4.4788495940051885, enabled=True)
# 	DefaultConnectionGene(key=(129, 2), weight=0.678498077682363, enabled=True)
# 	DefaultConnectionGene(key=(129, 3), weight=0.9919551401629196, enabled=True)
# 	DefaultConnectionGene(key=(129, 4355), weight=-1.8769840602069643, enabled=True)
# 	DefaultConnectionGene(key=(130, 0), weight=0.781939553222631, enabled=False)
# 	DefaultConnectionGene(key=(130, 1), weight=1.1700593061725832, enabled=True)
# 	DefaultConnectionGene(key=(130, 2), weight=4.760552077986629, enabled=True)
# 	DefaultConnectionGene(key=(130, 3), weight=0.20102441238666643, enabled=True)
# 	DefaultConnectionGene(key=(299, 0), weight=-1.223597918937972, enabled=False)
# 	DefaultConnectionGene(key=(299, 5807), weight=-0.23182692792452608, enabled=True)
# 	DefaultConnectionGene(key=(365, 130), weight=-0.620943428314236, enabled=True)
# 	DefaultConnectionGene(key=(406, 130), weight=-1.8383382258999625, enabled=True)
# 	DefaultConnectionGene(key=(3879, 406), weight=2.8781772048181224, enabled=True)
# 	DefaultConnectionGene(key=(4134, 129), weight=0.04423760043897046, enabled=False)
# 	DefaultConnectionGene(key=(4134, 26655), weight=0.8899292746886354, enabled=True)
# 	DefaultConnectionGene(key=(4228, 130), weight=-1.0081319927461354, enabled=False)
# 	DefaultConnectionGene(key=(4309, 0), weight=-0.6248891332013135, enabled=True)
# 	DefaultConnectionGene(key=(4309, 129), weight=0.043483194763330985, enabled=True)
# 	DefaultConnectionGene(key=(4355, 3), weight=-1.434446496140486, enabled=True)
# 	DefaultConnectionGene(key=(5168, 130), weight=1.66755678281677, enabled=True)
# 	DefaultConnectionGene(key=(5807, 0), weight=-0.5409362296930176, enabled=True)
# 	DefaultConnectionGene(key=(7443, 128), weight=-0.23404644632022484, enabled=True)
# 	DefaultConnectionGene(key=(11841, 1), weight=0.8406628685718995, enabled=True)
# 	DefaultConnectionGene(key=(26655, 129), weight=0.7266389428270231, enabled=True)
# 	DefaultConnectionGene(key=(45466, 3), weight=2.34529697267809, enabled=True)
# -1897.0006994844853
# Sending: 2
# Agent count: 2
# .
# -1897.0
# -1897.0006994844853
# -1897.0006994844853
# Sending: 1
# Agent count: 1
# .
# -1897.0
# -1897.0006994844853
# Sending: 2
# Agent count: 2
# .
# -1897.0
# -1897.0006994844853
# -1897.0006994844853
# Sending: 1
# Agent count: 1
# .
# -1897.0
# -1897.0006994844853
# Sending: 2
# Agent count: 2
# ---------------------------------------------------------------------------
# UnityCommunicatorStoppedException         Traceback (most recent call last)
# Cell In[29], line 11
#       6 print(genome.fitness)
#       7 config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
#       8                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
#       9                     'config')
# ---> 11 eval_agent(genome, config)
#
# Cell In[28], line 41, in eval_agent(genome, cfg)
#      37         action_tuple = ActionTuple(discrete=None, continuous=continous_actions)
#      38         env.set_action_for_agent(behavior_name=behavior_name,
#      39                                 agent_id=agent,
#      40                                 action=action_tuple)
# ---> 41 env.step()
#      42 decision_steps, terminal_steps = env.get_steps(behavior_name)
#      43 for agent in range(agent_count):
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File c:\Users\alesm\miniconda3\envs\mlagents\lib\site-packages\mlagents_envs\environment.py:350, in UnityEnvironment.step(self)
#     348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
# --> 350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#     351 self._update_behavior_specs(outputs)
#     352 rl_output = outputs.rl_output
#
# UnityCommunicatorStoppedException: Communicator has exited.

# %%
env.close()
